# %%
import tensorflow as tf
import tensorflow_io as tfio
import tensorflow_probability as tfp

print(tf.__version__)
print('Listing all GPU resources:')
print(tf.config.experimental.list_physical_devices('GPU'))
print()
import tensorflow.keras as keras
print(tfp.__version__)
import numpy as np
import datetime
import time
import matplotlib.pyplot as plt
import pickle
import os
import sys
import git
import importlib.util
from tqdm import trange
# Out:
# 2.2.0
# Listing all GPU resources:
# []
#
# 0.10.0

# %%
LAYER_NAME = 'linear_gaussian'
ROOT_PATH = git.Repo("", search_parent_directories=True).git.rev_parse("--show-toplevel")
DATA_PATH = ROOT_PATH + "/data/"
SAVE_PATH = "bayesian_model.h5"
N_DATA = 16
X_DIM = 2
EPOCHS = 1000
VERBOSE = 2
N_SAMPLES = 1000

PRIOR_MU = 0
PRIOR_STDDEV = 10
LIKELIHOOD_STDDEV = 0.1

np.random.seed(1)

# %%
X = np.random.rand(N_DATA, X_DIM)
y = (3*X[:, 0].reshape(-1, 1) 
     + 2*X[:, 1].reshape(-1, 1) 
     + np.random.normal(0, LIKELIHOOD_STDDEV, N_DATA).reshape(-1, 1))

print("-" * 30)
print("Loading training and testing data...")
print("-" * 30)

print('X:', X.shape)
print('y: ', y.shape)

Xy = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(X),
                                tf.data.Dataset.from_tensor_slices(y))).cache()
# Out:
# ------------------------------
# Loading training and testing data...
# ------------------------------
# X: (16, 2)
# y:  (16, 1)

# %%
def make_model():

    class KLDivergence:
        def __init__(self, q_dist, p_dist):
            self.q_dist = q_dist
            self.p_dist = p_dist
        def call(self):
            return tfp.distributions.kl_divergence(self.q_dist, self.p_dist)
    
    likelihood_fn = tfp.distributions.MultivariateNormalDiag(np.zeros(N_DATA).astype(np.float32), 
                                                             scale_identity_multiplier=LIKELIHOOD_STDDEV)
    
    def gaussian_likelihood(y, y_pred):
        return -likelihood_fn.log_prob(y-y_pred)
    

    posterior_fn = tfp.layers.default_mean_field_normal_fn(
              loc_initializer=tf.random_normal_initializer(
                  mean=PRIOR_MU, stddev=0.05),
              untransformed_scale_initializer=tf.random_normal_initializer(
                  mean=np.log(np.exp(PRIOR_STDDEV) - 1), stddev=0.05))

    def prior_fn(dtype, shape, name, trainable, add_variable_fn):
        dist = tfp.distributions.Normal(loc=PRIOR_MU*tf.ones(shape, dtype), 
                                 scale=PRIOR_STDDEV*tf.ones(shape, dtype))
        multivar_dist = tfp.distributions.Independent(dist, reinterpreted_batch_ndims=tf.size(dist.batch_shape_tensor()))

        return multivar_dist

    flipout_params = dict(kernel_prior_fn=prior_fn,
                          bias_prior_fn=prior_fn,
                          kernel_posterior_fn=posterior_fn,
                          bias_posterior_fn=posterior_fn,
                          kernel_divergence_fn=None,
                          bias_divergence_fn=None)

    input_layer = keras.layers.Input(shape=(X_DIM), name="input_layer")

    output_layer = tfp.layers.DenseFlipout(1, name='dense_layer', **flipout_params)(input_layer)
    
    print()
    print('Input size:', input_layer.shape)
    print('Output size:', output_layer.shape)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer,
                               name = 'model_' + LAYER_NAME)

    for layer in model.layers:
        if type(layer) == tfp.python.layers.dense_variational.DenseFlipout:
            layer.add_loss(KLDivergence(layer.kernel_posterior, layer.kernel_prior).call)
            layer.add_loss(KLDivergence(layer.bias_posterior, layer.bias_prior).call)

    model.compile(optimizer=keras.optimizers.Nadam(learning_rate=2e-2),
                  loss=gaussian_likelihood,
                  metrics=[gaussian_likelihood],
                  )

    return model

# %%
print("-" * 30)
print("Constructing model...")
print("-" * 30)
mirrored_strategy = tf.distribute.MirroredStrategy()

with mirrored_strategy.scope():
    model = make_model()

print('Model summary:')
print(model.summary())

print('Model losses:')
print(model.losses)

print("-" * 30)
print("Fitting model with training data ...")
print("-" * 30)

print("Training the model started at {}".format(datetime.datetime.now()))
start_time = time.time()

#Train the model
history = model.fit(Xy.batch(N_DATA).repeat(32).unbatch().batch(32*N_DATA),
                    epochs=EPOCHS, verbose=VERBOSE,
                    batch_size=N_DATA)

print("Total time elapsed for training = {} seconds".format(time.time() - start_time))
print("Training finished at {}".format(datetime.datetime.now()))


# Save the model
# serialize weights to HDF5
model.save_weights(SAVE_PATH)
# Out:
# ------------------------------
# Constructing model...
# ------------------------------
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# WARNING:tensorflow:From /Users/hauthj/miniconda3/envs/test-env/lib/python3.7/site-packages/tensorflow_probability/python/layers/util.py:106: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
#
# Input size: (None, 2)
# Output size: (None, 1)
# Model summary:
# Model: "model_linear_gaussian"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 2)]               0
# _________________________________________________________________
# dense_layer (DenseFlipout)   (None, 1)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model losses:
# [<tf.Tensor: shape=(), dtype=float32, numpy=5.3551747e-05>, <tf.Tensor: shape=(), dtype=float32, numpy=2.565654e-05>]
# ------------------------------
# Fitting model with training data ...
# ------------------------------
# Training the model started at 2020-07-21 13:15:42.455514
# Epoch 1/1000
# 1/1 - 0s - gaussian_likelihood: 285638.3438 - loss: 285638.3438
# Epoch 2/1000
# 1/1 - 0s - gaussian_likelihood: 22186.7344 - loss: 22186.7344
# Epoch 3/1000
# 1/1 - 0s - gaussian_likelihood: 102049.1406 - loss: 102049.1406
# Epoch 4/1000
# 1/1 - 0s - gaussian_likelihood: 11990.0859 - loss: 11990.0859
# Epoch 5/1000
# 1/1 - 0s - gaussian_likelihood: 129564.5469 - loss: 129564.5469
# Epoch 6/1000
# 1/1 - 0s - gaussian_likelihood: 5516.0010 - loss: 5516.0010
# Epoch 7/1000
# 1/1 - 0s - gaussian_likelihood: 72711.4297 - loss: 72711.4297
# Epoch 8/1000
# 1/1 - 0s - gaussian_likelihood: 138316.8594 - loss: 138316.8594
# Epoch 9/1000
# 1/1 - 0s - gaussian_likelihood: 400484.4375 - loss: 400484.4375
# Epoch 10/1000
# 1/1 - 0s - gaussian_likelihood: 229508.5781 - loss: 229508.5781
# Epoch 11/1000
# 1/1 - 0s - gaussian_likelihood: 220152.8750 - loss: 220152.8750
# Epoch 12/1000
# 1/1 - 0s - gaussian_likelihood: 183552.3438 - loss: 183552.3438
# Epoch 13/1000
# 1/1 - 0s - gaussian_likelihood: 70631.1094 - loss: 70631.1094
# Epoch 14/1000
# 1/1 - 0s - gaussian_likelihood: 187396.8125 - loss: 187396.8125
# Epoch 15/1000
# 1/1 - 0s - gaussian_likelihood: 91718.8750 - loss: 91718.8750
# Epoch 16/1000
# 1/1 - 0s - gaussian_likelihood: 57799.5664 - loss: 57799.5664
# Epoch 17/1000
# 1/1 - 0s - gaussian_likelihood: 34877.5781 - loss: 34877.5781
# Epoch 18/1000
# 1/1 - 0s - gaussian_likelihood: 184124.7188 - loss: 184124.7188
# Epoch 19/1000
# 1/1 - 0s - gaussian_likelihood: 66519.1641 - loss: 66519.1641
# Epoch 20/1000
# 1/1 - 0s - gaussian_likelihood: 106479.8906 - loss: 106479.8906
# Epoch 21/1000
# 1/1 - 0s - gaussian_likelihood: 140183.7500 - loss: 140183.7500
# Epoch 22/1000
# 1/1 - 0s - gaussian_likelihood: 53932.8633 - loss: 53932.8672
# Epoch 23/1000
# 1/1 - 0s - gaussian_likelihood: 17443.6602 - loss: 17443.6621
# Epoch 24/1000
# 1/1 - 0s - gaussian_likelihood: 3530.7681 - loss: 3530.7705
# Epoch 25/1000
# 1/1 - 0s - gaussian_likelihood: 170249.6562 - loss: 170249.6562
# Epoch 26/1000
# 1/1 - 0s - gaussian_likelihood: 145969.2188 - loss: 145969.2188
# Epoch 27/1000
# 1/1 - 0s - gaussian_likelihood: 544002.6875 - loss: 544002.6875
# Epoch 28/1000
# 1/1 - 0s - gaussian_likelihood: 28034.3477 - loss: 28034.3516
# Epoch 29/1000
# 1/1 - 0s - gaussian_likelihood: 102167.4922 - loss: 102167.5000
# Epoch 30/1000
# 1/1 - 0s - gaussian_likelihood: 146097.1250 - loss: 146097.1250
# Epoch 31/1000
# 1/1 - 0s - gaussian_likelihood: 234691.0000 - loss: 234691.0000
# Epoch 32/1000
# 1/1 - 0s - gaussian_likelihood: 227251.9062 - loss: 227251.9062
# Epoch 33/1000
# 1/1 - 0s - gaussian_likelihood: 190007.5938 - loss: 190007.5938
# Epoch 34/1000
# 1/1 - 0s - gaussian_likelihood: 121372.7500 - loss: 121372.7578
# Epoch 35/1000
# 1/1 - 0s - gaussian_likelihood: 377714.9062 - loss: 377714.9062
# Epoch 36/1000
# 1/1 - 0s - gaussian_likelihood: 264679.8125 - loss: 264679.8125
# Epoch 37/1000
# 1/1 - 0s - gaussian_likelihood: 18260.6504 - loss: 18260.6582
# Epoch 38/1000
# 1/1 - 0s - gaussian_likelihood: 93464.7344 - loss: 93464.7422
# Epoch 39/1000
# 1/1 - 0s - gaussian_likelihood: 428264.4375 - loss: 428264.4375
# Epoch 40/1000
# 1/1 - 0s - gaussian_likelihood: 231340.9844 - loss: 231341.0000
# Epoch 41/1000
# 1/1 - 0s - gaussian_likelihood: 40650.3789 - loss: 40650.3867
# Epoch 42/1000
# 1/1 - 0s - gaussian_likelihood: 80858.1406 - loss: 80858.1484
# Epoch 43/1000
# 1/1 - 0s - gaussian_likelihood: 212592.1562 - loss: 212592.1719
# Epoch 44/1000
# 1/1 - 0s - gaussian_likelihood: 28559.2148 - loss: 28559.2266
# Epoch 45/1000
# 1/1 - 0s - gaussian_likelihood: 302718.4688 - loss: 302718.4688
# Epoch 46/1000
# 1/1 - 0s - gaussian_likelihood: 56285.2773 - loss: 56285.2891
# Epoch 47/1000
# 1/1 - 0s - gaussian_likelihood: 48869.4766 - loss: 48869.4883
# Epoch 48/1000
# 1/1 - 0s - gaussian_likelihood: 238398.8906 - loss: 238398.9062
# Epoch 49/1000
# 1/1 - 0s - gaussian_likelihood: 64947.5703 - loss: 64947.5859
# Epoch 50/1000
# 1/1 - 0s - gaussian_likelihood: 159071.4062 - loss: 159071.4219
# Epoch 51/1000
# 1/1 - 0s - gaussian_likelihood: 523086.4062 - loss: 523086.4062
# Epoch 52/1000
# 1/1 - 0s - gaussian_likelihood: 91285.1406 - loss: 91285.1562
# Epoch 53/1000
# 1/1 - 0s - gaussian_likelihood: 147125.8125 - loss: 147125.8281
# Epoch 54/1000
# 1/1 - 0s - gaussian_likelihood: 286602.1875 - loss: 286602.2188
# Epoch 55/1000
# 1/1 - 0s - gaussian_likelihood: 308867.9375 - loss: 308867.9688
# Epoch 56/1000
# 1/1 - 0s - gaussian_likelihood: 51510.6719 - loss: 51510.6914
# Epoch 57/1000
# 1/1 - 0s - gaussian_likelihood: 113575.7344 - loss: 113575.7500
# Epoch 58/1000
# 1/1 - 0s - gaussian_likelihood: 528645.9375 - loss: 528645.9375
# Epoch 59/1000
# 1/1 - 0s - gaussian_likelihood: 79077.4297 - loss: 79077.4531
# Epoch 60/1000
# 1/1 - 0s - gaussian_likelihood: 29810.1836 - loss: 29810.2051
# Epoch 61/1000
# 1/1 - 0s - gaussian_likelihood: 132486.7188 - loss: 132486.7344
# Epoch 62/1000
# 1/1 - 0s - gaussian_likelihood: 250060.7188 - loss: 250060.7344
# Epoch 63/1000
# 1/1 - 0s - gaussian_likelihood: 28503.0547 - loss: 28503.0781
# Epoch 64/1000
# 1/1 - 0s - gaussian_likelihood: 68385.2891 - loss: 68385.3125
# Epoch 65/1000
# 1/1 - 0s - gaussian_likelihood: 116236.9219 - loss: 116236.9453
# Epoch 66/1000
# 1/1 - 0s - gaussian_likelihood: 21440.5469 - loss: 21440.5723
# Epoch 67/1000
# 1/1 - 0s - gaussian_likelihood: 154461.6875 - loss: 154461.7188
# Epoch 68/1000
# 1/1 - 0s - gaussian_likelihood: 34639.4688 - loss: 34639.4961
# Epoch 69/1000
# 1/1 - 0s - gaussian_likelihood: 799.0143 - loss: 799.0419
# Epoch 70/1000
# 1/1 - 0s - gaussian_likelihood: 127655.2188 - loss: 127655.2500
# Epoch 71/1000
# 1/1 - 0s - gaussian_likelihood: 24977.1699 - loss: 24977.1992
# Epoch 72/1000
# 1/1 - 0s - gaussian_likelihood: 138813.9844 - loss: 138814.0156
# Epoch 73/1000
# 1/1 - 0s - gaussian_likelihood: 342015.2812 - loss: 342015.3125
# Epoch 74/1000
# 1/1 - 0s - gaussian_likelihood: 45714.4531 - loss: 45714.4844
# Epoch 75/1000
# 1/1 - 0s - gaussian_likelihood: 44869.4141 - loss: 44869.4453
# Epoch 76/1000
# 1/1 - 0s - gaussian_likelihood: 237331.8750 - loss: 237331.9062
# Epoch 77/1000
# 1/1 - 0s - gaussian_likelihood: 17652.5781 - loss: 17652.6113
# Epoch 78/1000
# 1/1 - 0s - gaussian_likelihood: 209614.1562 - loss: 209614.1875
# Epoch 79/1000
# 1/1 - 0s - gaussian_likelihood: 127245.7500 - loss: 127245.7812
# Epoch 80/1000
# 1/1 - 0s - gaussian_likelihood: 54661.0859 - loss: 54661.1211
# Epoch 81/1000
# 1/1 - 0s - gaussian_likelihood: 208458.6875 - loss: 208458.7188
# Epoch 82/1000
# 1/1 - 0s - gaussian_likelihood: 144494.0156 - loss: 144494.0469
# Epoch 83/1000
# 1/1 - 0s - gaussian_likelihood: 26708.2520 - loss: 26708.2891
# Epoch 84/1000
# 1/1 - 0s - gaussian_likelihood: 161059.9844 - loss: 161060.0156
# Epoch 85/1000
# 1/1 - 0s - gaussian_likelihood: 228742.9062 - loss: 228742.9531
# Epoch 86/1000
# 1/1 - 0s - gaussian_likelihood: 49599.9297 - loss: 49599.9688
# Epoch 87/1000
# 1/1 - 0s - gaussian_likelihood: 188232.7031 - loss: 188232.7500
# Epoch 88/1000
# 1/1 - 0s - gaussian_likelihood: 575909.5000 - loss: 575909.5625
# Epoch 89/1000
# 1/1 - 0s - gaussian_likelihood: 10296.0537 - loss: 10296.0986
# Epoch 90/1000
# 1/1 - 0s - gaussian_likelihood: 10000.6152 - loss: 10000.6611
# Epoch 91/1000
# 1/1 - 0s - gaussian_likelihood: 46166.1484 - loss: 46166.1953
# Epoch 92/1000
# 1/1 - 0s - gaussian_likelihood: 23377.6992 - loss: 23377.7461
# Epoch 93/1000
# 1/1 - 0s - gaussian_likelihood: 110476.9219 - loss: 110476.9688
# Epoch 94/1000
# 1/1 - 0s - gaussian_likelihood: 27862.3242 - loss: 27862.3730
# Epoch 95/1000
# 1/1 - 0s - gaussian_likelihood: 102597.2266 - loss: 102597.2734
# Epoch 96/1000
# 1/1 - 0s - gaussian_likelihood: 265975.0312 - loss: 265975.0938
# Epoch 97/1000
# 1/1 - 0s - gaussian_likelihood: 105830.8203 - loss: 105830.8750
# Epoch 98/1000
# 1/1 - 0s - gaussian_likelihood: 73162.0469 - loss: 73162.1016
# Epoch 99/1000
# 1/1 - 0s - gaussian_likelihood: 72137.0234 - loss: 72137.0781
# Epoch 100/1000
# 1/1 - 0s - gaussian_likelihood: 293451.9375 - loss: 293452.0000
# Epoch 101/1000
# 1/1 - 0s - gaussian_likelihood: 81974.7500 - loss: 81974.8047
# Epoch 102/1000
# 1/1 - 0s - gaussian_likelihood: 148315.3906 - loss: 148315.4531
# Epoch 103/1000
# 1/1 - 0s - gaussian_likelihood: 234918.4375 - loss: 234918.5000
# Epoch 104/1000
# 1/1 - 0s - gaussian_likelihood: 30796.1523 - loss: 30796.2109
# Epoch 105/1000
# 1/1 - 0s - gaussian_likelihood: 42337.3047 - loss: 42337.3633
# Epoch 106/1000
# 1/1 - 0s - gaussian_likelihood: 141949.3438 - loss: 141949.4062
# Epoch 107/1000
# 1/1 - 0s - gaussian_likelihood: 91200.2344 - loss: 91200.2969
# Epoch 108/1000
# 1/1 - 0s - gaussian_likelihood: 56463.0781 - loss: 56463.1406
# Epoch 109/1000
# 1/1 - 0s - gaussian_likelihood: 105260.6797 - loss: 105260.7422
# Epoch 110/1000
# 1/1 - 0s - gaussian_likelihood: 127264.3047 - loss: 127264.3672
# Epoch 111/1000
# 1/1 - 0s - gaussian_likelihood: 60072.8203 - loss: 60072.8867
# Epoch 112/1000
# 1/1 - 0s - gaussian_likelihood: 100722.1719 - loss: 100722.2344
# Epoch 113/1000
# 1/1 - 0s - gaussian_likelihood: 37815.9297 - loss: 37815.9961
# Epoch 114/1000
# 1/1 - 0s - gaussian_likelihood: 6621.7319 - loss: 6621.7998
# Epoch 115/1000
# 1/1 - 0s - gaussian_likelihood: 34709.1055 - loss: 34709.1719
# Epoch 116/1000
# 1/1 - 0s - gaussian_likelihood: 18389.2500 - loss: 18389.3184
# Epoch 117/1000
# 1/1 - 0s - gaussian_likelihood: 538882.1250 - loss: 538882.1875
# Epoch 118/1000
# 1/1 - 0s - gaussian_likelihood: 39397.9297 - loss: 39398.0039
# Epoch 119/1000
# 1/1 - 0s - gaussian_likelihood: 21967.8984 - loss: 21967.9727
# Epoch 120/1000
# 1/1 - 0s - gaussian_likelihood: 39326.0898 - loss: 39326.1641
# Epoch 121/1000
# 1/1 - 0s - gaussian_likelihood: 176036.9062 - loss: 176036.9844
# Epoch 122/1000
# 1/1 - 0s - gaussian_likelihood: 59198.7930 - loss: 59198.8711
# Epoch 123/1000
# 1/1 - 0s - gaussian_likelihood: 392949.9688 - loss: 392950.0312
# Epoch 124/1000
# 1/1 - 0s - gaussian_likelihood: 8226.5254 - loss: 8226.6055
# Epoch 125/1000
# 1/1 - 0s - gaussian_likelihood: 129237.5781 - loss: 129237.6562
# Epoch 126/1000
# 1/1 - 0s - gaussian_likelihood: 58346.4219 - loss: 58346.5039
# Epoch 127/1000
# 1/1 - 0s - gaussian_likelihood: 80648.7500 - loss: 80648.8359
# Epoch 128/1000
# 1/1 - 0s - gaussian_likelihood: 753.2327 - loss: 753.3162
# Epoch 129/1000
# 1/1 - 0s - gaussian_likelihood: 26932.3516 - loss: 26932.4355
# Epoch 130/1000
# 1/1 - 0s - gaussian_likelihood: 97672.6016 - loss: 97672.6875
# Epoch 131/1000
# 1/1 - 0s - gaussian_likelihood: 207758.3438 - loss: 207758.4219
# Epoch 132/1000
# 1/1 - 0s - gaussian_likelihood: 116621.5938 - loss: 116621.6797
# Epoch 133/1000
# 1/1 - 0s - gaussian_likelihood: 198543.0000 - loss: 198543.0938
# Epoch 134/1000
# 1/1 - 0s - gaussian_likelihood: 25736.4492 - loss: 25736.5410
# Epoch 135/1000
# 1/1 - 0s - gaussian_likelihood: 11807.4131 - loss: 11807.5049
# Epoch 136/1000
# 1/1 - 0s - gaussian_likelihood: 39690.3516 - loss: 39690.4453
# Epoch 137/1000
# 1/1 - 0s - gaussian_likelihood: 179439.4062 - loss: 179439.5000
# Epoch 138/1000
# 1/1 - 0s - gaussian_likelihood: 54933.3594 - loss: 54933.4531
# Epoch 139/1000
# 1/1 - 0s - gaussian_likelihood: 92051.9531 - loss: 92052.0469
# Epoch 140/1000
# 1/1 - 0s - gaussian_likelihood: 94505.6641 - loss: 94505.7578
# Epoch 141/1000
# 1/1 - 0s - gaussian_likelihood: 58202.5938 - loss: 58202.6914
# Epoch 142/1000
# 1/1 - 0s - gaussian_likelihood: 36590.1172 - loss: 36590.2148
# Epoch 143/1000
# 1/1 - 0s - gaussian_likelihood: 16805.1367 - loss: 16805.2363
# Epoch 144/1000
# 1/1 - 0s - gaussian_likelihood: 218062.5625 - loss: 218062.6562
# Epoch 145/1000
# 1/1 - 0s - gaussian_likelihood: 81283.9375 - loss: 81284.0391
# Epoch 146/1000
# 1/1 - 0s - gaussian_likelihood: 106409.2031 - loss: 106409.3047
# Epoch 147/1000
# 1/1 - 0s - gaussian_likelihood: 24731.8379 - loss: 24731.9414
# Epoch 148/1000
# 1/1 - 0s - gaussian_likelihood: 277402.0938 - loss: 277402.1875
# Epoch 149/1000
# 1/1 - 0s - gaussian_likelihood: 17414.2656 - loss: 17414.3711
# Epoch 150/1000
# 1/1 - 0s - gaussian_likelihood: 124800.0156 - loss: 124800.1250
# Epoch 151/1000
# 1/1 - 0s - gaussian_likelihood: 74284.7656 - loss: 74284.8750
# Epoch 152/1000
# 1/1 - 0s - gaussian_likelihood: 31885.2500 - loss: 31885.3594
# Epoch 153/1000
# 1/1 - 0s - gaussian_likelihood: 31325.9746 - loss: 31326.0840
# Epoch 154/1000
# 1/1 - 0s - gaussian_likelihood: 199428.3906 - loss: 199428.5000
# Epoch 155/1000
# 1/1 - 0s - gaussian_likelihood: 25912.6797 - loss: 25912.7930
# Epoch 156/1000
# 1/1 - 0s - gaussian_likelihood: 127783.3125 - loss: 127783.4297
# Epoch 157/1000
# 1/1 - 0s - gaussian_likelihood: 43037.4531 - loss: 43037.5664
# Epoch 158/1000
# 1/1 - 0s - gaussian_likelihood: 180236.2188 - loss: 180236.3281
# Epoch 159/1000
# 1/1 - 0s - gaussian_likelihood: 57897.0586 - loss: 57897.1758
# Epoch 160/1000
# 1/1 - 0s - gaussian_likelihood: 15493.8125 - loss: 15493.9307
# Epoch 161/1000
# 1/1 - 0s - gaussian_likelihood: 11670.2207 - loss: 11670.3398
# Epoch 162/1000
# 1/1 - 0s - gaussian_likelihood: 31285.0234 - loss: 31285.1426
# Epoch 163/1000
# 1/1 - 0s - gaussian_likelihood: 70020.1016 - loss: 70020.2188
# Epoch 164/1000
# 1/1 - 0s - gaussian_likelihood: 104634.9844 - loss: 104635.1094
# Epoch 165/1000
# 1/1 - 0s - gaussian_likelihood: 75335.3281 - loss: 75335.4531
# Epoch 166/1000
# 1/1 - 0s - gaussian_likelihood: 26377.8438 - loss: 26377.9688
# Epoch 167/1000
# 1/1 - 0s - gaussian_likelihood: 24849.1992 - loss: 24849.3242
# Epoch 168/1000
# 1/1 - 0s - gaussian_likelihood: 61888.8516 - loss: 61888.9766
# Epoch 169/1000
# 1/1 - 0s - gaussian_likelihood: 75886.1094 - loss: 75886.2344
# Epoch 170/1000
# 1/1 - 0s - gaussian_likelihood: 146077.2188 - loss: 146077.3438
# Epoch 171/1000
# 1/1 - 0s - gaussian_likelihood: 78421.2500 - loss: 78421.3750
# Epoch 172/1000
# 1/1 - 0s - gaussian_likelihood: 4449.5205 - loss: 4449.6499
# Epoch 173/1000
# 1/1 - 0s - gaussian_likelihood: 25436.1680 - loss: 25436.2988
# Epoch 174/1000
# 1/1 - 0s - gaussian_likelihood: 37050.5625 - loss: 37050.6914
# Epoch 175/1000
# 1/1 - 0s - gaussian_likelihood: 235188.7344 - loss: 235188.8594
# Epoch 176/1000
# 1/1 - 0s - gaussian_likelihood: 91982.1094 - loss: 91982.2422
# Epoch 177/1000
# 1/1 - 0s - gaussian_likelihood: 54473.5625 - loss: 54473.6953
# Epoch 178/1000
# 1/1 - 0s - gaussian_likelihood: 154891.3438 - loss: 154891.4844
# Epoch 179/1000
# 1/1 - 0s - gaussian_likelihood: 43216.5859 - loss: 43216.7227
# Epoch 180/1000
# 1/1 - 0s - gaussian_likelihood: 104855.1875 - loss: 104855.3281
# Epoch 181/1000
# 1/1 - 0s - gaussian_likelihood: 15372.7207 - loss: 15372.8613
# Epoch 182/1000
# 1/1 - 0s - gaussian_likelihood: 135180.7188 - loss: 135180.8594
# Epoch 183/1000
# 1/1 - 0s - gaussian_likelihood: 106170.1719 - loss: 106170.3125
# Epoch 184/1000
# 1/1 - 0s - gaussian_likelihood: 44447.4531 - loss: 44447.5977
# Epoch 185/1000
# 1/1 - 0s - gaussian_likelihood: 134524.4531 - loss: 134524.5938
# Epoch 186/1000
# 1/1 - 0s - gaussian_likelihood: 29684.8711 - loss: 29685.0195
# Epoch 187/1000
# 1/1 - 0s - gaussian_likelihood: 90827.9922 - loss: 90828.1406
# Epoch 188/1000
# 1/1 - 0s - gaussian_likelihood: 89720.3281 - loss: 89720.4766
# Epoch 189/1000
# 1/1 - 0s - gaussian_likelihood: 32433.0742 - loss: 32433.2266
# Epoch 190/1000
# 1/1 - 0s - gaussian_likelihood: 70301.5312 - loss: 70301.6875
# Epoch 191/1000
# 1/1 - 0s - gaussian_likelihood: 38196.6680 - loss: 38196.8203
# Epoch 192/1000
# 1/1 - 0s - gaussian_likelihood: 104175.5000 - loss: 104175.6562
# Epoch 193/1000
# 1/1 - 0s - gaussian_likelihood: 5222.6846 - loss: 5222.8408
# Epoch 194/1000
# 1/1 - 0s - gaussian_likelihood: 45723.1836 - loss: 45723.3398
# Epoch 195/1000
# 1/1 - 0s - gaussian_likelihood: 10558.8027 - loss: 10558.9609
# Epoch 196/1000
# 1/1 - 0s - gaussian_likelihood: 75290.1250 - loss: 75290.2812
# Epoch 197/1000
# 1/1 - 0s - gaussian_likelihood: 30840.6875 - loss: 30840.8477
# Epoch 198/1000
# 1/1 - 0s - gaussian_likelihood: 76680.3984 - loss: 76680.5625
# Epoch 199/1000
# 1/1 - 0s - gaussian_likelihood: 275467.9062 - loss: 275468.0625
# Epoch 200/1000
# 1/1 - 0s - gaussian_likelihood: 54110.6992 - loss: 54110.8633
# Epoch 201/1000
# 1/1 - 0s - gaussian_likelihood: 98944.3594 - loss: 98944.5234
# Epoch 202/1000
# 1/1 - 0s - gaussian_likelihood: 39843.2109 - loss: 39843.3789
# Epoch 203/1000
# 1/1 - 0s - gaussian_likelihood: 74374.9531 - loss: 74375.1250
# Epoch 204/1000
# 1/1 - 0s - gaussian_likelihood: 152375.4688 - loss: 152375.6406
# Epoch 205/1000
# 1/1 - 0s - gaussian_likelihood: 24988.3242 - loss: 24988.4980
# Epoch 206/1000
# 1/1 - 0s - gaussian_likelihood: 204185.1094 - loss: 204185.2812
# Epoch 207/1000
# 1/1 - 0s - gaussian_likelihood: 126584.0625 - loss: 126584.2422
# Epoch 208/1000
# 1/1 - 0s - gaussian_likelihood: 258722.0625 - loss: 258722.2344
# Epoch 209/1000
# 1/1 - 0s - gaussian_likelihood: 25722.8789 - loss: 25723.0625
# Epoch 210/1000
# 1/1 - 0s - gaussian_likelihood: 76830.3750 - loss: 76830.5625
# Epoch 211/1000
# 1/1 - 0s - gaussian_likelihood: 44654.8477 - loss: 44655.0352
# Epoch 212/1000
# 1/1 - 0s - gaussian_likelihood: 98608.5469 - loss: 98608.7344
# Epoch 213/1000
# 1/1 - 0s - gaussian_likelihood: 20313.0664 - loss: 20313.2539
# Epoch 214/1000
# 1/1 - 0s - gaussian_likelihood: 311497.0625 - loss: 311497.2500
# Epoch 215/1000
# 1/1 - 0s - gaussian_likelihood: 363492.0312 - loss: 363492.2188
# Epoch 216/1000
# 1/1 - 0s - gaussian_likelihood: 158788.5625 - loss: 158788.7656
# Epoch 217/1000
# 1/1 - 0s - gaussian_likelihood: 32561.3574 - loss: 32561.5586
# Epoch 218/1000
# 1/1 - 0s - gaussian_likelihood: 146963.1562 - loss: 146963.3594
# Epoch 219/1000
# 1/1 - 0s - gaussian_likelihood: 17147.3867 - loss: 17147.5918
# Epoch 220/1000
# 1/1 - 0s - gaussian_likelihood: 67573.4453 - loss: 67573.6484
# Epoch 221/1000
# 1/1 - 0s - gaussian_likelihood: 104260.5312 - loss: 104260.7422
# Epoch 222/1000
# 1/1 - 0s - gaussian_likelihood: 59008.9453 - loss: 59009.1562
# Epoch 223/1000
# 1/1 - 0s - gaussian_likelihood: 103332.3594 - loss: 103332.5703
# Epoch 224/1000
# 1/1 - 0s - gaussian_likelihood: 34148.2266 - loss: 34148.4414
# Epoch 225/1000
# 1/1 - 0s - gaussian_likelihood: 24886.7344 - loss: 24886.9512
# Epoch 226/1000
# 1/1 - 0s - gaussian_likelihood: 264377.3438 - loss: 264377.5625
# Epoch 227/1000
# 1/1 - 0s - gaussian_likelihood: 91409.0312 - loss: 91409.2500
# Epoch 228/1000
# 1/1 - 0s - gaussian_likelihood: 46934.0898 - loss: 46934.3125
# Epoch 229/1000
# 1/1 - 0s - gaussian_likelihood: 69257.3281 - loss: 69257.5547
# Epoch 230/1000
# 1/1 - 0s - gaussian_likelihood: 74176.9375 - loss: 74177.1641
# Epoch 231/1000
# 1/1 - 0s - gaussian_likelihood: 186419.9688 - loss: 186420.2031
# Epoch 232/1000
# 1/1 - 0s - gaussian_likelihood: 97060.4531 - loss: 97060.6797
# Epoch 233/1000
# 1/1 - 0s - gaussian_likelihood: 60101.2734 - loss: 60101.5078
# Epoch 234/1000
# 1/1 - 0s - gaussian_likelihood: 89532.0625 - loss: 89532.2969
# Epoch 235/1000
# 1/1 - 0s - gaussian_likelihood: 6899.9961 - loss: 6900.2324
# Epoch 236/1000
# 1/1 - 0s - gaussian_likelihood: 183679.0938 - loss: 183679.3281
# Epoch 237/1000
# 1/1 - 0s - gaussian_likelihood: 101655.3906 - loss: 101655.6328
# Epoch 238/1000
# 1/1 - 0s - gaussian_likelihood: 46936.2500 - loss: 46936.4922
# Epoch 239/1000
# 1/1 - 0s - gaussian_likelihood: 51238.2266 - loss: 51238.4688
# Epoch 240/1000
# 1/1 - 0s - gaussian_likelihood: 136462.2500 - loss: 136462.5000
# Epoch 241/1000
# 1/1 - 0s - gaussian_likelihood: 166625.5312 - loss: 166625.7812
# Epoch 242/1000
# 1/1 - 0s - gaussian_likelihood: 65908.5000 - loss: 65908.7500
# Epoch 243/1000
# 1/1 - 0s - gaussian_likelihood: 21620.1074 - loss: 21620.3613
# Epoch 244/1000
# 1/1 - 0s - gaussian_likelihood: 374519.4062 - loss: 374519.6562
# Epoch 245/1000
# 1/1 - 0s - gaussian_likelihood: 82956.9531 - loss: 82957.2109
# Epoch 246/1000
# 1/1 - 0s - gaussian_likelihood: 90755.7734 - loss: 90756.0391
# Epoch 247/1000
# 1/1 - 0s - gaussian_likelihood: 41278.1914 - loss: 41278.4570
# Epoch 248/1000
# 1/1 - 0s - gaussian_likelihood: 104776.0625 - loss: 104776.3281
# Epoch 249/1000
# 1/1 - 0s - gaussian_likelihood: 73465.7344 - loss: 73466.0000
# Epoch 250/1000
# 1/1 - 0s - gaussian_likelihood: 90676.2891 - loss: 90676.5547
# Epoch 251/1000
# 1/1 - 0s - gaussian_likelihood: 21241.3281 - loss: 21241.6016
# Epoch 252/1000
# 1/1 - 0s - gaussian_likelihood: 52307.5078 - loss: 52307.7812
# Epoch 253/1000
# 1/1 - 0s - gaussian_likelihood: 18907.1367 - loss: 18907.4121
# Epoch 254/1000
# 1/1 - 0s - gaussian_likelihood: 132574.5625 - loss: 132574.8438
# Epoch 255/1000
# 1/1 - 0s - gaussian_likelihood: 27993.4609 - loss: 27993.7422
# Epoch 256/1000
# 1/1 - 0s - gaussian_likelihood: 354475.0000 - loss: 354475.2812
# Epoch 257/1000
# 1/1 - 0s - gaussian_likelihood: 49950.2891 - loss: 49950.5781
# Epoch 258/1000
# 1/1 - 0s - gaussian_likelihood: 34653.1133 - loss: 34653.4023
# Epoch 259/1000
# 1/1 - 0s - gaussian_likelihood: 48120.1094 - loss: 48120.4023
# Epoch 260/1000
# 1/1 - 0s - gaussian_likelihood: 801.3031 - loss: 801.5974
# Epoch 261/1000
# 1/1 - 0s - gaussian_likelihood: 77750.3281 - loss: 77750.6250
# Epoch 262/1000
# 1/1 - 0s - gaussian_likelihood: 92407.2344 - loss: 92407.5312
# Epoch 263/1000
# 1/1 - 0s - gaussian_likelihood: 45057.7266 - loss: 45058.0273
# Epoch 264/1000
# 1/1 - 0s - gaussian_likelihood: 33600.7344 - loss: 33601.0352
# Epoch 265/1000
# 1/1 - 0s - gaussian_likelihood: 13897.7949 - loss: 13898.0986
# Epoch 266/1000
# 1/1 - 0s - gaussian_likelihood: 112577.2031 - loss: 112577.5078
# Epoch 267/1000
# 1/1 - 0s - gaussian_likelihood: 143190.0312 - loss: 143190.3438
# Epoch 268/1000
# 1/1 - 0s - gaussian_likelihood: 3297.1230 - loss: 3297.4355
# Epoch 269/1000
# 1/1 - 0s - gaussian_likelihood: 80350.6406 - loss: 80350.9531
# Epoch 270/1000
# 1/1 - 0s - gaussian_likelihood: 44986.2539 - loss: 44986.5703
# Epoch 271/1000
# 1/1 - 0s - gaussian_likelihood: 15767.1406 - loss: 15767.4590
# Epoch 272/1000
# 1/1 - 0s - gaussian_likelihood: 48762.4961 - loss: 48762.8164
# Epoch 273/1000
# 1/1 - 0s - gaussian_likelihood: 8296.2734 - loss: 8296.5947
# Epoch 274/1000
# 1/1 - 0s - gaussian_likelihood: 201176.1094 - loss: 201176.4375
# Epoch 275/1000
# 1/1 - 0s - gaussian_likelihood: 25843.5020 - loss: 25843.8281
# Epoch 276/1000
# 1/1 - 0s - gaussian_likelihood: 24190.8613 - loss: 24191.1895
# Epoch 277/1000
# 1/1 - 0s - gaussian_likelihood: 32637.9492 - loss: 32638.2793
# Epoch 278/1000
# 1/1 - 0s - gaussian_likelihood: 18343.2422 - loss: 18343.5742
# Epoch 279/1000
# 1/1 - 0s - gaussian_likelihood: 65130.9883 - loss: 65131.3203
# Epoch 280/1000
# 1/1 - 0s - gaussian_likelihood: 8956.0400 - loss: 8956.3750
# Epoch 281/1000
# 1/1 - 0s - gaussian_likelihood: 41710.4766 - loss: 41710.8125
# Epoch 282/1000
# 1/1 - 0s - gaussian_likelihood: 12039.7188 - loss: 12040.0566
# Epoch 283/1000
# 1/1 - 0s - gaussian_likelihood: 111522.2734 - loss: 111522.6094
# Epoch 284/1000
# 1/1 - 0s - gaussian_likelihood: 272618.9375 - loss: 272619.2812
# Epoch 285/1000
# 1/1 - 0s - gaussian_likelihood: 54538.0703 - loss: 54538.4180
# Epoch 286/1000
# 1/1 - 0s - gaussian_likelihood: 15812.8105 - loss: 15813.1602
# Epoch 287/1000
# 1/1 - 0s - gaussian_likelihood: 39658.7031 - loss: 39659.0547
# Epoch 288/1000
# 1/1 - 0s - gaussian_likelihood: 114102.8438 - loss: 114103.1953
# Epoch 289/1000
# 1/1 - 0s - gaussian_likelihood: 23246.1562 - loss: 23246.5117
# Epoch 290/1000
# 1/1 - 0s - gaussian_likelihood: 175620.2500 - loss: 175620.6094
# Epoch 291/1000
# 1/1 - 0s - gaussian_likelihood: 25014.9219 - loss: 25015.2812
# Epoch 292/1000
# 1/1 - 0s - gaussian_likelihood: 32253.3809 - loss: 32253.7422
# Epoch 293/1000
# 1/1 - 0s - gaussian_likelihood: 56319.3672 - loss: 56319.7305
# Epoch 294/1000
# 1/1 - 0s - gaussian_likelihood: 122347.4609 - loss: 122347.8281
# Epoch 295/1000
# 1/1 - 0s - gaussian_likelihood: 165080.9375 - loss: 165081.3125
# Epoch 296/1000
# 1/1 - 0s - gaussian_likelihood: 81909.7266 - loss: 81910.1016
# Epoch 297/1000
# 1/1 - 0s - gaussian_likelihood: 22077.2539 - loss: 22077.6309
# Epoch 298/1000
# 1/1 - 0s - gaussian_likelihood: 40913.0391 - loss: 40913.4180
# Epoch 299/1000
# 1/1 - 0s - gaussian_likelihood: 33365.6484 - loss: 33366.0273
# Epoch 300/1000
# 1/1 - 0s - gaussian_likelihood: 33658.9297 - loss: 33659.3125
# Epoch 301/1000
# 1/1 - 0s - gaussian_likelihood: 102922.7344 - loss: 102923.1172
# Epoch 302/1000
# 1/1 - 0s - gaussian_likelihood: 14455.1562 - loss: 14455.5420
# Epoch 303/1000
# 1/1 - 0s - gaussian_likelihood: 133529.7188 - loss: 133530.1094
# Epoch 304/1000
# 1/1 - 0s - gaussian_likelihood: 29601.7051 - loss: 29602.0957
# Epoch 305/1000
# 1/1 - 0s - gaussian_likelihood: 44045.7734 - loss: 44046.1680
# Epoch 306/1000
# 1/1 - 0s - gaussian_likelihood: 49652.4883 - loss: 49652.8828
# Epoch 307/1000
# 1/1 - 0s - gaussian_likelihood: 46080.5391 - loss: 46080.9375
# Epoch 308/1000
# 1/1 - 0s - gaussian_likelihood: 177984.0938 - loss: 177984.4844
# Epoch 309/1000
# 1/1 - 0s - gaussian_likelihood: 58406.2109 - loss: 58406.6133
# Epoch 310/1000
# 1/1 - 0s - gaussian_likelihood: 422343.5000 - loss: 422343.9062
# Epoch 311/1000
# 1/1 - 0s - gaussian_likelihood: 57984.8438 - loss: 57985.2539
# Epoch 312/1000
# 1/1 - 0s - gaussian_likelihood: 114865.6094 - loss: 114866.0234
# Epoch 313/1000
# 1/1 - 0s - gaussian_likelihood: 58518.2227 - loss: 58518.6367
# Epoch 314/1000
# 1/1 - 0s - gaussian_likelihood: 7954.7656 - loss: 7955.1846
# Epoch 315/1000
# 1/1 - 0s - gaussian_likelihood: 37112.3594 - loss: 37112.7812
# Epoch 316/1000
# 1/1 - 0s - gaussian_likelihood: 120444.6875 - loss: 120445.1094
# Epoch 317/1000
# 1/1 - 0s - gaussian_likelihood: 71771.9688 - loss: 71772.3984
# Epoch 318/1000
# 1/1 - 0s - gaussian_likelihood: 120100.2031 - loss: 120100.6328
# Epoch 319/1000
# 1/1 - 0s - gaussian_likelihood: 177203.6875 - loss: 177204.1250
# Epoch 320/1000
# 1/1 - 0s - gaussian_likelihood: 41650.0977 - loss: 41650.5312
# Epoch 321/1000
# 1/1 - 0s - gaussian_likelihood: 57227.1406 - loss: 57227.5781
# Epoch 322/1000
# 1/1 - 0s - gaussian_likelihood: 4268.8271 - loss: 4269.2671
# Epoch 323/1000
# 1/1 - 0s - gaussian_likelihood: 60556.6719 - loss: 60557.1133
# Epoch 324/1000
# 1/1 - 0s - gaussian_likelihood: 42335.5391 - loss: 42335.9844
# Epoch 325/1000
# 1/1 - 0s - gaussian_likelihood: 80175.0781 - loss: 80175.5234
# Epoch 326/1000
# 1/1 - 0s - gaussian_likelihood: 13659.9961 - loss: 13660.4453
# Epoch 327/1000
# 1/1 - 0s - gaussian_likelihood: 215998.2188 - loss: 215998.6719
# Epoch 328/1000
# 1/1 - 0s - gaussian_likelihood: 7581.5742 - loss: 7582.0337
# Epoch 329/1000
# 1/1 - 0s - gaussian_likelihood: 44377.0312 - loss: 44377.4922
# Epoch 330/1000
# 1/1 - 0s - gaussian_likelihood: 147980.0781 - loss: 147980.5469
# Epoch 331/1000
# 1/1 - 0s - gaussian_likelihood: 156526.6562 - loss: 156527.1250
# Epoch 332/1000
# 1/1 - 0s - gaussian_likelihood: 63767.9883 - loss: 63768.4609
# Epoch 333/1000
# 1/1 - 0s - gaussian_likelihood: 9843.6387 - loss: 9844.1152
# Epoch 334/1000
# 1/1 - 0s - gaussian_likelihood: 21806.4805 - loss: 21806.9590
# Epoch 335/1000
# 1/1 - 0s - gaussian_likelihood: 63334.8906 - loss: 63335.3711
# Epoch 336/1000
# 1/1 - 0s - gaussian_likelihood: 8465.4297 - loss: 8465.9131
# Epoch 337/1000
# 1/1 - 0s - gaussian_likelihood: 48844.4688 - loss: 48844.9531
# Epoch 338/1000
# 1/1 - 0s - gaussian_likelihood: 41603.4648 - loss: 41603.9531
# Epoch 339/1000
# 1/1 - 0s - gaussian_likelihood: 47386.4453 - loss: 47386.9336
# Epoch 340/1000
# 1/1 - 0s - gaussian_likelihood: 92754.8750 - loss: 92755.3672
# Epoch 341/1000
# 1/1 - 0s - gaussian_likelihood: 2766.8787 - loss: 2767.3755
# Epoch 342/1000
# 1/1 - 0s - gaussian_likelihood: 179202.3906 - loss: 179202.8906
# Epoch 343/1000
# 1/1 - 0s - gaussian_likelihood: 48019.8281 - loss: 48020.3320
# Epoch 344/1000
# 1/1 - 0s - gaussian_likelihood: 32493.9512 - loss: 32494.4570
# Epoch 345/1000
# 1/1 - 0s - gaussian_likelihood: 17510.9766 - loss: 17511.4863
# Epoch 346/1000
# 1/1 - 0s - gaussian_likelihood: 12070.9658 - loss: 12071.4766
# Epoch 347/1000
# 1/1 - 0s - gaussian_likelihood: 33260.5312 - loss: 33261.0430
# Epoch 348/1000
# 1/1 - 0s - gaussian_likelihood: 13863.4082 - loss: 13863.9229
# Epoch 349/1000
# 1/1 - 0s - gaussian_likelihood: 15976.5371 - loss: 15977.0527
# Epoch 350/1000
# 1/1 - 0s - gaussian_likelihood: 47036.0234 - loss: 47036.5391
# Epoch 351/1000
# 1/1 - 0s - gaussian_likelihood: 14548.1992 - loss: 14548.7178
# Epoch 352/1000
# 1/1 - 0s - gaussian_likelihood: 22647.2520 - loss: 22647.7715
# Epoch 353/1000
# 1/1 - 0s - gaussian_likelihood: 42397.4062 - loss: 42397.9258
# Epoch 354/1000
# 1/1 - 0s - gaussian_likelihood: 19861.3047 - loss: 19861.8281
# Epoch 355/1000
# 1/1 - 0s - gaussian_likelihood: 37538.4219 - loss: 37538.9453
# Epoch 356/1000
# 1/1 - 0s - gaussian_likelihood: 25146.4316 - loss: 25146.9590
# Epoch 357/1000
# 1/1 - 0s - gaussian_likelihood: 24122.8438 - loss: 24123.3711
# Epoch 358/1000
# 1/1 - 0s - gaussian_likelihood: 24009.1777 - loss: 24009.7070
# Epoch 359/1000
# 1/1 - 0s - gaussian_likelihood: 59993.1484 - loss: 59993.6797
# Epoch 360/1000
# 1/1 - 0s - gaussian_likelihood: 80184.1484 - loss: 80184.6797
# Epoch 361/1000
# 1/1 - 0s - gaussian_likelihood: 116277.9688 - loss: 116278.5078
# Epoch 362/1000
# 1/1 - 0s - gaussian_likelihood: 32406.7383 - loss: 32407.2773
# Epoch 363/1000
# 1/1 - 0s - gaussian_likelihood: 165390.3438 - loss: 165390.8906
# Epoch 364/1000
# 1/1 - 0s - gaussian_likelihood: 18919.7070 - loss: 18920.2539
# Epoch 365/1000
# 1/1 - 0s - gaussian_likelihood: 56854.2891 - loss: 56854.8398
# Epoch 366/1000
# 1/1 - 0s - gaussian_likelihood: 4205.6274 - loss: 4206.1797
# Epoch 367/1000
# 1/1 - 0s - gaussian_likelihood: 11639.2549 - loss: 11639.8086
# Epoch 368/1000
# 1/1 - 0s - gaussian_likelihood: 42622.2891 - loss: 42622.8438
# Epoch 369/1000
# 1/1 - 0s - gaussian_likelihood: 116413.1250 - loss: 116413.6797
# Epoch 370/1000
# 1/1 - 0s - gaussian_likelihood: 6248.1069 - loss: 6248.6675
# Epoch 371/1000
# 1/1 - 0s - gaussian_likelihood: 125927.5625 - loss: 125928.1250
# Epoch 372/1000
# 1/1 - 0s - gaussian_likelihood: 25098.6836 - loss: 25099.2500
# Epoch 373/1000
# 1/1 - 0s - gaussian_likelihood: 9182.0605 - loss: 9182.6299
# Epoch 374/1000
# 1/1 - 0s - gaussian_likelihood: 6584.2139 - loss: 6584.7842
# Epoch 375/1000
# 1/1 - 0s - gaussian_likelihood: 95735.7656 - loss: 95736.3359
# Epoch 376/1000
# 1/1 - 0s - gaussian_likelihood: 72631.5000 - loss: 72632.0703
# Epoch 377/1000
# 1/1 - 0s - gaussian_likelihood: 85785.2812 - loss: 85785.8594
# Epoch 378/1000
# 1/1 - 0s - gaussian_likelihood: 63654.1172 - loss: 63654.6992
# Epoch 379/1000
# 1/1 - 0s - gaussian_likelihood: 21894.9375 - loss: 21895.5195
# Epoch 380/1000
# 1/1 - 0s - gaussian_likelihood: 4576.1172 - loss: 4576.7021
# Epoch 381/1000
# 1/1 - 0s - gaussian_likelihood: 27496.5469 - loss: 27497.1328
# Epoch 382/1000
# 1/1 - 0s - gaussian_likelihood: 62336.5195 - loss: 62337.1055
# Epoch 383/1000
# 1/1 - 0s - gaussian_likelihood: 79221.8047 - loss: 79222.3984
# Epoch 384/1000
# 1/1 - 0s - gaussian_likelihood: 89250.1484 - loss: 89250.7422
# Epoch 385/1000
# 1/1 - 0s - gaussian_likelihood: 92898.7812 - loss: 92899.3750
# Epoch 386/1000
# 1/1 - 0s - gaussian_likelihood: 107051.4844 - loss: 107052.0859
# Epoch 387/1000
# 1/1 - 0s - gaussian_likelihood: 22554.3047 - loss: 22554.9102
# Epoch 388/1000
# 1/1 - 0s - gaussian_likelihood: 103733.3516 - loss: 103733.9609
# Epoch 389/1000
# 1/1 - 0s - gaussian_likelihood: 27555.6641 - loss: 27556.2773
# Epoch 390/1000
# 1/1 - 0s - gaussian_likelihood: 86323.4453 - loss: 86324.0625
# Epoch 391/1000
# 1/1 - 0s - gaussian_likelihood: 126149.2969 - loss: 126149.9141
# Epoch 392/1000
# 1/1 - 0s - gaussian_likelihood: 22265.9570 - loss: 22266.5820
# Epoch 393/1000
# 1/1 - 0s - gaussian_likelihood: 25714.9492 - loss: 25715.5762
# Epoch 394/1000
# 1/1 - 0s - gaussian_likelihood: 68488.1016 - loss: 68488.7344
# Epoch 395/1000
# 1/1 - 0s - gaussian_likelihood: 14824.9512 - loss: 14825.5850
# Epoch 396/1000
# 1/1 - 0s - gaussian_likelihood: 145113.5781 - loss: 145114.2188
# Epoch 397/1000
# 1/1 - 0s - gaussian_likelihood: 16760.4199 - loss: 16761.0625
# Epoch 398/1000
# 1/1 - 0s - gaussian_likelihood: 68350.5469 - loss: 68351.1953
# Epoch 399/1000
# 1/1 - 0s - gaussian_likelihood: 16410.3652 - loss: 16411.0156
# Epoch 400/1000
# 1/1 - 0s - gaussian_likelihood: 7846.8184 - loss: 7847.4717
# Epoch 401/1000
# 1/1 - 0s - gaussian_likelihood: 74469.4844 - loss: 74470.1406
# Epoch 402/1000
# 1/1 - 0s - gaussian_likelihood: 17359.6934 - loss: 17360.3516
# Epoch 403/1000
# 1/1 - 0s - gaussian_likelihood: 40864.8945 - loss: 40865.5547
# Epoch 404/1000
# 1/1 - 0s - gaussian_likelihood: 155269.0625 - loss: 155269.7344
# Epoch 405/1000
# 1/1 - 0s - gaussian_likelihood: 93184.5625 - loss: 93185.2344
# Epoch 406/1000
# 1/1 - 0s - gaussian_likelihood: 138317.9375 - loss: 138318.6094
# Epoch 407/1000
# 1/1 - 0s - gaussian_likelihood: 78383.8438 - loss: 78384.5312
# Epoch 408/1000
# 1/1 - 0s - gaussian_likelihood: 14295.1123 - loss: 14295.8018
# Epoch 409/1000
# 1/1 - 0s - gaussian_likelihood: 49215.5742 - loss: 49216.2656
# Epoch 410/1000
# 1/1 - 0s - gaussian_likelihood: 15086.5273 - loss: 15087.2236
# Epoch 411/1000
# 1/1 - 0s - gaussian_likelihood: 135639.2500 - loss: 135639.9531
# Epoch 412/1000
# 1/1 - 0s - gaussian_likelihood: 19048.1914 - loss: 19048.8945
# Epoch 413/1000
# 1/1 - 0s - gaussian_likelihood: 85095.1250 - loss: 85095.8281
# Epoch 414/1000
# 1/1 - 0s - gaussian_likelihood: 3030.3335 - loss: 3031.0452
# Epoch 415/1000
# 1/1 - 0s - gaussian_likelihood: 8709.1191 - loss: 8709.8330
# Epoch 416/1000
# 1/1 - 0s - gaussian_likelihood: 16725.8789 - loss: 16726.5938
# Epoch 417/1000
# 1/1 - 0s - gaussian_likelihood: 20940.6758 - loss: 20941.3945
# Epoch 418/1000
# 1/1 - 0s - gaussian_likelihood: 2959.0298 - loss: 2959.7498
# Epoch 419/1000
# 1/1 - 0s - gaussian_likelihood: 11145.4531 - loss: 11146.1748
# Epoch 420/1000
# 1/1 - 0s - gaussian_likelihood: 25830.4531 - loss: 25831.1758
# Epoch 421/1000
# 1/1 - 0s - gaussian_likelihood: 8652.8135 - loss: 8653.5381
# Epoch 422/1000
# 1/1 - 0s - gaussian_likelihood: 86031.4062 - loss: 86032.1328
# Epoch 423/1000
# 1/1 - 0s - gaussian_likelihood: 49893.1094 - loss: 49893.8398
# Epoch 424/1000
# 1/1 - 0s - gaussian_likelihood: 86685.3359 - loss: 86686.0703
# Epoch 425/1000
# 1/1 - 0s - gaussian_likelihood: 8430.2695 - loss: 8431.0059
# Epoch 426/1000
# 1/1 - 0s - gaussian_likelihood: 14037.1895 - loss: 14037.9277
# Epoch 427/1000
# 1/1 - 0s - gaussian_likelihood: 15806.4561 - loss: 15807.1963
# Epoch 428/1000
# 1/1 - 0s - gaussian_likelihood: 142940.7500 - loss: 142941.4844
# Epoch 429/1000
# 1/1 - 0s - gaussian_likelihood: 8454.9336 - loss: 8455.6807
# Epoch 430/1000
# 1/1 - 0s - gaussian_likelihood: 64297.4883 - loss: 64298.2383
# Epoch 431/1000
# 1/1 - 0s - gaussian_likelihood: 75491.2969 - loss: 75492.0469
# Epoch 432/1000
# 1/1 - 0s - gaussian_likelihood: 21279.2383 - loss: 21279.9941
# Epoch 433/1000
# 1/1 - 0s - gaussian_likelihood: 29504.9336 - loss: 29505.6934
# Epoch 434/1000
# 1/1 - 0s - gaussian_likelihood: 12890.2793 - loss: 12891.0410
# Epoch 435/1000
# 1/1 - 0s - gaussian_likelihood: 59568.4688 - loss: 59569.2305
# Epoch 436/1000
# 1/1 - 0s - gaussian_likelihood: 19664.8594 - loss: 19665.6270
# Epoch 437/1000
# 1/1 - 0s - gaussian_likelihood: 41558.7500 - loss: 41559.5195
# Epoch 438/1000
# 1/1 - 0s - gaussian_likelihood: 60908.1758 - loss: 60908.9492
# Epoch 439/1000
# 1/1 - 0s - gaussian_likelihood: 22267.1367 - loss: 22267.9141
# Epoch 440/1000
# 1/1 - 0s - gaussian_likelihood: 67483.2031 - loss: 67483.9844
# Epoch 441/1000
# 1/1 - 0s - gaussian_likelihood: 48321.5352 - loss: 48322.3203
# Epoch 442/1000
# 1/1 - 0s - gaussian_likelihood: 17364.3203 - loss: 17365.1074
# Epoch 443/1000
# 1/1 - 0s - gaussian_likelihood: 33634.4648 - loss: 33635.2539
# Epoch 444/1000
# 1/1 - 0s - gaussian_likelihood: 4049.4409 - loss: 4050.2319
# Epoch 445/1000
# 1/1 - 0s - gaussian_likelihood: 21919.4102 - loss: 21920.2031
# Epoch 446/1000
# 1/1 - 0s - gaussian_likelihood: 11933.9844 - loss: 11934.7793
# Epoch 447/1000
# 1/1 - 0s - gaussian_likelihood: 7770.9214 - loss: 7771.7183
# Epoch 448/1000
# 1/1 - 0s - gaussian_likelihood: 13172.3691 - loss: 13173.1670
# Epoch 449/1000
# 1/1 - 0s - gaussian_likelihood: 104842.0625 - loss: 104842.8594
# Epoch 450/1000
# 1/1 - 0s - gaussian_likelihood: 15240.2832 - loss: 15241.0898
# Epoch 451/1000
# 1/1 - 0s - gaussian_likelihood: 90413.6250 - loss: 90414.4375
# Epoch 452/1000
# 1/1 - 0s - gaussian_likelihood: 11724.3027 - loss: 11725.1162
# Epoch 453/1000
# 1/1 - 0s - gaussian_likelihood: 31311.5352 - loss: 31312.3516
# Epoch 454/1000
# 1/1 - 0s - gaussian_likelihood: 29934.9570 - loss: 29935.7754
# Epoch 455/1000
# 1/1 - 0s - gaussian_likelihood: 3742.8184 - loss: 3743.6392
# Epoch 456/1000
# 1/1 - 0s - gaussian_likelihood: 28166.4355 - loss: 28167.2578
# Epoch 457/1000
# 1/1 - 0s - gaussian_likelihood: 13393.7910 - loss: 13394.6152
# Epoch 458/1000
# 1/1 - 0s - gaussian_likelihood: 24192.1699 - loss: 24192.9961
# Epoch 459/1000
# 1/1 - 0s - gaussian_likelihood: 57389.0039 - loss: 57389.8320
# Epoch 460/1000
# 1/1 - 0s - gaussian_likelihood: 35130.2891 - loss: 35131.1211
# Epoch 461/1000
# 1/1 - 0s - gaussian_likelihood: 18899.5586 - loss: 18900.3926
# Epoch 462/1000
# 1/1 - 0s - gaussian_likelihood: 43857.7969 - loss: 43858.6328
# Epoch 463/1000
# 1/1 - 0s - gaussian_likelihood: 91135.3750 - loss: 91136.2109
# Epoch 464/1000
# 1/1 - 0s - gaussian_likelihood: 25276.4609 - loss: 25277.3066
# Epoch 465/1000
# 1/1 - 0s - gaussian_likelihood: 19756.0977 - loss: 19756.9453
# Epoch 466/1000
# 1/1 - 0s - gaussian_likelihood: 39570.0352 - loss: 39570.8867
# Epoch 467/1000
# 1/1 - 0s - gaussian_likelihood: 13256.2422 - loss: 13257.0957
# Epoch 468/1000
# 1/1 - 0s - gaussian_likelihood: 3316.3188 - loss: 3317.1746
# Epoch 469/1000
# 1/1 - 0s - gaussian_likelihood: 35476.6992 - loss: 35477.5547
# Epoch 470/1000
# 1/1 - 0s - gaussian_likelihood: 6267.8320 - loss: 6268.6914
# Epoch 471/1000
# 1/1 - 0s - gaussian_likelihood: 49302.7969 - loss: 49303.6562
# Epoch 472/1000
# 1/1 - 0s - gaussian_likelihood: 33344.6367 - loss: 33345.5000
# Epoch 473/1000
# 1/1 - 0s - gaussian_likelihood: 49245.6602 - loss: 49246.5273
# Epoch 474/1000
# 1/1 - 0s - gaussian_likelihood: 46339.6484 - loss: 46340.5195
# Epoch 475/1000
# 1/1 - 0s - gaussian_likelihood: 12893.2852 - loss: 12894.1582
# Epoch 476/1000
# 1/1 - 0s - gaussian_likelihood: 17042.7305 - loss: 17043.6055
# Epoch 477/1000
# 1/1 - 0s - gaussian_likelihood: 25937.8906 - loss: 25938.7676
# Epoch 478/1000
# 1/1 - 0s - gaussian_likelihood: 130154.1172 - loss: 130155.0000
# Epoch 479/1000
# 1/1 - 0s - gaussian_likelihood: 59713.6641 - loss: 59714.5508
# Epoch 480/1000
# 1/1 - 0s - gaussian_likelihood: 8320.4268 - loss: 8321.3174
# Epoch 481/1000
# 1/1 - 0s - gaussian_likelihood: 18982.2559 - loss: 18983.1484
# Epoch 482/1000
# 1/1 - 0s - gaussian_likelihood: 26910.5547 - loss: 26911.4492
# Epoch 483/1000
# 1/1 - 0s - gaussian_likelihood: 8282.2012 - loss: 8283.0996
# Epoch 484/1000
# 1/1 - 0s - gaussian_likelihood: 27955.0742 - loss: 27955.9746
# Epoch 485/1000
# 1/1 - 0s - gaussian_likelihood: 14490.2891 - loss: 14491.1924
# Epoch 486/1000
# 1/1 - 0s - gaussian_likelihood: 57873.8047 - loss: 57874.7109
# Epoch 487/1000
# 1/1 - 0s - gaussian_likelihood: 30976.5312 - loss: 30977.4395
# Epoch 488/1000
# 1/1 - 0s - gaussian_likelihood: 39088.9492 - loss: 39089.8633
# Epoch 489/1000
# 1/1 - 0s - gaussian_likelihood: 19505.6289 - loss: 19506.5430
# Epoch 490/1000
# 1/1 - 0s - gaussian_likelihood: 44218.3438 - loss: 44219.2617
# Epoch 491/1000
# 1/1 - 0s - gaussian_likelihood: 14257.5508 - loss: 14258.4697
# Epoch 492/1000
# 1/1 - 0s - gaussian_likelihood: 24902.7773 - loss: 24903.6992
# Epoch 493/1000
# 1/1 - 0s - gaussian_likelihood: 24007.1016 - loss: 24008.0254
# Epoch 494/1000
# 1/1 - 0s - gaussian_likelihood: 87818.3438 - loss: 87819.2734
# Epoch 495/1000
# 1/1 - 0s - gaussian_likelihood: 58466.3594 - loss: 58467.2930
# Epoch 496/1000
# 1/1 - 0s - gaussian_likelihood: 13700.1484 - loss: 13701.0850
# Epoch 497/1000
# 1/1 - 0s - gaussian_likelihood: 24447.4727 - loss: 24448.4121
# Epoch 498/1000
# 1/1 - 0s - gaussian_likelihood: 7328.7939 - loss: 7329.7363
# Epoch 499/1000
# 1/1 - 0s - gaussian_likelihood: 6742.4824 - loss: 6743.4268
# Epoch 500/1000
# 1/1 - 0s - gaussian_likelihood: 64296.9141 - loss: 64297.8594
# Epoch 501/1000
# 1/1 - 0s - gaussian_likelihood: 41185.5703 - loss: 41186.5195
# Epoch 502/1000
# 1/1 - 0s - gaussian_likelihood: 27777.7832 - loss: 27778.7363
# Epoch 503/1000
# 1/1 - 0s - gaussian_likelihood: 17668.6367 - loss: 17669.5918
# Epoch 504/1000
# 1/1 - 0s - gaussian_likelihood: 9835.2949 - loss: 9836.2529
# Epoch 505/1000
# 1/1 - 0s - gaussian_likelihood: 69517.8203 - loss: 69518.7812
# Epoch 506/1000
# 1/1 - 0s - gaussian_likelihood: 41750.6641 - loss: 41751.6289
# Epoch 507/1000
# 1/1 - 0s - gaussian_likelihood: 22693.6992 - loss: 22694.6680
# Epoch 508/1000
# 1/1 - 0s - gaussian_likelihood: 30768.9062 - loss: 30769.8770
# Epoch 509/1000
# 1/1 - 0s - gaussian_likelihood: 13249.7246 - loss: 13250.6992
# Epoch 510/1000
# 1/1 - 0s - gaussian_likelihood: 92639.1094 - loss: 92640.0859
# Epoch 511/1000
# 1/1 - 0s - gaussian_likelihood: 184321.4375 - loss: 184322.4219
# Epoch 512/1000
# 1/1 - 0s - gaussian_likelihood: 12379.7832 - loss: 12380.7773
# Epoch 513/1000
# 1/1 - 0s - gaussian_likelihood: 7246.2588 - loss: 7247.2554
# Epoch 514/1000
# 1/1 - 0s - gaussian_likelihood: 42403.7188 - loss: 42404.7188
# Epoch 515/1000
# 1/1 - 0s - gaussian_likelihood: 4457.1709 - loss: 4458.1748
# Epoch 516/1000
# 1/1 - 0s - gaussian_likelihood: 32890.1484 - loss: 32891.1562
# Epoch 517/1000
# 1/1 - 0s - gaussian_likelihood: 25364.4531 - loss: 25365.4648
# Epoch 518/1000
# 1/1 - 0s - gaussian_likelihood: 25751.2559 - loss: 25752.2695
# Epoch 519/1000
# 1/1 - 0s - gaussian_likelihood: 2858.2969 - loss: 2859.3142
# Epoch 520/1000
# 1/1 - 0s - gaussian_likelihood: 43768.0625 - loss: 43769.0820
# Epoch 521/1000
# 1/1 - 0s - gaussian_likelihood: 11327.2090 - loss: 11328.2305
# Epoch 522/1000
# 1/1 - 0s - gaussian_likelihood: 33026.3633 - loss: 33027.3867
# Epoch 523/1000
# 1/1 - 0s - gaussian_likelihood: 25691.5625 - loss: 25692.5898
# Epoch 524/1000
# 1/1 - 0s - gaussian_likelihood: 136098.6562 - loss: 136099.6875
# Epoch 525/1000
# 1/1 - 0s - gaussian_likelihood: 7078.0312 - loss: 7079.0698
# Epoch 526/1000
# 1/1 - 0s - gaussian_likelihood: 24691.1914 - loss: 24692.2324
# Epoch 527/1000
# 1/1 - 0s - gaussian_likelihood: 9187.4600 - loss: 9188.5039
# Epoch 528/1000
# 1/1 - 0s - gaussian_likelihood: 2903.4839 - loss: 2904.5300
# Epoch 529/1000
# 1/1 - 0s - gaussian_likelihood: 28025.4297 - loss: 28026.4785
# Epoch 530/1000
# 1/1 - 0s - gaussian_likelihood: 31027.4609 - loss: 31028.5117
# Epoch 531/1000
# 1/1 - 0s - gaussian_likelihood: 86478.4375 - loss: 86479.4922
# Epoch 532/1000
# 1/1 - 0s - gaussian_likelihood: 10274.1602 - loss: 10275.2207
# Epoch 533/1000
# 1/1 - 0s - gaussian_likelihood: 27832.5078 - loss: 27833.5703
# Epoch 534/1000
# 1/1 - 0s - gaussian_likelihood: 4946.3867 - loss: 4947.4546
# Epoch 535/1000
# 1/1 - 0s - gaussian_likelihood: 42810.9141 - loss: 42811.9844
# Epoch 536/1000
# 1/1 - 0s - gaussian_likelihood: 40750.6758 - loss: 40751.7500
# Epoch 537/1000
# 1/1 - 0s - gaussian_likelihood: 30704.0547 - loss: 30705.1328
# Epoch 538/1000
# 1/1 - 0s - gaussian_likelihood: 14102.7871 - loss: 14103.8682
# Epoch 539/1000
# 1/1 - 0s - gaussian_likelihood: 38290.4297 - loss: 38291.5117
# Epoch 540/1000
# 1/1 - 0s - gaussian_likelihood: 4402.7949 - loss: 4403.8818
# Epoch 541/1000
# 1/1 - 0s - gaussian_likelihood: 24115.2754 - loss: 24116.3633
# Epoch 542/1000
# 1/1 - 0s - gaussian_likelihood: 34472.7578 - loss: 34473.8477
# Epoch 543/1000
# 1/1 - 0s - gaussian_likelihood: 4168.3262 - loss: 4169.4199
# Epoch 544/1000
# 1/1 - 0s - gaussian_likelihood: 11858.4629 - loss: 11859.5586
# Epoch 545/1000
# 1/1 - 0s - gaussian_likelihood: 50392.4258 - loss: 50393.5234
# Epoch 546/1000
# 1/1 - 0s - gaussian_likelihood: 31576.9102 - loss: 31578.0117
# Epoch 547/1000
# 1/1 - 0s - gaussian_likelihood: 15559.8477 - loss: 15560.9512
# Epoch 548/1000
# 1/1 - 0s - gaussian_likelihood: 26564.2969 - loss: 26565.4023
# Epoch 549/1000
# 1/1 - 0s - gaussian_likelihood: 96737.1562 - loss: 96738.2656
# Epoch 550/1000
# 1/1 - 0s - gaussian_likelihood: 13598.8779 - loss: 13599.9971
# Epoch 551/1000
# 1/1 - 0s - gaussian_likelihood: 11051.8945 - loss: 11053.0166
# Epoch 552/1000
# 1/1 - 0s - gaussian_likelihood: 47343.2266 - loss: 47344.3516
# Epoch 553/1000
# 1/1 - 0s - gaussian_likelihood: 54841.3281 - loss: 54842.4570
# Epoch 554/1000
# 1/1 - 0s - gaussian_likelihood: 23364.0938 - loss: 23365.2246
# Epoch 555/1000
# 1/1 - 0s - gaussian_likelihood: 33418.2812 - loss: 33419.4180
# Epoch 556/1000
# 1/1 - 0s - gaussian_likelihood: 35029.5078 - loss: 35030.6445
# Epoch 557/1000
# 1/1 - 0s - gaussian_likelihood: 4035.7080 - loss: 4036.8513
# Epoch 558/1000
# 1/1 - 0s - gaussian_likelihood: 20266.9453 - loss: 20268.0898
# Epoch 559/1000
# 1/1 - 0s - gaussian_likelihood: 14402.5264 - loss: 14403.6748
# Epoch 560/1000
# 1/1 - 0s - gaussian_likelihood: 3868.0503 - loss: 3869.2012
# Epoch 561/1000
# 1/1 - 0s - gaussian_likelihood: 6459.4204 - loss: 6460.5728
# Epoch 562/1000
# 1/1 - 0s - gaussian_likelihood: 58081.2305 - loss: 58082.3867
# Epoch 563/1000
# 1/1 - 0s - gaussian_likelihood: 26063.0625 - loss: 26064.2227
# Epoch 564/1000
# 1/1 - 0s - gaussian_likelihood: 43282.8477 - loss: 43284.0117
# Epoch 565/1000
# 1/1 - 0s - gaussian_likelihood: 47219.3984 - loss: 47220.5664
# Epoch 566/1000
# 1/1 - 0s - gaussian_likelihood: 31488.4941 - loss: 31489.6680
# Epoch 567/1000
# 1/1 - 0s - gaussian_likelihood: 7279.7090 - loss: 7280.8877
# Epoch 568/1000
# 1/1 - 0s - gaussian_likelihood: 21382.2812 - loss: 21383.4629
# Epoch 569/1000
# 1/1 - 0s - gaussian_likelihood: 40723.8008 - loss: 40724.9844
# Epoch 570/1000
# 1/1 - 0s - gaussian_likelihood: 16048.3379 - loss: 16049.5264
# Epoch 571/1000
# 1/1 - 0s - gaussian_likelihood: 28445.3125 - loss: 28446.5039
# Epoch 572/1000
# 1/1 - 0s - gaussian_likelihood: 49346.0391 - loss: 49347.2344
# Epoch 573/1000
# 1/1 - 0s - gaussian_likelihood: 16032.0859 - loss: 16033.2842
# Epoch 574/1000
# 1/1 - 0s - gaussian_likelihood: 84345.2422 - loss: 84346.4453
# Epoch 575/1000
# 1/1 - 0s - gaussian_likelihood: 6338.4668 - loss: 6339.6743
# Epoch 576/1000
# 1/1 - 0s - gaussian_likelihood: 5409.2891 - loss: 5410.4985
# Epoch 577/1000
# 1/1 - 0s - gaussian_likelihood: 46642.8125 - loss: 46644.0234
# Epoch 578/1000
# 1/1 - 0s - gaussian_likelihood: 25719.3438 - loss: 25720.5605
# Epoch 579/1000
# 1/1 - 0s - gaussian_likelihood: 6037.2109 - loss: 6038.4312
# Epoch 580/1000
# 1/1 - 0s - gaussian_likelihood: 54146.6797 - loss: 54147.9023
# Epoch 581/1000
# 1/1 - 0s - gaussian_likelihood: 8902.6055 - loss: 8903.8330
# Epoch 582/1000
# 1/1 - 0s - gaussian_likelihood: 45401.8359 - loss: 45403.0664
# Epoch 583/1000
# 1/1 - 0s - gaussian_likelihood: 12059.9385 - loss: 12061.1768
# Epoch 584/1000
# 1/1 - 0s - gaussian_likelihood: 12913.4502 - loss: 12914.6914
# Epoch 585/1000
# 1/1 - 0s - gaussian_likelihood: 4220.9214 - loss: 4222.1650
# Epoch 586/1000
# 1/1 - 0s - gaussian_likelihood: 59746.1172 - loss: 59747.3633
# Epoch 587/1000
# 1/1 - 0s - gaussian_likelihood: 2830.1421 - loss: 2831.3940
# Epoch 588/1000
# 1/1 - 0s - gaussian_likelihood: 77637.4062 - loss: 77638.6641
# Epoch 589/1000
# 1/1 - 0s - gaussian_likelihood: 54676.6172 - loss: 54677.8789
# Epoch 590/1000
# 1/1 - 0s - gaussian_likelihood: 73879.6719 - loss: 73880.9375
# Epoch 591/1000
# 1/1 - 0s - gaussian_likelihood: 34284.2695 - loss: 34285.5430
# Epoch 592/1000
# 1/1 - 0s - gaussian_likelihood: 34267.5703 - loss: 34268.8516
# Epoch 593/1000
# 1/1 - 0s - gaussian_likelihood: 9187.7246 - loss: 9189.0098
# Epoch 594/1000
# 1/1 - 0s - gaussian_likelihood: 14023.8662 - loss: 14025.1553
# Epoch 595/1000
# 1/1 - 0s - gaussian_likelihood: 17326.2441 - loss: 17327.5352
# Epoch 596/1000
# 1/1 - 0s - gaussian_likelihood: 21884.9570 - loss: 21886.2520
# Epoch 597/1000
# 1/1 - 0s - gaussian_likelihood: 213349.6250 - loss: 213350.9219
# Epoch 598/1000
# 1/1 - 0s - gaussian_likelihood: 11948.4336 - loss: 11949.7432
# Epoch 599/1000
# 1/1 - 0s - gaussian_likelihood: 21457.8281 - loss: 21459.1426
# Epoch 600/1000
# 1/1 - 0s - gaussian_likelihood: 42791.3164 - loss: 42792.6328
# Epoch 601/1000
# 1/1 - 0s - gaussian_likelihood: 12207.9053 - loss: 12209.2285
# Epoch 602/1000
# ...
# Epoch 791/1000
# 1/1 - 0s - gaussian_likelihood: 11252.8447 - loss: 11255.0283
# Epoch 792/1000
# 1/1 - 0s - gaussian_likelihood: 34401.1641 - loss: 34403.3516
# Epoch 793/1000
# 1/1 - 0s - gaussian_likelihood: 13639.4326 - loss: 13641.6279
# Epoch 794/1000
# 1/1 - 0s - gaussian_likelihood: 9770.5898 - loss: 9772.7891
# Epoch 795/1000
# 1/1 - 0s - gaussian_likelihood: 52127.3945 - loss: 52129.5977
# Epoch 796/1000
# 1/1 - 0s - gaussian_likelihood: 6120.1621 - loss: 6122.3745
# Epoch 797/1000
# 1/1 - 0s - gaussian_likelihood: 6915.6772 - loss: 6917.8936
# Epoch 798/1000
# 1/1 - 0s - gaussian_likelihood: 1102.8241 - loss: 1105.0450
# Epoch 799/1000
# 1/1 - 0s - gaussian_likelihood: 10640.9648 - loss: 10643.1885
# Epoch 800/1000
# 1/1 - 0s - gaussian_likelihood: 14026.1104 - loss: 14028.3389
# Epoch 801/1000
# 1/1 - 0s - gaussian_likelihood: 6437.0176 - loss: 6439.2520
# Epoch 802/1000
# 1/1 - 0s - gaussian_likelihood: 18291.1777 - loss: 18293.4160
# Epoch 803/1000
# 1/1 - 0s - gaussian_likelihood: 1642.7582 - loss: 1645.0009
# Epoch 804/1000
# 1/1 - 0s - gaussian_likelihood: 12770.6719 - loss: 12772.9170
# Epoch 805/1000
# 1/1 - 0s - gaussian_likelihood: 15242.6367 - loss: 15244.8857
# Epoch 806/1000
# 1/1 - 0s - gaussian_likelihood: 20896.6289 - loss: 20898.8828
# Epoch 807/1000
# 1/1 - 0s - gaussian_likelihood: 13420.2148 - loss: 13422.4746
# Epoch 808/1000
# 1/1 - 0s - gaussian_likelihood: 2926.8809 - loss: 2929.1448
# Epoch 809/1000
# 1/1 - 0s - gaussian_likelihood: 3903.0654 - loss: 3905.3320
# Epoch 810/1000
# 1/1 - 0s - gaussian_likelihood: 14456.3682 - loss: 14458.6377
# Epoch 811/1000
# 1/1 - 0s - gaussian_likelihood: 3664.3623 - loss: 3666.6377
# Epoch 812/1000
# 1/1 - 0s - gaussian_likelihood: 2045.1864 - loss: 2047.4645
# Epoch 813/1000
# 1/1 - 0s - gaussian_likelihood: 308.9765 - loss: 311.2568
# Epoch 814/1000
# 1/1 - 0s - gaussian_likelihood: 3439.3789 - loss: 3441.6609
# Epoch 815/1000
# 1/1 - 0s - gaussian_likelihood: 3994.8228 - loss: 3997.1077
# Epoch 816/1000
# 1/1 - 0s - gaussian_likelihood: 12688.4141 - loss: 12690.7012
# Epoch 817/1000
# 1/1 - 0s - gaussian_likelihood: 6344.5850 - loss: 6346.8765
# Epoch 818/1000
# 1/1 - 0s - gaussian_likelihood: 19642.1641 - loss: 19644.4590
# Epoch 819/1000
# 1/1 - 0s - gaussian_likelihood: 7563.9795 - loss: 7566.2812
# Epoch 820/1000
# 1/1 - 0s - gaussian_likelihood: 14794.5859 - loss: 14796.8906
# Epoch 821/1000
# 1/1 - 0s - gaussian_likelihood: 15731.7100 - loss: 15734.0205
# Epoch 822/1000
# 1/1 - 0s - gaussian_likelihood: 1255.1616 - loss: 1257.4766
# Epoch 823/1000
# 1/1 - 0s - gaussian_likelihood: 3433.6487 - loss: 3435.9656
# Epoch 824/1000
# 1/1 - 0s - gaussian_likelihood: 5623.5068 - loss: 5625.8267
# Epoch 825/1000
# 1/1 - 0s - gaussian_likelihood: 6864.6621 - loss: 6866.9839
# Epoch 826/1000
# 1/1 - 0s - gaussian_likelihood: 7183.2354 - loss: 7185.5596
# Epoch 827/1000
# 1/1 - 0s - gaussian_likelihood: 18556.9824 - loss: 18559.3105
# Epoch 828/1000
# 1/1 - 0s - gaussian_likelihood: 19153.5918 - loss: 19155.9238
# Epoch 829/1000
# 1/1 - 0s - gaussian_likelihood: 13148.4980 - loss: 13150.8340
# Epoch 830/1000
# 1/1 - 0s - gaussian_likelihood: 4061.4304 - loss: 4063.7725
# Epoch 831/1000
# 1/1 - 0s - gaussian_likelihood: 1630.1840 - loss: 1632.5289
# Epoch 832/1000
# 1/1 - 0s - gaussian_likelihood: 18832.1797 - loss: 18834.5273
# Epoch 833/1000
# 1/1 - 0s - gaussian_likelihood: 17378.0137 - loss: 17380.3672
# Epoch 834/1000
# 1/1 - 0s - gaussian_likelihood: 17165.4004 - loss: 17167.7578
# Epoch 835/1000
# 1/1 - 0s - gaussian_likelihood: 10498.8760 - loss: 10501.2393
# Epoch 836/1000
# 1/1 - 0s - gaussian_likelihood: 3892.2275 - loss: 3894.5959
# Epoch 837/1000
# 1/1 - 0s - gaussian_likelihood: 11973.4160 - loss: 11975.7871
# Epoch 838/1000
# 1/1 - 0s - gaussian_likelihood: 3073.9377 - loss: 3076.3132
# Epoch 839/1000
# 1/1 - 0s - gaussian_likelihood: 3019.7720 - loss: 3022.1504
# Epoch 840/1000
# 1/1 - 0s - gaussian_likelihood: 26007.1914 - loss: 26009.5723
# Epoch 841/1000
# 1/1 - 0s - gaussian_likelihood: 10621.8086 - loss: 10624.1973
# Epoch 842/1000
# 1/1 - 0s - gaussian_likelihood: 11478.2422 - loss: 11480.6348
# Epoch 843/1000
# 1/1 - 0s - gaussian_likelihood: 16161.4180 - loss: 16163.8145
# Epoch 844/1000
# 1/1 - 0s - gaussian_likelihood: 10800.2422 - loss: 10802.6445
# Epoch 845/1000
# 1/1 - 0s - gaussian_likelihood: 15929.0957 - loss: 15931.5020
# Epoch 846/1000
# 1/1 - 0s - gaussian_likelihood: 41914.4375 - loss: 41916.8477
# Epoch 847/1000
# 1/1 - 0s - gaussian_likelihood: 1109.6727 - loss: 1112.0945
# Epoch 848/1000
# 1/1 - 0s - gaussian_likelihood: 24450.9961 - loss: 24453.4199
# Epoch 849/1000
# 1/1 - 0s - gaussian_likelihood: 18604.2305 - loss: 18606.6602
# Epoch 850/1000
# 1/1 - 0s - gaussian_likelihood: 3462.6499 - loss: 3465.0867
# Epoch 851/1000
# 1/1 - 0s - gaussian_likelihood: 325.8387 - loss: 328.2789
# Epoch 852/1000
# 1/1 - 0s - gaussian_likelihood: 41859.2266 - loss: 41861.6680
# Epoch 853/1000
# 1/1 - 0s - gaussian_likelihood: 2759.3638 - loss: 2761.8140
# Epoch 854/1000
# 1/1 - 0s - gaussian_likelihood: 9843.2480 - loss: 9845.7012
# Epoch 855/1000
# 1/1 - 0s - gaussian_likelihood: 6858.1465 - loss: 6860.6064
# Epoch 856/1000
# 1/1 - 0s - gaussian_likelihood: 9032.9385 - loss: 9035.4014
# Epoch 857/1000
# 1/1 - 0s - gaussian_likelihood: 899.9225 - loss: 902.3903
# Epoch 858/1000
# 1/1 - 0s - gaussian_likelihood: 18420.8867 - loss: 18423.3574
# Epoch 859/1000
# 1/1 - 0s - gaussian_likelihood: 14650.3926 - loss: 14652.8682
# Epoch 860/1000
# 1/1 - 0s - gaussian_likelihood: 10355.0068 - loss: 10357.4873
# Epoch 861/1000
# 1/1 - 0s - gaussian_likelihood: 4268.7676 - loss: 4271.2524
# Epoch 862/1000
# 1/1 - 0s - gaussian_likelihood: 7373.7686 - loss: 7376.2563
# Epoch 863/1000
# 1/1 - 0s - gaussian_likelihood: 6020.1436 - loss: 6022.6353
# Epoch 864/1000
# 1/1 - 0s - gaussian_likelihood: 6304.3115 - loss: 6306.8062
# Epoch 865/1000
# 1/1 - 0s - gaussian_likelihood: 6206.1177 - loss: 6208.6157
# Epoch 866/1000
# 1/1 - 0s - gaussian_likelihood: 26203.0078 - loss: 26205.5098
# Epoch 867/1000
# 1/1 - 0s - gaussian_likelihood: 9413.4424 - loss: 9415.9521
# Epoch 868/1000
# 1/1 - 0s - gaussian_likelihood: 17507.6758 - loss: 17510.1914
# Epoch 869/1000
# 1/1 - 0s - gaussian_likelihood: 4253.8228 - loss: 4256.3452
# Epoch 870/1000
# 1/1 - 0s - gaussian_likelihood: 7238.8379 - loss: 7241.3638
# Epoch 871/1000
# 1/1 - 0s - gaussian_likelihood: 1278.4381 - loss: 1280.9680
# Epoch 872/1000
# 1/1 - 0s - gaussian_likelihood: 8260.7578 - loss: 8263.2900
# Epoch 873/1000
# 1/1 - 0s - gaussian_likelihood: 8716.7461 - loss: 8719.2822
# Epoch 874/1000
# 1/1 - 0s - gaussian_likelihood: 20274.1992 - loss: 20276.7422
# Epoch 875/1000
# 1/1 - 0s - gaussian_likelihood: 4310.3545 - loss: 4312.9043
# Epoch 876/1000
# 1/1 - 0s - gaussian_likelihood: 16302.5537 - loss: 16305.1074
# Epoch 877/1000
# 1/1 - 0s - gaussian_likelihood: 5667.1123 - loss: 5669.6714
# Epoch 878/1000
# 1/1 - 0s - gaussian_likelihood: 9919.0664 - loss: 9921.6299
# Epoch 879/1000
# 1/1 - 0s - gaussian_likelihood: 11590.8691 - loss: 11593.4395
# Epoch 880/1000
# 1/1 - 0s - gaussian_likelihood: 14221.2314 - loss: 14223.8066
# Epoch 881/1000
# 1/1 - 0s - gaussian_likelihood: 3490.5688 - loss: 3493.1526
# Epoch 882/1000
# 1/1 - 0s - gaussian_likelihood: 6338.5869 - loss: 6341.1743
# Epoch 883/1000
# 1/1 - 0s - gaussian_likelihood: 9942.3848 - loss: 9944.9756
# Epoch 884/1000
# 1/1 - 0s - gaussian_likelihood: 2254.3037 - loss: 2256.9004
# Epoch 885/1000
# 1/1 - 0s - gaussian_likelihood: 13520.8984 - loss: 13523.4980
# Epoch 886/1000
# 1/1 - 0s - gaussian_likelihood: 35756.9648 - loss: 35759.5703
# Epoch 887/1000
# 1/1 - 0s - gaussian_likelihood: 3703.9009 - loss: 3706.5203
# Epoch 888/1000
# 1/1 - 0s - gaussian_likelihood: 13691.8613 - loss: 13694.4854
# Epoch 889/1000
# 1/1 - 0s - gaussian_likelihood: 4018.2998 - loss: 4020.9312
# Epoch 890/1000
# 1/1 - 0s - gaussian_likelihood: 4167.6016 - loss: 4170.2368
# Epoch 891/1000
# 1/1 - 0s - gaussian_likelihood: 3753.1016 - loss: 3755.7407
# Epoch 892/1000
# 1/1 - 0s - gaussian_likelihood: 10086.3545 - loss: 10088.9971
# Epoch 893/1000
# 1/1 - 0s - gaussian_likelihood: 1227.8835 - loss: 1230.5308
# Epoch 894/1000
# 1/1 - 0s - gaussian_likelihood: 18154.8359 - loss: 18157.4863
# Epoch 895/1000
# 1/1 - 0s - gaussian_likelihood: 1437.6934 - loss: 1440.3514
# Epoch 896/1000
# 1/1 - 0s - gaussian_likelihood: 8754.6816 - loss: 8757.3428
# Epoch 897/1000
# 1/1 - 0s - gaussian_likelihood: 12625.8770 - loss: 12628.5439
# Epoch 898/1000
# 1/1 - 0s - gaussian_likelihood: 4522.8545 - loss: 4525.5288
# Epoch 899/1000
# 1/1 - 0s - gaussian_likelihood: 8181.0503 - loss: 8183.7280
# Epoch 900/1000
# 1/1 - 0s - gaussian_likelihood: 3933.6221 - loss: 3936.3037
# Epoch 901/1000
# 1/1 - 0s - gaussian_likelihood: 7763.3247 - loss: 7766.0098
# Epoch 902/1000
# 1/1 - 0s - gaussian_likelihood: 11649.1484 - loss: 11651.8379
# Epoch 903/1000
# 1/1 - 0s - gaussian_likelihood: 31464.8711 - loss: 31467.5664
# Epoch 904/1000
# 1/1 - 0s - gaussian_likelihood: 7189.1934 - loss: 7191.8970
# Epoch 905/1000
# 1/1 - 0s - gaussian_likelihood: 40128.0469 - loss: 40130.7539
# Epoch 906/1000
# 1/1 - 0s - gaussian_likelihood: 3985.6897 - loss: 3988.4070
# Epoch 907/1000
# 1/1 - 0s - gaussian_likelihood: 24002.4883 - loss: 24005.2109
# Epoch 908/1000
# 1/1 - 0s - gaussian_likelihood: 6379.4385 - loss: 6382.1699
# Epoch 909/1000
# 1/1 - 0s - gaussian_likelihood: 9251.2822 - loss: 9254.0176
# Epoch 910/1000
# 1/1 - 0s - gaussian_likelihood: 20768.9336 - loss: 20771.6738
# Epoch 911/1000
# 1/1 - 0s - gaussian_likelihood: 4507.5869 - loss: 4510.3340
# Epoch 912/1000
# 1/1 - 0s - gaussian_likelihood: 28122.1055 - loss: 28124.8574
# Epoch 913/1000
# 1/1 - 0s - gaussian_likelihood: 19587.4531 - loss: 19590.2129
# Epoch 914/1000
# 1/1 - 0s - gaussian_likelihood: 1389.0970 - loss: 1391.8622
# Epoch 915/1000
# 1/1 - 0s - gaussian_likelihood: 9094.6709 - loss: 9097.4395
# Epoch 916/1000
# 1/1 - 0s - gaussian_likelihood: 12293.0605 - loss: 12295.8340
# Epoch 917/1000
# 1/1 - 0s - gaussian_likelihood: 22272.5938 - loss: 22275.3730
# Epoch 918/1000
# 1/1 - 0s - gaussian_likelihood: 9736.4258 - loss: 9739.2139
# Epoch 919/1000
# 1/1 - 0s - gaussian_likelihood: 3209.3770 - loss: 3212.1719
# Epoch 920/1000
# 1/1 - 0s - gaussian_likelihood: 3159.9604 - loss: 3162.7595
# Epoch 921/1000
# 1/1 - 0s - gaussian_likelihood: 4858.7720 - loss: 4861.5752
# Epoch 922/1000
# 1/1 - 0s - gaussian_likelihood: 8195.9805 - loss: 8198.7871
# Epoch 923/1000
# 1/1 - 0s - gaussian_likelihood: 7554.6855 - loss: 7557.4971
# Epoch 924/1000
# 1/1 - 0s - gaussian_likelihood: 2879.4897 - loss: 2882.3057
# Epoch 925/1000
# 1/1 - 0s - gaussian_likelihood: 8958.3809 - loss: 8961.2002
# Epoch 926/1000
# 1/1 - 0s - gaussian_likelihood: 14814.8525 - loss: 14817.6768
# Epoch 927/1000
# 1/1 - 0s - gaussian_likelihood: 674.1010 - loss: 676.9327
# Epoch 928/1000
# 1/1 - 0s - gaussian_likelihood: 5030.0996 - loss: 5032.9341
# Epoch 929/1000
# 1/1 - 0s - gaussian_likelihood: 398.8853 - loss: 401.7248
# Epoch 930/1000
# 1/1 - 0s - gaussian_likelihood: 3791.1531 - loss: 3793.9949
# Epoch 931/1000
# 1/1 - 0s - gaussian_likelihood: 14029.4170 - loss: 14032.2617
# Epoch 932/1000
# 1/1 - 0s - gaussian_likelihood: 4035.8689 - loss: 4038.7197
# Epoch 933/1000
# 1/1 - 0s - gaussian_likelihood: 761.5663 - loss: 764.4203
# Epoch 934/1000
# 1/1 - 0s - gaussian_likelihood: 4170.4961 - loss: 4173.3525
# Epoch 935/1000
# 1/1 - 0s - gaussian_likelihood: 3665.7000 - loss: 3668.5598
# Epoch 936/1000
# 1/1 - 0s - gaussian_likelihood: 1320.2478 - loss: 1323.1117
# Epoch 937/1000
# 1/1 - 0s - gaussian_likelihood: 19245.4570 - loss: 19248.3223
# Epoch 938/1000
# 1/1 - 0s - gaussian_likelihood: 1710.2177 - loss: 1713.0905
# Epoch 939/1000
# 1/1 - 0s - gaussian_likelihood: 8914.8125 - loss: 8917.6875
# Epoch 940/1000
# 1/1 - 0s - gaussian_likelihood: 1473.1956 - loss: 1476.0760
# Epoch 941/1000
# 1/1 - 0s - gaussian_likelihood: 1924.7653 - loss: 1927.6482
# Epoch 942/1000
# 1/1 - 0s - gaussian_likelihood: 6806.1504 - loss: 6809.0356
# Epoch 943/1000
# 1/1 - 0s - gaussian_likelihood: 21498.6719 - loss: 21501.5605
# Epoch 944/1000
# 1/1 - 0s - gaussian_likelihood: 16197.8281 - loss: 16200.7285
# Epoch 945/1000
# 1/1 - 0s - gaussian_likelihood: 1893.8667 - loss: 1896.7751
# Epoch 946/1000
# 1/1 - 0s - gaussian_likelihood: 4642.1904 - loss: 4645.1021
# Epoch 947/1000
# 1/1 - 0s - gaussian_likelihood: 6949.4316 - loss: 6952.3472
# Epoch 948/1000
# 1/1 - 0s - gaussian_likelihood: 8022.6519 - loss: 8025.5718
# Epoch 949/1000
# 1/1 - 0s - gaussian_likelihood: 4840.3818 - loss: 4843.3066
# Epoch 950/1000
# 1/1 - 0s - gaussian_likelihood: 8003.2222 - loss: 8006.1504
# Epoch 951/1000
# 1/1 - 0s - gaussian_likelihood: 7911.9888 - loss: 7914.9219
# Epoch 952/1000
# 1/1 - 0s - gaussian_likelihood: 4708.3159 - loss: 4711.2568
# Epoch 953/1000
# 1/1 - 0s - gaussian_likelihood: 1081.3623 - loss: 1084.3076
# Epoch 954/1000
# 1/1 - 0s - gaussian_likelihood: 631.9156 - loss: 634.8638
# Epoch 955/1000
# 1/1 - 0s - gaussian_likelihood: 11171.5918 - loss: 11174.5420
# Epoch 956/1000
# 1/1 - 0s - gaussian_likelihood: 14941.2754 - loss: 14944.2354
# Epoch 957/1000
# 1/1 - 0s - gaussian_likelihood: 5368.9692 - loss: 5371.9360
# Epoch 958/1000
# 1/1 - 0s - gaussian_likelihood: 8313.4463 - loss: 8316.4180
# Epoch 959/1000
# 1/1 - 0s - gaussian_likelihood: 7051.4219 - loss: 7054.3989
# Epoch 960/1000
# 1/1 - 0s - gaussian_likelihood: 10963.6680 - loss: 10966.6494
# Epoch 961/1000
# 1/1 - 0s - gaussian_likelihood: 2242.7568 - loss: 2245.7444
# Epoch 962/1000
# 1/1 - 0s - gaussian_likelihood: 6930.5098 - loss: 6933.5005
# Epoch 963/1000
# 1/1 - 0s - gaussian_likelihood: 6886.4307 - loss: 6889.4258
# Epoch 964/1000
# 1/1 - 0s - gaussian_likelihood: 27137.1016 - loss: 27140.1016
# Epoch 965/1000
# 1/1 - 0s - gaussian_likelihood: 13837.4258 - loss: 13840.4355
# Epoch 966/1000
# 1/1 - 0s - gaussian_likelihood: 5896.9097 - loss: 5899.9263
# Epoch 967/1000
# 1/1 - 0s - gaussian_likelihood: 991.0089 - loss: 994.0320
# Epoch 968/1000
# 1/1 - 0s - gaussian_likelihood: 8126.1948 - loss: 8129.2212
# Epoch 969/1000
# 1/1 - 0s - gaussian_likelihood: 1893.2393 - loss: 1896.2708
# Epoch 970/1000
# 1/1 - 0s - gaussian_likelihood: 11350.7871 - loss: 11353.8213
# Epoch 971/1000
# 1/1 - 0s - gaussian_likelihood: 10663.3320 - loss: 10666.3711
# Epoch 972/1000
# 1/1 - 0s - gaussian_likelihood: 16091.8428 - loss: 16094.8867
# Epoch 973/1000
# 1/1 - 0s - gaussian_likelihood: 3686.3267 - loss: 3689.3777
# Epoch 974/1000
# 1/1 - 0s - gaussian_likelihood: 9431.6191 - loss: 9434.6738
# Epoch 975/1000
# 1/1 - 0s - gaussian_likelihood: 6583.7217 - loss: 6586.7822
# Epoch 976/1000
# 1/1 - 0s - gaussian_likelihood: 564.9606 - loss: 568.0270
# Epoch 977/1000
# 1/1 - 0s - gaussian_likelihood: 1637.8665 - loss: 1640.9357
# Epoch 978/1000
# 1/1 - 0s - gaussian_likelihood: 7495.4082 - loss: 7498.4805
# Epoch 979/1000
# 1/1 - 0s - gaussian_likelihood: 5432.0254 - loss: 5435.1025
# Epoch 980/1000
# 1/1 - 0s - gaussian_likelihood: 12044.7715 - loss: 12047.8535
# Epoch 981/1000
# 1/1 - 0s - gaussian_likelihood: 27984.0078 - loss: 27987.0977
# Epoch 982/1000
# 1/1 - 0s - gaussian_likelihood: 9029.1260 - loss: 9032.2246
# Epoch 983/1000
# 1/1 - 0s - gaussian_likelihood: 1499.7528 - loss: 1502.8574
# Epoch 984/1000
# 1/1 - 0s - gaussian_likelihood: 21982.5508 - loss: 21985.6582
# Epoch 985/1000
# 1/1 - 0s - gaussian_likelihood: 4522.2163 - loss: 4525.3340
# Epoch 986/1000
# 1/1 - 0s - gaussian_likelihood: 3205.2200 - loss: 3208.3435
# Epoch 987/1000
# 1/1 - 0s - gaussian_likelihood: 1791.4114 - loss: 1794.5389
# Epoch 988/1000
# 1/1 - 0s - gaussian_likelihood: 2236.6975 - loss: 2239.8289
# Epoch 989/1000
# 1/1 - 0s - gaussian_likelihood: 5853.6978 - loss: 5856.8330
# Epoch 990/1000
# 1/1 - 0s - gaussian_likelihood: 11941.6436 - loss: 11944.7822
# Epoch 991/1000
# 1/1 - 0s - gaussian_likelihood: 4718.2197 - loss: 4721.3638
# Epoch 992/1000
# 1/1 - 0s - gaussian_likelihood: 2263.3174 - loss: 2266.4648
# Epoch 993/1000
# 1/1 - 0s - gaussian_likelihood: 4446.1309 - loss: 4449.2817
# Epoch 994/1000
# 1/1 - 0s - gaussian_likelihood: 10156.5391 - loss: 10159.6943
# Epoch 995/1000
# 1/1 - 0s - gaussian_likelihood: 2618.8340 - loss: 2621.9946
# Epoch 996/1000
# 1/1 - 0s - gaussian_likelihood: 22016.9062 - loss: 22020.0703
# Epoch 997/1000
# 1/1 - 0s - gaussian_likelihood: 4894.5078 - loss: 4897.6816
# Epoch 998/1000
# 1/1 - 0s - gaussian_likelihood: 6049.9189 - loss: 6053.0967
# Epoch 999/1000
# 1/1 - 0s - gaussian_likelihood: 6021.2490 - loss: 6024.4312
# Epoch 1000/1000
# 1/1 - 0s - gaussian_likelihood: 20358.2520 - loss: 20361.4395
# Total time elapsed for training = 42.261444091796875 seconds
# Training finished at 2020-07-21 13:16:24.717160

# %%
plt.plot(history.history['loss'])

# %%
for weights in model.get_weights():
    print('Weight/bias:', weights)
# Out:
# Weight/bias: [[1.6896183]
#  [1.5857412]]
# Weight/bias: [[2.2853649]
#  [1.8436363]]
# Weight/bias: [1.1454428]
# Weight/bias: [2.010527]

# %%
y_predict = np.zeros((N_SAMPLES, N_DATA))
for i in trange(N_SAMPLES):
    y_predict[i] = model.predict(Xy.batch(N_DATA)).flatten()
# Out:
# 100%|██████████| 1000/1000 [01:11<00:00, 13.89it/s]

# %%
plt.figure(dpi=200)
plt.errorbar(y, y_predict.mean(0),
             yerr=y_predict.std(0) + 2*LIKELIHOOD_STDDEV, 
             linestyle='None', marker=None)

plt.errorbar(y, y_predict.mean(0),
             yerr=y_predict.std(0), 
             linestyle='None', marker='o', mec='k', ms=1)

plt.plot([y.min()-0.5, y.max()+0.5], [y.min()-0.5, y.max()+0.5], 'k')

plt.axis('square')


plt.show()

# %%
Xb = np.concatenate([X, np.ones((N_DATA, 1))], axis=1)
# Xb = X
Sigma_0 = PRIOR_STDDEV**2 * np.eye(Xb.shape[1])
Sigma_e = LIKELIHOOD_STDDEV**2 * np.eye(N_DATA)
Sigma_k = np.linalg.inv(np.linalg.inv(Sigma_0) + Xb.T @ Xb/LIKELIHOOD_STDDEV**2)
Mu_k = Sigma_k @ (Xb.T @ y/LIKELIHOOD_STDDEV**2)

# %%
Mu_k
# Out:
# array([[2.99806   ],
#        [1.98603416],
#        [0.01332462]])

# %%
print(model.get_weights()[0])
print(model.get_weights()[2])
# Out:
# [[1.6896183]
#  [1.5857412]]
# [1.1454428]

# %%
Sigma_k
# Out:
# array([[ 0.01138525, -0.00313944, -0.00534137],
#        [-0.00313944,  0.00850925, -0.0023326 ],
#        [-0.00534137, -0.0023326 ,  0.0050255 ]])

# %%
U, s, V = np.linalg.svd(Sigma_k)
U @ np.diag(s**0.5) @ V
# np.linalg.cholesky(Sigma_k)
# Out:
# array([[ 0.09729889, -0.02162647, -0.03808509],
#        [-0.02162647,  0.08689335, -0.02216051],
#        [-0.03808509, -0.02216051,  0.0555332 ]])

# %%
print(np.log(np.exp(model.get_weights()[1]) + 1))
print(np.log(np.exp(model.get_weights()[3]) + 1))
# Out:
# [[2.3822527]
#  [1.9905387]]
# [2.136206]

# %%
print(np.exp(model.get_weights()[1]))
print(np.exp(model.get_weights()[3]))
# Out:
# [[9.829271 ]
#  [6.3194757]]
# [7.467251]
