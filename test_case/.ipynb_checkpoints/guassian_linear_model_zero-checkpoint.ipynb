# %%
import tensorflow as tf
import tensorflow_io as tfio
import tensorflow_probability as tfp

print(tf.__version__)
print('Listing all GPU resources:')
print(tf.config.experimental.list_physical_devices('GPU'))
print()
import tensorflow.keras as keras
print(tfp.__version__)
import numpy as np
import datetime
import time
import matplotlib.pyplot as plt
import pickle
import os
import sys
import git
import importlib.util
from tqdm import trange
# Out:
# 2.2.0
# Listing all GPU resources:
# []
#
# 0.10.0

# %%
LAYER_NAME = 'linear_gaussian'
ROOT_PATH = git.Repo("", search_parent_directories=True).git.rev_parse("--show-toplevel")
DATA_PATH = ROOT_PATH + "/data/"
SAVE_PATH = "bayesian_model.h5"
N_DATA = 16
X_DIM = 2
EPOCHS = 1000
VERBOSE = 2
N_SAMPLES = 1000

PRIOR_MU = 0
PRIOR_STDDEV = 10
LIKELIHOOD_STDDEV = 0.1

# %%
X = np.random.rand(N_DATA, X_DIM)
y = (3*X[:, 0].reshape(-1, 1) 
     + 2*X[:, 1].reshape(-1, 1) 
     + np.random.normal(0, LIKELIHOOD_STDDEV, N_DATA).reshape(-1, 1))

print("-" * 30)
print("Loading training and testing data...")
print("-" * 30)

print('X:', X.shape)
print('y: ', y.shape)

Xy = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(X),
                                tf.data.Dataset.from_tensor_slices(y))).cache()
# Out:
# ------------------------------
# Loading training and testing data...
# ------------------------------
# X: (16, 2)
# y:  (16, 1)

# %%
def make_model():

    class KLDivergence:
        def __init__(self, q_dist, p_dist):
            self.q_dist = q_dist
            self.p_dist = p_dist
        def call(self):
            return tfp.distributions.kl_divergence(self.q_dist, self.p_dist)
    
    likelihood_fn = tfp.distributions.MultivariateNormalDiag(np.zeros(N_DATA).astype(np.float32), 
                                                             scale_identity_multiplier=LIKELIHOOD_STDDEV)
    
    def gaussian_likelihood(y, y_pred):
        return -likelihood_fn.log_prob(y-y_pred)
    

    posterior_fn = tfp.layers.default_mean_field_normal_fn(
              loc_initializer=tf.random_normal_initializer(
                  mean=PRIOR_MU, stddev=0.05),
              untransformed_scale_initializer=tf.random_normal_initializer(
                  mean=np.log(np.exp(1e-3) - 1), stddev=0.05))

    def prior_fn(dtype, shape, name, trainable, add_variable_fn):
        dist = tfp.distributions.Normal(loc=PRIOR_MU*tf.ones(shape, dtype), 
                                 scale=PRIOR_STDDEV*tf.ones(shape, dtype))
        multivar_dist = tfp.distributions.Independent(dist, reinterpreted_batch_ndims=tf.size(dist.batch_shape_tensor()))

        return multivar_dist

    flipout_params = dict(kernel_prior_fn=prior_fn,
                          bias_prior_fn=prior_fn,
                          kernel_posterior_fn=posterior_fn,
                          bias_posterior_fn=posterior_fn,
                          kernel_divergence_fn=None,
                          bias_divergence_fn=None)

    input_layer = keras.layers.Input(shape=(X_DIM), name="input_layer")

    output_layer = tfp.layers.DenseFlipout(1, name='dense_layer', **flipout_params)(input_layer)
    
    print()
    print('Input size:', input_layer.shape)
    print('Output size:', output_layer.shape)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer,
                               name = 'model_' + LAYER_NAME)

    for layer in model.layers:
        if type(layer) == tfp.python.layers.dense_variational.DenseFlipout:
            layer.add_loss(KLDivergence(layer.kernel_posterior, layer.kernel_prior).call)
            layer.add_loss(KLDivergence(layer.bias_posterior, layer.bias_prior).call)

    model.compile(optimizer=keras.optimizers.Nadam(learning_rate=2e-2),
                  loss=gaussian_likelihood,
                  metrics=[gaussian_likelihood],
                  )

    return model

# %%
print("-" * 30)
print("Constructing model...")
print("-" * 30)
mirrored_strategy = tf.distribute.MirroredStrategy()

with mirrored_strategy.scope():
    model = make_model()

print('Model summary:')
print(model.summary())

print('Model losses:')
print(model.losses)

print("-" * 30)
print("Fitting model with training data ...")
print("-" * 30)

print("Training the model started at {}".format(datetime.datetime.now()))
start_time = time.time()

#Train the model
history = model.fit(Xy.batch(N_DATA).repeat(32).unbatch().batch(32*N_DATA),
                    epochs=EPOCHS, verbose=VERBOSE,
                    batch_size=N_DATA)

print("Total time elapsed for training = {} seconds".format(time.time() - start_time))
print("Training finished at {}".format(datetime.datetime.now()))


# Save the model
# serialize weights to HDF5
model.save_weights(SAVE_PATH)
# Out:
# ------------------------------
# Constructing model...
# ------------------------------
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
#
# Input size: (None, 2)
# Output size: (None, 1)
# Model summary:
# Model: "model_linear_gaussian"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 2)]               0
# _________________________________________________________________
# dense_layer (DenseFlipout)   (None, 1)                 6
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model losses:
# [<tf.Tensor: shape=(), dtype=float32, numpy=9.627378>, <tf.Tensor: shape=(), dtype=float32, numpy=4.8482847>]
# ------------------------------
# Fitting model with training data ...
# ------------------------------
# Training the model started at 2020-07-21 13:06:51.940760
# Epoch 1/1000
# 1/1 - 0s - loss: 5372.2485 - gaussian_likelihood: 5357.7729
# Epoch 2/1000
# 1/1 - 0s - loss: 5544.4912 - gaussian_likelihood: 5530.0771
# Epoch 3/1000
# 1/1 - 0s - loss: 5208.8364 - gaussian_likelihood: 5194.4346
# Epoch 4/1000
# 1/1 - 0s - loss: 5109.0225 - gaussian_likelihood: 5094.6426
# Epoch 5/1000
# 1/1 - 0s - loss: 5166.9014 - gaussian_likelihood: 5152.5376
# Epoch 6/1000
# 1/1 - 0s - loss: 5398.3086 - gaussian_likelihood: 5383.9473
# Epoch 7/1000
# 1/1 - 0s - loss: 4998.8652 - gaussian_likelihood: 4984.4990
# Epoch 8/1000
# 1/1 - 0s - loss: 4624.2603 - gaussian_likelihood: 4609.9004
# Epoch 9/1000
# 1/1 - 0s - loss: 4839.6880 - gaussian_likelihood: 4825.3350
# Epoch 10/1000
# 1/1 - 0s - loss: 4600.5396 - gaussian_likelihood: 4586.1953
# Epoch 11/1000
# 1/1 - 0s - loss: 4314.1694 - gaussian_likelihood: 4299.8271
# Epoch 12/1000
# 1/1 - 0s - loss: 3986.8171 - gaussian_likelihood: 3972.4795
# Epoch 13/1000
# 1/1 - 0s - loss: 3970.8372 - gaussian_likelihood: 3956.5261
# Epoch 14/1000
# 1/1 - 0s - loss: 4173.8701 - gaussian_likelihood: 4159.6045
# Epoch 15/1000
# 1/1 - 0s - loss: 3942.3181 - gaussian_likelihood: 3928.0352
# Epoch 16/1000
# 1/1 - 0s - loss: 4088.3157 - gaussian_likelihood: 4074.0601
# Epoch 17/1000
# 1/1 - 0s - loss: 3872.8845 - gaussian_likelihood: 3858.6541
# Epoch 18/1000
# 1/1 - 0s - loss: 3693.7573 - gaussian_likelihood: 3679.5215
# Epoch 19/1000
# 1/1 - 0s - loss: 3643.4197 - gaussian_likelihood: 3629.1626
# Epoch 20/1000
# 1/1 - 0s - loss: 3350.9465 - gaussian_likelihood: 3336.6953
# Epoch 21/1000
# 1/1 - 0s - loss: 3328.1404 - gaussian_likelihood: 3313.8462
# Epoch 22/1000
# 1/1 - 0s - loss: 3247.8413 - gaussian_likelihood: 3233.5190
# Epoch 23/1000
# 1/1 - 0s - loss: 2938.4854 - gaussian_likelihood: 2924.1509
# Epoch 24/1000
# 1/1 - 0s - loss: 2948.3044 - gaussian_likelihood: 2933.9927
# Epoch 25/1000
# 1/1 - 0s - loss: 2910.9746 - gaussian_likelihood: 2896.6748
# Epoch 26/1000
# 1/1 - 0s - loss: 3050.4460 - gaussian_likelihood: 3036.1333
# Epoch 27/1000
# 1/1 - 0s - loss: 2732.2336 - gaussian_likelihood: 2717.8857
# Epoch 28/1000
# 1/1 - 0s - loss: 2424.5991 - gaussian_likelihood: 2410.2612
# Epoch 29/1000
# 1/1 - 0s - loss: 2419.3181 - gaussian_likelihood: 2405.0215
# Epoch 30/1000
# 1/1 - 0s - loss: 2462.3809 - gaussian_likelihood: 2448.1006
# Epoch 31/1000
# 1/1 - 0s - loss: 2225.7952 - gaussian_likelihood: 2211.5159
# Epoch 32/1000
# 1/1 - 0s - loss: 2175.3049 - gaussian_likelihood: 2161.0310
# Epoch 33/1000
# 1/1 - 0s - loss: 2068.4194 - gaussian_likelihood: 2054.1484
# Epoch 34/1000
# 1/1 - 0s - loss: 1967.5081 - gaussian_likelihood: 1953.2635
# Epoch 35/1000
# 1/1 - 0s - loss: 1969.2371 - gaussian_likelihood: 1955.0133
# Epoch 36/1000
# 1/1 - 0s - loss: 2022.3071 - gaussian_likelihood: 2008.0864
# Epoch 37/1000
# 1/1 - 0s - loss: 1692.3489 - gaussian_likelihood: 1678.1246
# Epoch 38/1000
# 1/1 - 0s - loss: 1934.2487 - gaussian_likelihood: 1920.0393
# Epoch 39/1000
# 1/1 - 0s - loss: 1772.5665 - gaussian_likelihood: 1758.3290
# Epoch 40/1000
# 1/1 - 0s - loss: 1810.1279 - gaussian_likelihood: 1795.8870
# Epoch 41/1000
# 1/1 - 0s - loss: 1657.2753 - gaussian_likelihood: 1643.0165
# Epoch 42/1000
# 1/1 - 0s - loss: 1550.7008 - gaussian_likelihood: 1536.4192
# Epoch 43/1000
# 1/1 - 0s - loss: 1453.9213 - gaussian_likelihood: 1439.6445
# Epoch 44/1000
# 1/1 - 0s - loss: 1305.8406 - gaussian_likelihood: 1291.5619
# Epoch 45/1000
# 1/1 - 0s - loss: 1372.8572 - gaussian_likelihood: 1358.5837
# Epoch 46/1000
# 1/1 - 0s - loss: 1582.4982 - gaussian_likelihood: 1568.2283
# Epoch 47/1000
# 1/1 - 0s - loss: 1366.2354 - gaussian_likelihood: 1351.8906
# Epoch 48/1000
# 1/1 - 0s - loss: 1165.2512 - gaussian_likelihood: 1150.8838
# Epoch 49/1000
# 1/1 - 0s - loss: 1108.0510 - gaussian_likelihood: 1093.6511
# Epoch 50/1000
# 1/1 - 0s - loss: 1145.5575 - gaussian_likelihood: 1131.1614
# Epoch 51/1000
# 1/1 - 0s - loss: 1315.1403 - gaussian_likelihood: 1300.7307
# Epoch 52/1000
# 1/1 - 0s - loss: 991.0408 - gaussian_likelihood: 976.6105
# Epoch 53/1000
# 1/1 - 0s - loss: 1062.1569 - gaussian_likelihood: 1047.7119
# Epoch 54/1000
# 1/1 - 0s - loss: 989.6887 - gaussian_likelihood: 975.2455
# Epoch 55/1000
# 1/1 - 0s - loss: 950.7766 - gaussian_likelihood: 936.3295
# Epoch 56/1000
# 1/1 - 0s - loss: 1012.6539 - gaussian_likelihood: 998.2041
# Epoch 57/1000
# 1/1 - 0s - loss: 897.8188 - gaussian_likelihood: 883.3543
# Epoch 58/1000
# 1/1 - 0s - loss: 898.7953 - gaussian_likelihood: 884.3323
# Epoch 59/1000
# 1/1 - 0s - loss: 862.4542 - gaussian_likelihood: 847.9856
# Epoch 60/1000
# 1/1 - 0s - loss: 784.5157 - gaussian_likelihood: 770.0442
# Epoch 61/1000
# 1/1 - 0s - loss: 771.5110 - gaussian_likelihood: 757.0250
# Epoch 62/1000
# 1/1 - 0s - loss: 790.6454 - gaussian_likelihood: 776.1592
# Epoch 63/1000
# 1/1 - 0s - loss: 673.5811 - gaussian_likelihood: 659.0681
# Epoch 64/1000
# 1/1 - 0s - loss: 647.2882 - gaussian_likelihood: 632.7741
# Epoch 65/1000
# 1/1 - 0s - loss: 648.8604 - gaussian_likelihood: 634.3501
# Epoch 66/1000
# 1/1 - 0s - loss: 616.0607 - gaussian_likelihood: 601.5449
# Epoch 67/1000
# 1/1 - 0s - loss: 641.0710 - gaussian_likelihood: 626.5648
# Epoch 68/1000
# 1/1 - 0s - loss: 635.1599 - gaussian_likelihood: 620.6517
# Epoch 69/1000
# 1/1 - 0s - loss: 554.7325 - gaussian_likelihood: 540.2241
# Epoch 70/1000
# 1/1 - 0s - loss: 656.2095 - gaussian_likelihood: 641.7034
# Epoch 71/1000
# 1/1 - 0s - loss: 586.4685 - gaussian_likelihood: 571.9530
# Epoch 72/1000
# 1/1 - 0s - loss: 591.3419 - gaussian_likelihood: 576.8172
# Epoch 73/1000
# 1/1 - 0s - loss: 518.7773 - gaussian_likelihood: 504.2504
# Epoch 74/1000
# 1/1 - 0s - loss: 481.4351 - gaussian_likelihood: 466.9121
# Epoch 75/1000
# 1/1 - 0s - loss: 538.9639 - gaussian_likelihood: 524.4387
# Epoch 76/1000
# 1/1 - 0s - loss: 423.5022 - gaussian_likelihood: 408.9807
# Epoch 77/1000
# 1/1 - 0s - loss: 505.6434 - gaussian_likelihood: 491.1342
# Epoch 78/1000
# 1/1 - 0s - loss: 464.6010 - gaussian_likelihood: 450.0758
# Epoch 79/1000
# 1/1 - 0s - loss: 427.5585 - gaussian_likelihood: 413.0266
# Epoch 80/1000
# 1/1 - 0s - loss: 404.2239 - gaussian_likelihood: 389.6994
# Epoch 81/1000
# 1/1 - 0s - loss: 435.1909 - gaussian_likelihood: 420.6550
# Epoch 82/1000
# 1/1 - 0s - loss: 389.2779 - gaussian_likelihood: 374.7433
# Epoch 83/1000
# 1/1 - 0s - loss: 381.3853 - gaussian_likelihood: 366.8526
# Epoch 84/1000
# 1/1 - 0s - loss: 376.4633 - gaussian_likelihood: 361.9295
# Epoch 85/1000
# 1/1 - 0s - loss: 362.6115 - gaussian_likelihood: 348.0797
# Epoch 86/1000
# 1/1 - 0s - loss: 359.9868 - gaussian_likelihood: 345.4246
# Epoch 87/1000
# 1/1 - 0s - loss: 370.3195 - gaussian_likelihood: 355.7401
# Epoch 88/1000
# 1/1 - 0s - loss: 351.8806 - gaussian_likelihood: 337.2972
# Epoch 89/1000
# 1/1 - 0s - loss: 343.1479 - gaussian_likelihood: 328.5604
# Epoch 90/1000
# 1/1 - 0s - loss: 318.4947 - gaussian_likelihood: 303.9081
# Epoch 91/1000
# 1/1 - 0s - loss: 343.9179 - gaussian_likelihood: 329.3363
# Epoch 92/1000
# 1/1 - 0s - loss: 323.1195 - gaussian_likelihood: 308.5380
# Epoch 93/1000
# 1/1 - 0s - loss: 320.6440 - gaussian_likelihood: 306.0667
# Epoch 94/1000
# 1/1 - 0s - loss: 331.0956 - gaussian_likelihood: 316.5190
# Epoch 95/1000
# 1/1 - 0s - loss: 322.8036 - gaussian_likelihood: 308.2234
# Epoch 96/1000
# 1/1 - 0s - loss: 299.2644 - gaussian_likelihood: 284.6738
# Epoch 97/1000
# 1/1 - 0s - loss: 305.8551 - gaussian_likelihood: 291.2492
# Epoch 98/1000
# 1/1 - 0s - loss: 298.7577 - gaussian_likelihood: 284.1407
# Epoch 99/1000
# 1/1 - 0s - loss: 305.3687 - gaussian_likelihood: 290.7506
# Epoch 100/1000
# 1/1 - 0s - loss: 293.2282 - gaussian_likelihood: 278.5935
# Epoch 101/1000
# 1/1 - 0s - loss: 280.5746 - gaussian_likelihood: 265.9087
# Epoch 102/1000
# 1/1 - 0s - loss: 281.9625 - gaussian_likelihood: 267.2714
# Epoch 103/1000
# 1/1 - 0s - loss: 273.9040 - gaussian_likelihood: 259.2087
# Epoch 104/1000
# 1/1 - 0s - loss: 288.2614 - gaussian_likelihood: 273.5674
# Epoch 105/1000
# 1/1 - 0s - loss: 279.1716 - gaussian_likelihood: 264.4820
# Epoch 106/1000
# 1/1 - 0s - loss: 272.8871 - gaussian_likelihood: 258.1940
# Epoch 107/1000
# 1/1 - 0s - loss: 271.2523 - gaussian_likelihood: 256.5459
# Epoch 108/1000
# 1/1 - 0s - loss: 265.0202 - gaussian_likelihood: 250.3153
# Epoch 109/1000
# 1/1 - 0s - loss: 259.2947 - gaussian_likelihood: 244.5928
# Epoch 110/1000
# 1/1 - 0s - loss: 266.4204 - gaussian_likelihood: 251.7161
# Epoch 111/1000
# 1/1 - 0s - loss: 259.2056 - gaussian_likelihood: 244.4825
# Epoch 112/1000
# 1/1 - 0s - loss: 253.3399 - gaussian_likelihood: 238.6196
# Epoch 113/1000
# 1/1 - 0s - loss: 252.4435 - gaussian_likelihood: 237.7262
# Epoch 114/1000
# 1/1 - 0s - loss: 249.2298 - gaussian_likelihood: 234.5171
# Epoch 115/1000
# 1/1 - 0s - loss: 246.1373 - gaussian_likelihood: 231.4220
# Epoch 116/1000
# 1/1 - 0s - loss: 243.7151 - gaussian_likelihood: 229.0038
# Epoch 117/1000
# 1/1 - 0s - loss: 249.5683 - gaussian_likelihood: 234.8585
# Epoch 118/1000
# 1/1 - 0s - loss: 244.9705 - gaussian_likelihood: 230.2505
# Epoch 119/1000
# 1/1 - 0s - loss: 241.0719 - gaussian_likelihood: 226.3427
# Epoch 120/1000
# 1/1 - 0s - loss: 243.1152 - gaussian_likelihood: 228.3862
# Epoch 121/1000
# 1/1 - 0s - loss: 246.6183 - gaussian_likelihood: 231.8828
# Epoch 122/1000
# 1/1 - 0s - loss: 239.7998 - gaussian_likelihood: 225.0319
# Epoch 123/1000
# 1/1 - 0s - loss: 240.3600 - gaussian_likelihood: 225.5869
# Epoch 124/1000
# 1/1 - 0s - loss: 242.4017 - gaussian_likelihood: 227.6251
# Epoch 125/1000
# 1/1 - 0s - loss: 231.6956 - gaussian_likelihood: 216.8887
# Epoch 126/1000
# 1/1 - 0s - loss: 232.0661 - gaussian_likelihood: 217.2576
# Epoch 127/1000
# 1/1 - 0s - loss: 229.8873 - gaussian_likelihood: 215.0747
# Epoch 128/1000
# 1/1 - 0s - loss: 227.7587 - gaussian_likelihood: 212.9452
# Epoch 129/1000
# 1/1 - 0s - loss: 226.6037 - gaussian_likelihood: 211.7846
# Epoch 130/1000
# 1/1 - 0s - loss: 223.7010 - gaussian_likelihood: 208.8846
# Epoch 131/1000
# 1/1 - 0s - loss: 225.7910 - gaussian_likelihood: 210.9779
# Epoch 132/1000
# 1/1 - 0s - loss: 233.9009 - gaussian_likelihood: 219.0870
# Epoch 133/1000
# 1/1 - 0s - loss: 224.0083 - gaussian_likelihood: 209.1801
# Epoch 134/1000
# 1/1 - 0s - loss: 224.0828 - gaussian_likelihood: 209.2567
# Epoch 135/1000
# 1/1 - 0s - loss: 222.5324 - gaussian_likelihood: 207.6906
# Epoch 136/1000
# 1/1 - 0s - loss: 221.6609 - gaussian_likelihood: 206.8064
# Epoch 137/1000
# 1/1 - 0s - loss: 218.5429 - gaussian_likelihood: 203.6744
# Epoch 138/1000
# 1/1 - 0s - loss: 216.0525 - gaussian_likelihood: 201.1769
# Epoch 139/1000
# 1/1 - 0s - loss: 212.7662 - gaussian_likelihood: 197.8868
# Epoch 140/1000
# 1/1 - 0s - loss: 212.6977 - gaussian_likelihood: 197.8208
# Epoch 141/1000
# 1/1 - 0s - loss: 212.3780 - gaussian_likelihood: 197.5045
# Epoch 142/1000
# 1/1 - 0s - loss: 211.3655 - gaussian_likelihood: 196.4935
# Epoch 143/1000
# 1/1 - 0s - loss: 213.5083 - gaussian_likelihood: 198.6398
# Epoch 144/1000
# 1/1 - 0s - loss: 209.3876 - gaussian_likelihood: 194.5175
# Epoch 145/1000
# 1/1 - 0s - loss: 207.6949 - gaussian_likelihood: 192.8264
# Epoch 146/1000
# 1/1 - 0s - loss: 208.4865 - gaussian_likelihood: 193.6200
# Epoch 147/1000
# 1/1 - 0s - loss: 208.8068 - gaussian_likelihood: 193.9295
# Epoch 148/1000
# 1/1 - 0s - loss: 204.0650 - gaussian_likelihood: 189.1910
# Epoch 149/1000
# 1/1 - 0s - loss: 202.7725 - gaussian_likelihood: 187.9029
# Epoch 150/1000
# 1/1 - 0s - loss: 204.8749 - gaussian_likelihood: 190.0097
# Epoch 151/1000
# 1/1 - 0s - loss: 200.9286 - gaussian_likelihood: 186.0681
# Epoch 152/1000
# 1/1 - 0s - loss: 200.0785 - gaussian_likelihood: 185.2227
# Epoch 153/1000
# 1/1 - 0s - loss: 206.8644 - gaussian_likelihood: 192.0030
# Epoch 154/1000
# 1/1 - 0s - loss: 212.0248 - gaussian_likelihood: 197.1670
# Epoch 155/1000
# 1/1 - 0s - loss: 200.5848 - gaussian_likelihood: 185.7304
# Epoch 156/1000
# 1/1 - 0s - loss: 215.0649 - gaussian_likelihood: 200.2164
# Epoch 157/1000
# 1/1 - 0s - loss: 203.2229 - gaussian_likelihood: 188.3775
# Epoch 158/1000
# 1/1 - 0s - loss: 200.6838 - gaussian_likelihood: 185.8393
# Epoch 159/1000
# 1/1 - 0s - loss: 195.3289 - gaussian_likelihood: 180.4906
# Epoch 160/1000
# 1/1 - 0s - loss: 206.5760 - gaussian_likelihood: 191.7451
# Epoch 161/1000
# 1/1 - 0s - loss: 192.6386 - gaussian_likelihood: 177.7537
# Epoch 162/1000
# 1/1 - 0s - loss: 194.2876 - gaussian_likelihood: 179.4054
# Epoch 163/1000
# 1/1 - 0s - loss: 192.4540 - gaussian_likelihood: 177.5558
# Epoch 164/1000
# 1/1 - 0s - loss: 192.5824 - gaussian_likelihood: 177.6846
# Epoch 165/1000
# 1/1 - 0s - loss: 190.2136 - gaussian_likelihood: 175.3170
# Epoch 166/1000
# 1/1 - 0s - loss: 190.9479 - gaussian_likelihood: 176.0514
# Epoch 167/1000
# 1/1 - 0s - loss: 192.3509 - gaussian_likelihood: 177.4597
# Epoch 168/1000
# 1/1 - 0s - loss: 185.2645 - gaussian_likelihood: 170.3443
# Epoch 169/1000
# 1/1 - 0s - loss: 187.4444 - gaussian_likelihood: 172.5208
# Epoch 170/1000
# 1/1 - 0s - loss: 189.7738 - gaussian_likelihood: 174.8293
# Epoch 171/1000
# 1/1 - 0s - loss: 187.9438 - gaussian_likelihood: 172.9783
# Epoch 172/1000
# 1/1 - 0s - loss: 181.2427 - gaussian_likelihood: 166.2753
# Epoch 173/1000
# 1/1 - 0s - loss: 191.5336 - gaussian_likelihood: 176.5688
# Epoch 174/1000
# 1/1 - 0s - loss: 183.2449 - gaussian_likelihood: 168.2788
# Epoch 175/1000
# 1/1 - 0s - loss: 186.9946 - gaussian_likelihood: 172.0321
# Epoch 176/1000
# 1/1 - 0s - loss: 186.1269 - gaussian_likelihood: 171.1497
# Epoch 177/1000
# 1/1 - 0s - loss: 178.7374 - gaussian_likelihood: 163.7515
# Epoch 178/1000
# 1/1 - 0s - loss: 180.1326 - gaussian_likelihood: 165.1494
# Epoch 179/1000
# 1/1 - 0s - loss: 178.6251 - gaussian_likelihood: 163.6449
# Epoch 180/1000
# 1/1 - 0s - loss: 177.4110 - gaussian_likelihood: 162.4262
# Epoch 181/1000
# 1/1 - 0s - loss: 181.2482 - gaussian_likelihood: 166.2685
# Epoch 182/1000
# 1/1 - 0s - loss: 185.6992 - gaussian_likelihood: 170.7244
# Epoch 183/1000
# 1/1 - 0s - loss: 176.0511 - gaussian_likelihood: 161.0781
# Epoch 184/1000
# 1/1 - 0s - loss: 179.9954 - gaussian_likelihood: 165.0168
# Epoch 185/1000
# 1/1 - 0s - loss: 179.8996 - gaussian_likelihood: 164.9217
# Epoch 186/1000
# 1/1 - 0s - loss: 172.5442 - gaussian_likelihood: 157.5657
# Epoch 187/1000
# 1/1 - 0s - loss: 169.3828 - gaussian_likelihood: 154.4092
# Epoch 188/1000
# 1/1 - 0s - loss: 179.9828 - gaussian_likelihood: 165.0164
# Epoch 189/1000
# 1/1 - 0s - loss: 169.3617 - gaussian_likelihood: 154.3980
# Epoch 190/1000
# 1/1 - 0s - loss: 173.2407 - gaussian_likelihood: 158.2854
# Epoch 191/1000
# 1/1 - 0s - loss: 177.6747 - gaussian_likelihood: 162.7245
# Epoch 192/1000
# 1/1 - 0s - loss: 170.7032 - gaussian_likelihood: 155.7504
# Epoch 193/1000
# 1/1 - 0s - loss: 168.2369 - gaussian_likelihood: 153.2792
# Epoch 194/1000
# 1/1 - 0s - loss: 167.6575 - gaussian_likelihood: 152.7053
# Epoch 195/1000
# 1/1 - 0s - loss: 169.6018 - gaussian_likelihood: 154.6549
# Epoch 196/1000
# 1/1 - 0s - loss: 173.0045 - gaussian_likelihood: 158.0635
# Epoch 197/1000
# 1/1 - 0s - loss: 174.8910 - gaussian_likelihood: 159.9362
# Epoch 198/1000
# 1/1 - 0s - loss: 169.2784 - gaussian_likelihood: 154.3287
# Epoch 199/1000
# 1/1 - 0s - loss: 170.6606 - gaussian_likelihood: 155.7137
# Epoch 200/1000
# 1/1 - 0s - loss: 164.4868 - gaussian_likelihood: 149.5386
# Epoch 201/1000
# 1/1 - 0s - loss: 165.1819 - gaussian_likelihood: 150.2333
# Epoch 202/1000
# 1/1 - 0s - loss: 168.1639 - gaussian_likelihood: 153.2197
# Epoch 203/1000
# 1/1 - 0s - loss: 163.1732 - gaussian_likelihood: 148.2348
# Epoch 204/1000
# 1/1 - 0s - loss: 176.4066 - gaussian_likelihood: 161.4489
# Epoch 205/1000
# 1/1 - 0s - loss: 160.1210 - gaussian_likelihood: 145.1479
# Epoch 206/1000
# 1/1 - 0s - loss: 158.9843 - gaussian_likelihood: 144.0142
# Epoch 207/1000
# 1/1 - 0s - loss: 157.1702 - gaussian_likelihood: 142.1977
# Epoch 208/1000
# 1/1 - 0s - loss: 169.3112 - gaussian_likelihood: 154.3426
# Epoch 209/1000
# 1/1 - 0s - loss: 160.8760 - gaussian_likelihood: 145.9029
# Epoch 210/1000
# 1/1 - 0s - loss: 159.1345 - gaussian_likelihood: 144.1635
# Epoch 211/1000
# 1/1 - 0s - loss: 154.1526 - gaussian_likelihood: 139.1700
# Epoch 212/1000
# 1/1 - 0s - loss: 157.9592 - gaussian_likelihood: 142.9760
# Epoch 213/1000
# 1/1 - 0s - loss: 154.9504 - gaussian_likelihood: 139.9692
# Epoch 214/1000
# 1/1 - 0s - loss: 152.7948 - gaussian_likelihood: 137.8200
# Epoch 215/1000
# 1/1 - 0s - loss: 165.4632 - gaussian_likelihood: 150.4886
# Epoch 216/1000
# 1/1 - 0s - loss: 150.7092 - gaussian_likelihood: 135.7312
# Epoch 217/1000
# 1/1 - 0s - loss: 156.3047 - gaussian_likelihood: 141.3322
# Epoch 218/1000
# 1/1 - 0s - loss: 151.6737 - gaussian_likelihood: 136.7063
# Epoch 219/1000
# 1/1 - 0s - loss: 155.5162 - gaussian_likelihood: 140.5426
# Epoch 220/1000
# 1/1 - 0s - loss: 149.0010 - gaussian_likelihood: 134.0283
# Epoch 221/1000
# 1/1 - 0s - loss: 148.4622 - gaussian_likelihood: 133.4950
# Epoch 222/1000
# 1/1 - 0s - loss: 153.0734 - gaussian_likelihood: 138.1149
# Epoch 223/1000
# 1/1 - 0s - loss: 166.2600 - gaussian_likelihood: 151.2924
# Epoch 224/1000
# 1/1 - 0s - loss: 150.3657 - gaussian_likelihood: 135.3913
# Epoch 225/1000
# 1/1 - 0s - loss: 151.3112 - gaussian_likelihood: 136.3408
# Epoch 226/1000
# 1/1 - 0s - loss: 151.9170 - gaussian_likelihood: 136.9124
# Epoch 227/1000
# 1/1 - 0s - loss: 147.7958 - gaussian_likelihood: 132.7876
# Epoch 228/1000
# 1/1 - 0s - loss: 144.2989 - gaussian_likelihood: 129.2873
# Epoch 229/1000
# 1/1 - 0s - loss: 160.2182 - gaussian_likelihood: 145.2064
# Epoch 230/1000
# 1/1 - 0s - loss: 146.5321 - gaussian_likelihood: 131.5207
# Epoch 231/1000
# 1/1 - 0s - loss: 151.7311 - gaussian_likelihood: 136.7209
# Epoch 232/1000
# 1/1 - 0s - loss: 144.0392 - gaussian_likelihood: 129.0260
# Epoch 233/1000
# 1/1 - 0s - loss: 144.9667 - gaussian_likelihood: 129.9492
# Epoch 234/1000
# 1/1 - 0s - loss: 139.2466 - gaussian_likelihood: 124.2350
# Epoch 235/1000
# 1/1 - 0s - loss: 139.0400 - gaussian_likelihood: 124.0328
# Epoch 236/1000
# 1/1 - 0s - loss: 150.0928 - gaussian_likelihood: 135.0895
# Epoch 237/1000
# 1/1 - 0s - loss: 139.9760 - gaussian_likelihood: 124.9674
# Epoch 238/1000
# 1/1 - 0s - loss: 142.2022 - gaussian_likelihood: 127.1939
# Epoch 239/1000
# 1/1 - 0s - loss: 148.5118 - gaussian_likelihood: 133.5058
# Epoch 240/1000
# 1/1 - 0s - loss: 138.0476 - gaussian_likelihood: 123.0365
# Epoch 241/1000
# 1/1 - 0s - loss: 143.6277 - gaussian_likelihood: 128.6208
# Epoch 242/1000
# 1/1 - 0s - loss: 136.8089 - gaussian_likelihood: 121.7871
# Epoch 243/1000
# 1/1 - 0s - loss: 137.7825 - gaussian_likelihood: 122.7570
# Epoch 244/1000
# 1/1 - 0s - loss: 142.8095 - gaussian_likelihood: 127.7776
# Epoch 245/1000
# 1/1 - 0s - loss: 135.3948 - gaussian_likelihood: 120.3648
# Epoch 246/1000
# 1/1 - 0s - loss: 145.4545 - gaussian_likelihood: 130.4190
# Epoch 247/1000
# 1/1 - 0s - loss: 135.2187 - gaussian_likelihood: 120.1866
# Epoch 248/1000
# 1/1 - 0s - loss: 130.9226 - gaussian_likelihood: 115.8891
# Epoch 249/1000
# 1/1 - 0s - loss: 133.0388 - gaussian_likelihood: 118.0094
# Epoch 250/1000
# 1/1 - 0s - loss: 138.3299 - gaussian_likelihood: 123.2938
# Epoch 251/1000
# 1/1 - 0s - loss: 142.9472 - gaussian_likelihood: 127.8766
# Epoch 252/1000
# 1/1 - 0s - loss: 129.4097 - gaussian_likelihood: 114.2915
# Epoch 253/1000
# 1/1 - 0s - loss: 141.1038 - gaussian_likelihood: 125.9872
# Epoch 254/1000
# 1/1 - 0s - loss: 134.1704 - gaussian_likelihood: 119.0414
# Epoch 255/1000
# 1/1 - 0s - loss: 133.0861 - gaussian_likelihood: 117.9552
# Epoch 256/1000
# 1/1 - 0s - loss: 134.0426 - gaussian_likelihood: 118.9104
# Epoch 257/1000
# 1/1 - 0s - loss: 136.2209 - gaussian_likelihood: 121.0902
# Epoch 258/1000
# 1/1 - 0s - loss: 129.8671 - gaussian_likelihood: 114.7320
# Epoch 259/1000
# 1/1 - 0s - loss: 130.2478 - gaussian_likelihood: 115.1091
# Epoch 260/1000
# 1/1 - 0s - loss: 130.5151 - gaussian_likelihood: 115.3770
# Epoch 261/1000
# 1/1 - 0s - loss: 130.9388 - gaussian_likelihood: 115.7952
# Epoch 262/1000
# 1/1 - 0s - loss: 124.8484 - gaussian_likelihood: 109.7080
# Epoch 263/1000
# 1/1 - 0s - loss: 124.0790 - gaussian_likelihood: 108.9419
# Epoch 264/1000
# 1/1 - 0s - loss: 132.4105 - gaussian_likelihood: 117.2708
# Epoch 265/1000
# 1/1 - 0s - loss: 123.0287 - gaussian_likelihood: 107.8889
# Epoch 266/1000
# 1/1 - 0s - loss: 122.9147 - gaussian_likelihood: 107.7775
# Epoch 267/1000
# 1/1 - 0s - loss: 125.2369 - gaussian_likelihood: 110.1053
# Epoch 268/1000
# 1/1 - 0s - loss: 122.2395 - gaussian_likelihood: 107.1123
# Epoch 269/1000
# 1/1 - 0s - loss: 134.4095 - gaussian_likelihood: 119.2857
# Epoch 270/1000
# 1/1 - 0s - loss: 126.2596 - gaussian_likelihood: 111.1394
# Epoch 271/1000
# 1/1 - 0s - loss: 126.1214 - gaussian_likelihood: 111.0083
# Epoch 272/1000
# 1/1 - 0s - loss: 120.3007 - gaussian_likelihood: 105.1968
# Epoch 273/1000
# 1/1 - 0s - loss: 119.2669 - gaussian_likelihood: 104.1695
# Epoch 274/1000
# 1/1 - 0s - loss: 117.6274 - gaussian_likelihood: 102.5348
# Epoch 275/1000
# 1/1 - 0s - loss: 120.2492 - gaussian_likelihood: 105.1609
# Epoch 276/1000
# 1/1 - 0s - loss: 123.0459 - gaussian_likelihood: 107.9555
# Epoch 277/1000
# 1/1 - 0s - loss: 117.5846 - gaussian_likelihood: 102.4986
# Epoch 278/1000
# 1/1 - 0s - loss: 117.7613 - gaussian_likelihood: 102.6711
# Epoch 279/1000
# 1/1 - 0s - loss: 114.7533 - gaussian_likelihood: 99.6679
# Epoch 280/1000
# 1/1 - 0s - loss: 118.8096 - gaussian_likelihood: 103.7328
# Epoch 281/1000
# 1/1 - 0s - loss: 114.2516 - gaussian_likelihood: 99.1798
# Epoch 282/1000
# 1/1 - 0s - loss: 117.8118 - gaussian_likelihood: 102.7496
# Epoch 283/1000
# 1/1 - 0s - loss: 111.5382 - gaussian_likelihood: 96.4827
# Epoch 284/1000
# 1/1 - 0s - loss: 117.6465 - gaussian_likelihood: 102.6010
# Epoch 285/1000
# 1/1 - 0s - loss: 114.0783 - gaussian_likelihood: 99.0359
# Epoch 286/1000
# 1/1 - 0s - loss: 113.3457 - gaussian_likelihood: 98.3129
# Epoch 287/1000
# 1/1 - 0s - loss: 118.0783 - gaussian_likelihood: 103.0516
# Epoch 288/1000
# 1/1 - 0s - loss: 120.8652 - gaussian_likelihood: 105.8430
# Epoch 289/1000
# 1/1 - 0s - loss: 109.6056 - gaussian_likelihood: 94.5860
# Epoch 290/1000
# 1/1 - 0s - loss: 107.2384 - gaussian_likelihood: 92.2247
# Epoch 291/1000
# 1/1 - 0s - loss: 110.4796 - gaussian_likelihood: 95.4784
# Epoch 292/1000
# 1/1 - 0s - loss: 108.7782 - gaussian_likelihood: 93.7870
# Epoch 293/1000
# 1/1 - 0s - loss: 114.8659 - gaussian_likelihood: 99.8788
# Epoch 294/1000
# 1/1 - 0s - loss: 108.0741 - gaussian_likelihood: 93.0902
# Epoch 295/1000
# 1/1 - 0s - loss: 107.4816 - gaussian_likelihood: 92.5071
# Epoch 296/1000
# 1/1 - 0s - loss: 108.0027 - gaussian_likelihood: 93.0377
# Epoch 297/1000
# 1/1 - 0s - loss: 105.3572 - gaussian_likelihood: 90.3925
# Epoch 298/1000
# 1/1 - 0s - loss: 107.5643 - gaussian_likelihood: 92.6071
# Epoch 299/1000
# 1/1 - 0s - loss: 111.4132 - gaussian_likelihood: 96.4576
# Epoch 300/1000
# 1/1 - 0s - loss: 105.1607 - gaussian_likelihood: 90.2121
# Epoch 301/1000
# 1/1 - 0s - loss: 104.8023 - gaussian_likelihood: 89.8536
# Epoch 302/1000
# 1/1 - 0s - loss: 117.1022 - gaussian_likelihood: 102.1609
# Epoch 303/1000
# 1/1 - 0s - loss: 104.3648 - gaussian_likelihood: 89.4264
# Epoch 304/1000
# 1/1 - 0s - loss: 107.9733 - gaussian_likelihood: 93.0452
# Epoch 305/1000
# 1/1 - 0s - loss: 103.8815 - gaussian_likelihood: 88.9552
# Epoch 306/1000
# 1/1 - 0s - loss: 104.9713 - gaussian_likelihood: 90.0497
# Epoch 307/1000
# 1/1 - 0s - loss: 111.7440 - gaussian_likelihood: 96.8146
# Epoch 308/1000
# 1/1 - 0s - loss: 108.2307 - gaussian_likelihood: 93.2951
# Epoch 309/1000
# 1/1 - 0s - loss: 119.2432 - gaussian_likelihood: 104.3040
# Epoch 310/1000
# 1/1 - 0s - loss: 104.8196 - gaussian_likelihood: 89.8607
# Epoch 311/1000
# 1/1 - 0s - loss: 100.7209 - gaussian_likelihood: 85.7645
# Epoch 312/1000
# 1/1 - 0s - loss: 112.0010 - gaussian_likelihood: 97.0496
# Epoch 313/1000
# 1/1 - 0s - loss: 99.4538 - gaussian_likelihood: 84.5065
# Epoch 314/1000
# 1/1 - 0s - loss: 99.9178 - gaussian_likelihood: 84.9788
# Epoch 315/1000
# 1/1 - 0s - loss: 111.8069 - gaussian_likelihood: 96.8687
# Epoch 316/1000
# 1/1 - 0s - loss: 106.0347 - gaussian_likelihood: 91.0993
# Epoch 317/1000
# 1/1 - 0s - loss: 98.0505 - gaussian_likelihood: 83.1151
# Epoch 318/1000
# 1/1 - 0s - loss: 99.3335 - gaussian_likelihood: 84.4037
# Epoch 319/1000
# 1/1 - 0s - loss: 101.0400 - gaussian_likelihood: 86.0970
# Epoch 320/1000
# 1/1 - 0s - loss: 99.1593 - gaussian_likelihood: 84.2211
# Epoch 321/1000
# 1/1 - 0s - loss: 106.6268 - gaussian_likelihood: 91.6958
# Epoch 322/1000
# 1/1 - 0s - loss: 94.9805 - gaussian_likelihood: 80.0432
# Epoch 323/1000
# 1/1 - 0s - loss: 95.7123 - gaussian_likelihood: 80.7815
# Epoch 324/1000
# 1/1 - 0s - loss: 101.3048 - gaussian_likelihood: 86.3803
# Epoch 325/1000
# 1/1 - 0s - loss: 98.1528 - gaussian_likelihood: 83.2216
# Epoch 326/1000
# 1/1 - 0s - loss: 108.9888 - gaussian_likelihood: 94.0626
# Epoch 327/1000
# 1/1 - 0s - loss: 104.4248 - gaussian_likelihood: 89.4981
# Epoch 328/1000
# 1/1 - 0s - loss: 94.2579 - gaussian_likelihood: 79.3229
# Epoch 329/1000
# 1/1 - 0s - loss: 92.2548 - gaussian_likelihood: 77.3214
# Epoch 330/1000
# 1/1 - 0s - loss: 99.5128 - gaussian_likelihood: 84.5871
# Epoch 331/1000
# 1/1 - 0s - loss: 98.6116 - gaussian_likelihood: 83.6821
# Epoch 332/1000
# 1/1 - 0s - loss: 93.6580 - gaussian_likelihood: 78.7122
# Epoch 333/1000
# 1/1 - 0s - loss: 94.0766 - gaussian_likelihood: 79.1241
# Epoch 334/1000
# 1/1 - 0s - loss: 96.2925 - gaussian_likelihood: 81.3418
# Epoch 335/1000
# 1/1 - 0s - loss: 92.3090 - gaussian_likelihood: 77.3435
# Epoch 336/1000
# 1/1 - 0s - loss: 93.9042 - gaussian_likelihood: 78.9435
# Epoch 337/1000
# 1/1 - 0s - loss: 94.9515 - gaussian_likelihood: 79.9925
# Epoch 338/1000
# 1/1 - 0s - loss: 89.6419 - gaussian_likelihood: 74.6871
# Epoch 339/1000
# 1/1 - 0s - loss: 90.5005 - gaussian_likelihood: 75.5470
# Epoch 340/1000
# 1/1 - 0s - loss: 90.3287 - gaussian_likelihood: 75.3685
# Epoch 341/1000
# 1/1 - 0s - loss: 96.9621 - gaussian_likelihood: 81.9966
# Epoch 342/1000
# 1/1 - 0s - loss: 94.1111 - gaussian_likelihood: 79.1422
# Epoch 343/1000
# 1/1 - 0s - loss: 90.9191 - gaussian_likelihood: 75.9429
# Epoch 344/1000
# 1/1 - 0s - loss: 99.5954 - gaussian_likelihood: 84.6127
# Epoch 345/1000
# 1/1 - 0s - loss: 89.7854 - gaussian_likelihood: 74.7842
# Epoch 346/1000
# 1/1 - 0s - loss: 85.5612 - gaussian_likelihood: 70.5624
# Epoch 347/1000
# 1/1 - 0s - loss: 89.3038 - gaussian_likelihood: 74.3103
# Epoch 348/1000
# 1/1 - 0s - loss: 88.1430 - gaussian_likelihood: 73.1568
# Epoch 349/1000
# 1/1 - 0s - loss: 93.5003 - gaussian_likelihood: 78.5071
# Epoch 350/1000
# 1/1 - 0s - loss: 87.5518 - gaussian_likelihood: 72.5546
# Epoch 351/1000
# 1/1 - 0s - loss: 85.9908 - gaussian_likelihood: 70.9753
# Epoch 352/1000
# 1/1 - 0s - loss: 87.9978 - gaussian_likelihood: 72.9859
# Epoch 353/1000
# 1/1 - 0s - loss: 84.6788 - gaussian_likelihood: 69.6656
# Epoch 354/1000
# 1/1 - 0s - loss: 84.9318 - gaussian_likelihood: 69.9170
# Epoch 355/1000
# 1/1 - 0s - loss: 84.4998 - gaussian_likelihood: 69.4873
# Epoch 356/1000
# 1/1 - 0s - loss: 98.5623 - gaussian_likelihood: 83.5543
# Epoch 357/1000
# 1/1 - 0s - loss: 82.7695 - gaussian_likelihood: 67.7515
# Epoch 358/1000
# 1/1 - 0s - loss: 88.5824 - gaussian_likelihood: 73.5641
# Epoch 359/1000
# 1/1 - 0s - loss: 81.2815 - gaussian_likelihood: 66.2499
# Epoch 360/1000
# 1/1 - 0s - loss: 83.2058 - gaussian_likelihood: 68.1749
# Epoch 361/1000
# 1/1 - 0s - loss: 81.3017 - gaussian_likelihood: 66.2710
# Epoch 362/1000
# 1/1 - 0s - loss: 88.8981 - gaussian_likelihood: 73.8664
# Epoch 363/1000
# 1/1 - 0s - loss: 79.9554 - gaussian_likelihood: 64.9118
# Epoch 364/1000
# 1/1 - 0s - loss: 89.8961 - gaussian_likelihood: 74.8521
# Epoch 365/1000
# 1/1 - 0s - loss: 79.2782 - gaussian_likelihood: 64.2208
# Epoch 366/1000
# 1/1 - 0s - loss: 80.4596 - gaussian_likelihood: 65.4019
# Epoch 367/1000
# 1/1 - 0s - loss: 80.2440 - gaussian_likelihood: 65.1730
# Epoch 368/1000
# 1/1 - 0s - loss: 79.2409 - gaussian_likelihood: 64.1729
# Epoch 369/1000
# 1/1 - 0s - loss: 77.1488 - gaussian_likelihood: 62.0788
# Epoch 370/1000
# 1/1 - 0s - loss: 80.3333 - gaussian_likelihood: 65.2658
# Epoch 371/1000
# 1/1 - 0s - loss: 76.5254 - gaussian_likelihood: 61.4643
# Epoch 372/1000
# 1/1 - 0s - loss: 80.7346 - gaussian_likelihood: 65.6766
# Epoch 373/1000
# 1/1 - 0s - loss: 81.4847 - gaussian_likelihood: 66.4131
# Epoch 374/1000
# 1/1 - 0s - loss: 76.1225 - gaussian_likelihood: 61.0544
# Epoch 375/1000
# 1/1 - 0s - loss: 78.3009 - gaussian_likelihood: 63.2386
# Epoch 376/1000
# 1/1 - 0s - loss: 78.5332 - gaussian_likelihood: 63.4757
# Epoch 377/1000
# 1/1 - 0s - loss: 82.9532 - gaussian_likelihood: 67.8999
# Epoch 378/1000
# 1/1 - 0s - loss: 74.8416 - gaussian_likelihood: 59.7885
# Epoch 379/1000
# 1/1 - 0s - loss: 76.4920 - gaussian_likelihood: 61.4444
# Epoch 380/1000
# 1/1 - 0s - loss: 77.2644 - gaussian_likelihood: 62.2214
# Epoch 381/1000
# 1/1 - 0s - loss: 73.3539 - gaussian_likelihood: 58.3133
# Epoch 382/1000
# 1/1 - 0s - loss: 75.4601 - gaussian_likelihood: 60.4220
# Epoch 383/1000
# 1/1 - 0s - loss: 73.3530 - gaussian_likelihood: 58.3187
# Epoch 384/1000
# 1/1 - 0s - loss: 72.1730 - gaussian_likelihood: 57.1317
# Epoch 385/1000
# 1/1 - 0s - loss: 91.1679 - gaussian_likelihood: 76.1319
# Epoch 386/1000
# 1/1 - 0s - loss: 76.0663 - gaussian_likelihood: 61.0330
# Epoch 387/1000
# 1/1 - 0s - loss: 72.6670 - gaussian_likelihood: 57.6289
# Epoch 388/1000
# 1/1 - 0s - loss: 71.2315 - gaussian_likelihood: 56.2003
# Epoch 389/1000
# 1/1 - 0s - loss: 78.8058 - gaussian_likelihood: 63.7807
# Epoch 390/1000
# 1/1 - 0s - loss: 75.9520 - gaussian_likelihood: 60.9269
# Epoch 391/1000
# 1/1 - 0s - loss: 69.1818 - gaussian_likelihood: 54.1623
# Epoch 392/1000
# 1/1 - 0s - loss: 74.3848 - gaussian_likelihood: 59.3757
# Epoch 393/1000
# 1/1 - 0s - loss: 76.2502 - gaussian_likelihood: 61.2471
# Epoch 394/1000
# 1/1 - 0s - loss: 80.1513 - gaussian_likelihood: 65.1549
# Epoch 395/1000
# 1/1 - 0s - loss: 78.4425 - gaussian_likelihood: 63.4364
# Epoch 396/1000
# 1/1 - 0s - loss: 70.6743 - gaussian_likelihood: 55.6629
# Epoch 397/1000
# 1/1 - 0s - loss: 68.9355 - gaussian_likelihood: 53.9272
# Epoch 398/1000
# 1/1 - 0s - loss: 70.3907 - gaussian_likelihood: 55.3878
# Epoch 399/1000
# 1/1 - 0s - loss: 70.1449 - gaussian_likelihood: 55.1514
# Epoch 400/1000
# 1/1 - 0s - loss: 69.4711 - gaussian_likelihood: 54.4836
# Epoch 401/1000
# 1/1 - 0s - loss: 80.6636 - gaussian_likelihood: 65.6755
# Epoch 402/1000
# 1/1 - 0s - loss: 68.4132 - gaussian_likelihood: 53.3944
# Epoch 403/1000
# 1/1 - 0s - loss: 70.3764 - gaussian_likelihood: 55.3619
# Epoch 404/1000
# 1/1 - 0s - loss: 67.5652 - gaussian_likelihood: 52.5524
# Epoch 405/1000
# 1/1 - 0s - loss: 65.7045 - gaussian_likelihood: 50.6985
# Epoch 406/1000
# 1/1 - 0s - loss: 70.4004 - gaussian_likelihood: 55.4027
# Epoch 407/1000
# 1/1 - 0s - loss: 66.0147 - gaussian_likelihood: 50.9905
# Epoch 408/1000
# 1/1 - 0s - loss: 70.0496 - gaussian_likelihood: 55.0260
# Epoch 409/1000
# 1/1 - 0s - loss: 69.6076 - gaussian_likelihood: 54.5903
# Epoch 410/1000
# 1/1 - 0s - loss: 65.9088 - gaussian_likelihood: 50.8849
# Epoch 411/1000
# 1/1 - 0s - loss: 64.6596 - gaussian_likelihood: 49.6374
# Epoch 412/1000
# 1/1 - 0s - loss: 68.4456 - gaussian_likelihood: 53.4257
# Epoch 413/1000
# 1/1 - 0s - loss: 68.3010 - gaussian_likelihood: 53.2579
# Epoch 414/1000
# 1/1 - 0s - loss: 62.5973 - gaussian_likelihood: 47.5482
# Epoch 415/1000
# 1/1 - 0s - loss: 69.6973 - gaussian_likelihood: 54.6548
# Epoch 416/1000
# 1/1 - 0s - loss: 64.4693 - gaussian_likelihood: 49.4301
# Epoch 417/1000
# 1/1 - 0s - loss: 67.6061 - gaussian_likelihood: 52.5727
# Epoch 418/1000
# 1/1 - 0s - loss: 62.9869 - gaussian_likelihood: 47.9539
# Epoch 419/1000
# 1/1 - 0s - loss: 62.0608 - gaussian_likelihood: 47.0227
# Epoch 420/1000
# 1/1 - 0s - loss: 64.3907 - gaussian_likelihood: 49.3570
# Epoch 421/1000
# 1/1 - 0s - loss: 66.6419 - gaussian_likelihood: 51.6068
# Epoch 422/1000
# 1/1 - 0s - loss: 60.2821 - gaussian_likelihood: 45.2524
# Epoch 423/1000
# 1/1 - 0s - loss: 63.5192 - gaussian_likelihood: 48.4990
# Epoch 424/1000
# 1/1 - 0s - loss: 64.2251 - gaussian_likelihood: 49.2124
# Epoch 425/1000
# 1/1 - 0s - loss: 68.2629 - gaussian_likelihood: 53.2592
# Epoch 426/1000
# 1/1 - 0s - loss: 66.7031 - gaussian_likelihood: 51.7034
# Epoch 427/1000
# 1/1 - 0s - loss: 73.2215 - gaussian_likelihood: 58.2125
# Epoch 428/1000
# 1/1 - 0s - loss: 69.0125 - gaussian_likelihood: 54.0052
# Epoch 429/1000
# 1/1 - 0s - loss: 59.4338 - gaussian_likelihood: 44.3785
# Epoch 430/1000
# 1/1 - 0s - loss: 59.4094 - gaussian_likelihood: 44.3559
# Epoch 431/1000
# 1/1 - 0s - loss: 59.9634 - gaussian_likelihood: 44.9042
# Epoch 432/1000
# 1/1 - 0s - loss: 60.7426 - gaussian_likelihood: 45.6792
# Epoch 433/1000
# 1/1 - 0s - loss: 63.4911 - gaussian_likelihood: 48.4320
# Epoch 434/1000
# 1/1 - 0s - loss: 57.9717 - gaussian_likelihood: 42.9113
# Epoch 435/1000
# 1/1 - 0s - loss: 57.5353 - gaussian_likelihood: 42.4771
# Epoch 436/1000
# 1/1 - 0s - loss: 58.6567 - gaussian_likelihood: 43.6037
# Epoch 437/1000
# 1/1 - 0s - loss: 57.5627 - gaussian_likelihood: 42.5043
# Epoch 438/1000
# 1/1 - 0s - loss: 55.8046 - gaussian_likelihood: 40.7512
# Epoch 439/1000
# 1/1 - 0s - loss: 62.0477 - gaussian_likelihood: 47.0002
# Epoch 440/1000
# 1/1 - 0s - loss: 58.1210 - gaussian_likelihood: 43.0752
# Epoch 441/1000
# 1/1 - 0s - loss: 55.3543 - gaussian_likelihood: 40.3081
# Epoch 442/1000
# 1/1 - 0s - loss: 58.9212 - gaussian_likelihood: 43.8790
# Epoch 443/1000
# 1/1 - 0s - loss: 55.9359 - gaussian_likelihood: 40.8833
# Epoch 444/1000
# 1/1 - 0s - loss: 54.4940 - gaussian_likelihood: 39.4330
# Epoch 445/1000
# 1/1 - 0s - loss: 56.2041 - gaussian_likelihood: 41.1446
# Epoch 446/1000
# 1/1 - 0s - loss: 54.8018 - gaussian_likelihood: 39.7414
# Epoch 447/1000
# 1/1 - 0s - loss: 54.9577 - gaussian_likelihood: 39.8924
# Epoch 448/1000
# 1/1 - 0s - loss: 54.9820 - gaussian_likelihood: 39.9205
# Epoch 449/1000
# 1/1 - 0s - loss: 53.0347 - gaussian_likelihood: 37.9632
# Epoch 450/1000
# 1/1 - 0s - loss: 56.4094 - gaussian_likelihood: 41.3379
# Epoch 451/1000
# 1/1 - 0s - loss: 53.0760 - gaussian_likelihood: 37.9930
# Epoch 452/1000
# 1/1 - 0s - loss: 62.4128 - gaussian_likelihood: 47.3191
# Epoch 453/1000
# 1/1 - 0s - loss: 53.8186 - gaussian_likelihood: 38.7265
# Epoch 454/1000
# 1/1 - 0s - loss: 56.7542 - gaussian_likelihood: 41.6591
# Epoch 455/1000
# 1/1 - 0s - loss: 57.4756 - gaussian_likelihood: 42.3821
# Epoch 456/1000
# 1/1 - 0s - loss: 57.5790 - gaussian_likelihood: 42.4800
# Epoch 457/1000
# 1/1 - 0s - loss: 61.8088 - gaussian_likelihood: 46.7024
# Epoch 458/1000
# 1/1 - 0s - loss: 52.0196 - gaussian_likelihood: 36.8797
# Epoch 459/1000
# 1/1 - 0s - loss: 52.1197 - gaussian_likelihood: 36.9848
# Epoch 460/1000
# 1/1 - 0s - loss: 51.0534 - gaussian_likelihood: 35.9235
# Epoch 461/1000
# 1/1 - 0s - loss: 55.2391 - gaussian_likelihood: 40.1131
# Epoch 462/1000
# 1/1 - 0s - loss: 52.8109 - gaussian_likelihood: 37.6485
# Epoch 463/1000
# 1/1 - 0s - loss: 54.6383 - gaussian_likelihood: 39.4543
# Epoch 464/1000
# 1/1 - 0s - loss: 49.1768 - gaussian_likelihood: 33.9888
# Epoch 465/1000
# 1/1 - 0s - loss: 51.0022 - gaussian_likelihood: 35.8167
# Epoch 466/1000
# 1/1 - 0s - loss: 48.8746 - gaussian_likelihood: 33.6877
# Epoch 467/1000
# 1/1 - 0s - loss: 48.2767 - gaussian_likelihood: 33.0926
# Epoch 468/1000
# 1/1 - 0s - loss: 47.7144 - gaussian_likelihood: 32.5362
# Epoch 469/1000
# 1/1 - 0s - loss: 50.5912 - gaussian_likelihood: 35.4202
# Epoch 470/1000
# 1/1 - 0s - loss: 48.8685 - gaussian_likelihood: 33.6856
# Epoch 471/1000
# 1/1 - 0s - loss: 50.1776 - gaussian_likelihood: 34.9961
# Epoch 472/1000
# 1/1 - 0s - loss: 47.5376 - gaussian_likelihood: 32.3634
# Epoch 473/1000
# 1/1 - 0s - loss: 55.3378 - gaussian_likelihood: 40.1668
# Epoch 474/1000
# 1/1 - 0s - loss: 48.2767 - gaussian_likelihood: 33.1031
# Epoch 475/1000
# 1/1 - 0s - loss: 48.8400 - gaussian_likelihood: 33.6701
# Epoch 476/1000
# 1/1 - 0s - loss: 51.8617 - gaussian_likelihood: 36.6984
# Epoch 477/1000
# 1/1 - 0s - loss: 48.9581 - gaussian_likelihood: 33.7947
# Epoch 478/1000
# 1/1 - 0s - loss: 47.2171 - gaussian_likelihood: 32.0542
# Epoch 479/1000
# 1/1 - 0s - loss: 44.5785 - gaussian_likelihood: 29.4233
# Epoch 480/1000
# 1/1 - 0s - loss: 45.9916 - gaussian_likelihood: 30.8443
# Epoch 481/1000
# 1/1 - 0s - loss: 44.2973 - gaussian_likelihood: 29.1415
# Epoch 482/1000
# 1/1 - 0s - loss: 44.6703 - gaussian_likelihood: 29.5170
# Epoch 483/1000
# 1/1 - 0s - loss: 52.5943 - gaussian_likelihood: 37.4458
# Epoch 484/1000
# 1/1 - 0s - loss: 43.6647 - gaussian_likelihood: 28.5231
# Epoch 485/1000
# 1/1 - 0s - loss: 43.5432 - gaussian_likelihood: 28.4074
# Epoch 486/1000
# 1/1 - 0s - loss: 47.6726 - gaussian_likelihood: 32.5357
# Epoch 487/1000
# 1/1 - 0s - loss: 50.2500 - gaussian_likelihood: 35.1160
# Epoch 488/1000
# 1/1 - 0s - loss: 42.0279 - gaussian_likelihood: 26.8738
# Epoch 489/1000
# 1/1 - 0s - loss: 44.5701 - gaussian_likelihood: 29.4262
# Epoch 490/1000
# 1/1 - 0s - loss: 41.1714 - gaussian_likelihood: 26.0363
# Epoch 491/1000
# 1/1 - 0s - loss: 45.7862 - gaussian_likelihood: 30.6615
# Epoch 492/1000
# 1/1 - 0s - loss: 47.2712 - gaussian_likelihood: 32.1380
# Epoch 493/1000
# 1/1 - 0s - loss: 44.0310 - gaussian_likelihood: 28.8973
# Epoch 494/1000
# 1/1 - 0s - loss: 40.7736 - gaussian_likelihood: 25.6399
# Epoch 495/1000
# 1/1 - 0s - loss: 43.3607 - gaussian_likelihood: 28.2369
# Epoch 496/1000
# 1/1 - 0s - loss: 41.5543 - gaussian_likelihood: 26.4289
# Epoch 497/1000
# 1/1 - 0s - loss: 42.5141 - gaussian_likelihood: 27.3974
# Epoch 498/1000
# 1/1 - 0s - loss: 41.3186 - gaussian_likelihood: 26.2080
# Epoch 499/1000
# 1/1 - 0s - loss: 46.9930 - gaussian_likelihood: 31.8834
# Epoch 500/1000
# 1/1 - 0s - loss: 41.9697 - gaussian_likelihood: 26.8622
# Epoch 501/1000
# 1/1 - 0s - loss: 42.8171 - gaussian_likelihood: 27.7040
# Epoch 502/1000
# 1/1 - 0s - loss: 49.0815 - gaussian_likelihood: 33.9588
# Epoch 503/1000
# 1/1 - 0s - loss: 40.8670 - gaussian_likelihood: 25.7339
# Epoch 504/1000
# 1/1 - 0s - loss: 38.9184 - gaussian_likelihood: 23.7920
# Epoch 505/1000
# 1/1 - 0s - loss: 41.1157 - gaussian_likelihood: 25.9974
# Epoch 506/1000
# 1/1 - 0s - loss: 47.5324 - gaussian_likelihood: 32.4004
# Epoch 507/1000
# 1/1 - 0s - loss: 38.6831 - gaussian_likelihood: 23.5520
# Epoch 508/1000
# 1/1 - 0s - loss: 38.5536 - gaussian_likelihood: 23.4232
# Epoch 509/1000
# 1/1 - 0s - loss: 46.2269 - gaussian_likelihood: 31.1054
# Epoch 510/1000
# 1/1 - 0s - loss: 46.9851 - gaussian_likelihood: 31.8648
# Epoch 511/1000
# 1/1 - 0s - loss: 39.9687 - gaussian_likelihood: 24.8530
# Epoch 512/1000
# 1/1 - 0s - loss: 38.1276 - gaussian_likelihood: 23.0150
# Epoch 513/1000
# 1/1 - 0s - loss: 45.3706 - gaussian_likelihood: 30.2598
# Epoch 514/1000
# 1/1 - 0s - loss: 45.7889 - gaussian_likelihood: 30.6701
# Epoch 515/1000
# 1/1 - 0s - loss: 38.9882 - gaussian_likelihood: 23.8417
# Epoch 516/1000
# 1/1 - 0s - loss: 37.0213 - gaussian_likelihood: 21.8783
# Epoch 517/1000
# 1/1 - 0s - loss: 36.7554 - gaussian_likelihood: 21.6162
# Epoch 518/1000
# 1/1 - 0s - loss: 36.3951 - gaussian_likelihood: 21.2552
# Epoch 519/1000
# 1/1 - 0s - loss: 36.4719 - gaussian_likelihood: 21.3401
# Epoch 520/1000
# 1/1 - 0s - loss: 40.3564 - gaussian_likelihood: 25.2360
# Epoch 521/1000
# 1/1 - 0s - loss: 36.9844 - gaussian_likelihood: 21.8690
# Epoch 522/1000
# 1/1 - 0s - loss: 43.6576 - gaussian_likelihood: 28.5536
# Epoch 523/1000
# 1/1 - 0s - loss: 44.8197 - gaussian_likelihood: 29.7191
# Epoch 524/1000
# 1/1 - 0s - loss: 37.2002 - gaussian_likelihood: 22.1017
# Epoch 525/1000
# 1/1 - 0s - loss: 35.3293 - gaussian_likelihood: 20.2371
# Epoch 526/1000
# 1/1 - 0s - loss: 38.4398 - gaussian_likelihood: 23.3559
# Epoch 527/1000
# 1/1 - 0s - loss: 36.2836 - gaussian_likelihood: 21.2043
# Epoch 528/1000
# 1/1 - 0s - loss: 36.4307 - gaussian_likelihood: 21.3590
# Epoch 529/1000
# 1/1 - 0s - loss: 37.4734 - gaussian_likelihood: 22.4020
# Epoch 530/1000
# 1/1 - 0s - loss: 36.5050 - gaussian_likelihood: 21.4221
# Epoch 531/1000
# 1/1 - 0s - loss: 36.1576 - gaussian_likelihood: 21.0847
# Epoch 532/1000
# 1/1 - 0s - loss: 35.4316 - gaussian_likelihood: 20.3590
# Epoch 533/1000
# 1/1 - 0s - loss: 33.8576 - gaussian_likelihood: 18.7945
# Epoch 534/1000
# 1/1 - 0s - loss: 33.6424 - gaussian_likelihood: 18.5868
# Epoch 535/1000
# 1/1 - 0s - loss: 34.3199 - gaussian_likelihood: 19.2696
# Epoch 536/1000
# 1/1 - 0s - loss: 33.9725 - gaussian_likelihood: 18.9330
# Epoch 537/1000
# 1/1 - 0s - loss: 33.2419 - gaussian_likelihood: 18.2124
# Epoch 538/1000
# 1/1 - 0s - loss: 37.5913 - gaussian_likelihood: 22.5702
# Epoch 539/1000
# 1/1 - 0s - loss: 32.6118 - gaussian_likelihood: 17.5955
# Epoch 540/1000
# 1/1 - 0s - loss: 34.7210 - gaussian_likelihood: 19.7157
# Epoch 541/1000
# 1/1 - 0s - loss: 38.2108 - gaussian_likelihood: 23.2147
# Epoch 542/1000
# 1/1 - 0s - loss: 38.5748 - gaussian_likelihood: 23.5750
# Epoch 543/1000
# 1/1 - 0s - loss: 31.3865 - gaussian_likelihood: 16.3756
# Epoch 544/1000
# 1/1 - 0s - loss: 34.0932 - gaussian_likelihood: 19.0930
# Epoch 545/1000
# 1/1 - 0s - loss: 33.6735 - gaussian_likelihood: 18.6745
# Epoch 546/1000
# 1/1 - 0s - loss: 32.8010 - gaussian_likelihood: 17.8107
# Epoch 547/1000
# 1/1 - 0s - loss: 31.5439 - gaussian_likelihood: 16.5637
# Epoch 548/1000
# 1/1 - 0s - loss: 33.1646 - gaussian_likelihood: 18.1942
# Epoch 549/1000
# 1/1 - 0s - loss: 33.7693 - gaussian_likelihood: 18.7964
# Epoch 550/1000
# 1/1 - 0s - loss: 29.7895 - gaussian_likelihood: 14.8104
# Epoch 551/1000
# 1/1 - 0s - loss: 32.8430 - gaussian_likelihood: 17.8750
# Epoch 552/1000
# 1/1 - 0s - loss: 34.6115 - gaussian_likelihood: 19.6470
# Epoch 553/1000
# 1/1 - 0s - loss: 35.0600 - gaussian_likelihood: 20.0713
# Epoch 554/1000
# 1/1 - 0s - loss: 32.9390 - gaussian_likelihood: 17.9491
# Epoch 555/1000
# 1/1 - 0s - loss: 31.4395 - gaussian_likelihood: 16.4517
# Epoch 556/1000
# 1/1 - 0s - loss: 31.1528 - gaussian_likelihood: 16.1548
# Epoch 557/1000
# 1/1 - 0s - loss: 30.3452 - gaussian_likelihood: 15.3458
# Epoch 558/1000
# 1/1 - 0s - loss: 38.3728 - gaussian_likelihood: 23.3692
# Epoch 559/1000
# 1/1 - 0s - loss: 28.5564 - gaussian_likelihood: 13.5373
# Epoch 560/1000
# 1/1 - 0s - loss: 28.5534 - gaussian_likelihood: 13.5418
# Epoch 561/1000
# 1/1 - 0s - loss: 33.0136 - gaussian_likelihood: 18.0112
# Epoch 562/1000
# 1/1 - 0s - loss: 36.4974 - gaussian_likelihood: 21.4835
# Epoch 563/1000
# 1/1 - 0s - loss: 28.6979 - gaussian_likelihood: 13.6804
# Epoch 564/1000
# 1/1 - 0s - loss: 29.0126 - gaussian_likelihood: 14.0002
# Epoch 565/1000
# 1/1 - 0s - loss: 28.4911 - gaussian_likelihood: 13.4731
# Epoch 566/1000
# 1/1 - 0s - loss: 35.1928 - gaussian_likelihood: 20.1772
# Epoch 567/1000
# 1/1 - 0s - loss: 30.3276 - gaussian_likelihood: 15.2923
# Epoch 568/1000
# 1/1 - 0s - loss: 29.0042 - gaussian_likelihood: 13.9713
# Epoch 569/1000
# 1/1 - 0s - loss: 29.9857 - gaussian_likelihood: 14.9579
# Epoch 570/1000
# 1/1 - 0s - loss: 31.2283 - gaussian_likelihood: 16.1822
# Epoch 571/1000
# 1/1 - 0s - loss: 29.4124 - gaussian_likelihood: 14.3694
# Epoch 572/1000
# 1/1 - 0s - loss: 29.4835 - gaussian_likelihood: 14.4255
# Epoch 573/1000
# 1/1 - 0s - loss: 28.8043 - gaussian_likelihood: 13.7240
# Epoch 574/1000
# 1/1 - 0s - loss: 26.6547 - gaussian_likelihood: 11.5772
# Epoch 575/1000
# 1/1 - 0s - loss: 27.9637 - gaussian_likelihood: 12.8843
# Epoch 576/1000
# 1/1 - 0s - loss: 39.9716 - gaussian_likelihood: 24.8779
# Epoch 577/1000
# 1/1 - 0s - loss: 27.9325 - gaussian_likelihood: 12.8156
# Epoch 578/1000
# 1/1 - 0s - loss: 25.9156 - gaussian_likelihood: 10.7997
# Epoch 579/1000
# 1/1 - 0s - loss: 26.0098 - gaussian_likelihood: 10.8970
# Epoch 580/1000
# 1/1 - 0s - loss: 26.5365 - gaussian_likelihood: 11.4266
# Epoch 581/1000
# 1/1 - 0s - loss: 27.5111 - gaussian_likelihood: 12.4033
# Epoch 582/1000
# 1/1 - 0s - loss: 25.3373 - gaussian_likelihood: 10.2214
# Epoch 583/1000
# 1/1 - 0s - loss: 27.2633 - gaussian_likelihood: 12.1526
# Epoch 584/1000
# 1/1 - 0s - loss: 25.6544 - gaussian_likelihood: 10.5460
# Epoch 585/1000
# 1/1 - 0s - loss: 33.2664 - gaussian_likelihood: 18.1664
# Epoch 586/1000
# 1/1 - 0s - loss: 25.9875 - gaussian_likelihood: 10.8353
# Epoch 587/1000
# 1/1 - 0s - loss: 25.8478 - gaussian_likelihood: 10.6853
# Epoch 588/1000
# 1/1 - 0s - loss: 34.7967 - gaussian_likelihood: 19.6332
# Epoch 589/1000
# 1/1 - 0s - loss: 33.2603 - gaussian_likelihood: 18.0866
# Epoch 590/1000
# 1/1 - 0s - loss: 24.0249 - gaussian_likelihood: 8.8513
# Epoch 591/1000
# 1/1 - 0s - loss: 24.2611 - gaussian_likelihood: 9.0930
# Epoch 592/1000
# 1/1 - 0s - loss: 37.8399 - gaussian_likelihood: 22.6787
# Epoch 593/1000
# 1/1 - 0s - loss: 25.4694 - gaussian_likelihood: 10.2938
# Epoch 594/1000
# 1/1 - 0s - loss: 39.6411 - gaussian_likelihood: 24.4602
# Epoch 595/1000
# 1/1 - 0s - loss: 24.7564 - gaussian_likelihood: 9.5614
# Epoch 596/1000
# 1/1 - 0s - loss: 25.8989 - gaussian_likelihood: 10.7011
# Epoch 597/1000
# 1/1 - 0s - loss: 26.1928 - gaussian_likelihood: 10.9899
# Epoch 598/1000
# 1/1 - 0s - loss: 24.2402 - gaussian_likelihood: 9.0431
# Epoch 599/1000
# 1/1 - 0s - loss: 26.0657 - gaussian_likelihood: 10.8676
# Epoch 600/1000
# 1/1 - 0s - loss: 23.0241 - gaussian_likelihood: 7.8104
# Epoch 601/1000
# 1/1 - 0s - loss: 22.6532 - gaussian_likelihood: 7.4470
# Epoch 602/1000
# 1/1 - 0s - loss: 23.2981 - gaussian_likelihood: 8.1006
# Epoch 603/1000
# 1/1 - 0s - loss: 22.6717 - gaussian_likelihood: 7.4779
# Epoch 604/1000
# 1/1 - 0s - loss: 22.6354 - gaussian_likelihood: 7.4475
# Epoch 605/1000
# 1/1 - 0s - loss: 22.7508 - gaussian_likelihood: 7.5709
# Epoch 606/1000
# 1/1 - 0s - loss: 26.3336 - gaussian_likelihood: 11.1552
# Epoch 607/1000
# 1/1 - 0s - loss: 21.5781 - gaussian_likelihood: 6.3997
# Epoch 608/1000
# 1/1 - 0s - loss: 23.4279 - gaussian_likelihood: 8.2595
# Epoch 609/1000
# 1/1 - 0s - loss: 25.0648 - gaussian_likelihood: 9.9042
# Epoch 610/1000
# 1/1 - 0s - loss: 26.3839 - gaussian_likelihood: 11.2044
# Epoch 611/1000
# 1/1 - 0s - loss: 22.9783 - gaussian_likelihood: 7.8059
# Epoch 612/1000
# 1/1 - 0s - loss: 24.6319 - gaussian_likelihood: 9.4533
# Epoch 613/1000
# 1/1 - 0s - loss: 22.5039 - gaussian_likelihood: 7.3176
# Epoch 614/1000
# 1/1 - 0s - loss: 21.9544 - gaussian_likelihood: 6.7674
# Epoch 615/1000
# 1/1 - 0s - loss: 23.4840 - gaussian_likelihood: 8.2950
# Epoch 616/1000
# 1/1 - 0s - loss: 21.2752 - gaussian_likelihood: 6.0711
# Epoch 617/1000
# 1/1 - 0s - loss: 23.5041 - gaussian_likelihood: 8.2984
# Epoch 618/1000
# 1/1 - 0s - loss: 20.2655 - gaussian_likelihood: 5.0591
# Epoch 619/1000
# 1/1 - 0s - loss: 20.0293 - gaussian_likelihood: 4.8254
# Epoch 620/1000
# 1/1 - 0s - loss: 20.4081 - gaussian_likelihood: 5.2062
# Epoch 621/1000
# 1/1 - 0s - loss: 22.1955 - gaussian_likelihood: 6.9897
# Epoch 622/1000
# 1/1 - 0s - loss: 21.6748 - gaussian_likelihood: 6.4709
# Epoch 623/1000
# 1/1 - 0s - loss: 18.5244 - gaussian_likelihood: 3.3203
# Epoch 624/1000
# 1/1 - 0s - loss: 21.7909 - gaussian_likelihood: 6.5955
# Epoch 625/1000
# 1/1 - 0s - loss: 19.7522 - gaussian_likelihood: 4.5574
# Epoch 626/1000
# 1/1 - 0s - loss: 29.7133 - gaussian_likelihood: 14.5279
# Epoch 627/1000
# 1/1 - 0s - loss: 18.8829 - gaussian_likelihood: 3.6981
# Epoch 628/1000
# 1/1 - 0s - loss: 18.5493 - gaussian_likelihood: 3.3692
# Epoch 629/1000
# 1/1 - 0s - loss: 22.1390 - gaussian_likelihood: 6.9645
# Epoch 630/1000
# 1/1 - 0s - loss: 21.2539 - gaussian_likelihood: 6.0776
# Epoch 631/1000
# 1/1 - 0s - loss: 19.4435 - gaussian_likelihood: 4.2763
# Epoch 632/1000
# 1/1 - 0s - loss: 20.0966 - gaussian_likelihood: 4.9292
# Epoch 633/1000
# 1/1 - 0s - loss: 23.5960 - gaussian_likelihood: 8.4192
# Epoch 634/1000
# 1/1 - 0s - loss: 18.2441 - gaussian_likelihood: 3.0694
# Epoch 635/1000
# 1/1 - 0s - loss: 26.5328 - gaussian_likelihood: 11.3670
# Epoch 636/1000
# 1/1 - 0s - loss: 21.0239 - gaussian_likelihood: 5.8637
# Epoch 637/1000
# 1/1 - 0s - loss: 18.0061 - gaussian_likelihood: 2.8365
# Epoch 638/1000
# 1/1 - 0s - loss: 18.9585 - gaussian_likelihood: 3.7884
# Epoch 639/1000
# 1/1 - 0s - loss: 22.8121 - gaussian_likelihood: 7.6431
# Epoch 640/1000
# 1/1 - 0s - loss: 22.9136 - gaussian_likelihood: 7.7375
# Epoch 641/1000
# 1/1 - 0s - loss: 19.7568 - gaussian_likelihood: 4.5873
# Epoch 642/1000
# 1/1 - 0s - loss: 18.2603 - gaussian_likelihood: 3.0961
# Epoch 643/1000
# 1/1 - 0s - loss: 17.6720 - gaussian_likelihood: 2.5180
# Epoch 644/1000
# 1/1 - 0s - loss: 18.9085 - gaussian_likelihood: 3.7594
# Epoch 645/1000
# 1/1 - 0s - loss: 18.7013 - gaussian_likelihood: 3.5502
# Epoch 646/1000
# 1/1 - 0s - loss: 19.6196 - gaussian_likelihood: 4.4715
# Epoch 647/1000
# 1/1 - 0s - loss: 17.4516 - gaussian_likelihood: 2.2979
# Epoch 648/1000
# 1/1 - 0s - loss: 16.3007 - gaussian_likelihood: 1.1425
# Epoch 649/1000
# 1/1 - 0s - loss: 18.5058 - gaussian_likelihood: 3.3537
# Epoch 650/1000
# 1/1 - 0s - loss: 17.5662 - gaussian_likelihood: 2.4158
# Epoch 651/1000
# ...
# Epoch 790/1000
# 1/1 - 0s - loss: 5.3255 - gaussian_likelihood: -9.8576e+00
# Epoch 791/1000
# 1/1 - 0s - loss: 7.6341 - gaussian_likelihood: -7.5451e+00
# Epoch 792/1000
# 1/1 - 0s - loss: 6.4055 - gaussian_likelihood: -8.7964e+00
# Epoch 793/1000
# 1/1 - 0s - loss: 7.1209 - gaussian_likelihood: -8.0855e+00
# Epoch 794/1000
# 1/1 - 0s - loss: 5.7263 - gaussian_likelihood: -9.4975e+00
# Epoch 795/1000
# 1/1 - 0s - loss: 4.6109 - gaussian_likelihood: -1.0617e+01
# Epoch 796/1000
# 1/1 - 0s - loss: 5.2146 - gaussian_likelihood: -1.0011e+01
# Epoch 797/1000
# 1/1 - 0s - loss: 4.7846 - gaussian_likelihood: -1.0435e+01
# Epoch 798/1000
# 1/1 - 0s - loss: 4.0768 - gaussian_likelihood: -1.1143e+01
# Epoch 799/1000
# 1/1 - 0s - loss: 4.4998 - gaussian_likelihood: -1.0712e+01
# Epoch 800/1000
# 1/1 - 0s - loss: 5.1289 - gaussian_likelihood: -1.0077e+01
# Epoch 801/1000
# 1/1 - 0s - loss: 4.2617 - gaussian_likelihood: -1.0938e+01
# Epoch 802/1000
# 1/1 - 0s - loss: 4.7908 - gaussian_likelihood: -1.0402e+01
# Epoch 803/1000
# 1/1 - 0s - loss: 5.7620 - gaussian_likelihood: -9.4313e+00
# Epoch 804/1000
# 1/1 - 0s - loss: 4.7408 - gaussian_likelihood: -1.0456e+01
# Epoch 805/1000
# 1/1 - 0s - loss: 4.5832 - gaussian_likelihood: -1.0610e+01
# Epoch 806/1000
# 1/1 - 0s - loss: 7.0869 - gaussian_likelihood: -8.1045e+00
# Epoch 807/1000
# 1/1 - 0s - loss: 3.8547 - gaussian_likelihood: -1.1331e+01
# Epoch 808/1000
# 1/1 - 0s - loss: 6.3731 - gaussian_likelihood: -8.8121e+00
# Epoch 809/1000
# 1/1 - 0s - loss: 2.9165 - gaussian_likelihood: -1.2290e+01
# Epoch 810/1000
# 1/1 - 0s - loss: 7.3098 - gaussian_likelihood: -7.8882e+00
# Epoch 811/1000
# 1/1 - 0s - loss: 6.3732 - gaussian_likelihood: -8.8171e+00
# Epoch 812/1000
# 1/1 - 0s - loss: 3.3836 - gaussian_likelihood: -1.1806e+01
# Epoch 813/1000
# 1/1 - 0s - loss: 10.6422 - gaussian_likelihood: -4.5402e+00
# Epoch 814/1000
# 1/1 - 0s - loss: 4.6215 - gaussian_likelihood: -1.0608e+01
# Epoch 815/1000
# 1/1 - 0s - loss: 3.0209 - gaussian_likelihood: -1.2215e+01
# Epoch 816/1000
# 1/1 - 0s - loss: 2.6807 - gaussian_likelihood: -1.2552e+01
# Epoch 817/1000
# 1/1 - 0s - loss: 4.0858 - gaussian_likelihood: -1.1141e+01
# Epoch 818/1000
# 1/1 - 0s - loss: 7.2201 - gaussian_likelihood: -8.0105e+00
# Epoch 819/1000
# 1/1 - 0s - loss: 4.0181 - gaussian_likelihood: -1.1224e+01
# Epoch 820/1000
# 1/1 - 0s - loss: 2.6382 - gaussian_likelihood: -1.2598e+01
# Epoch 821/1000
# 1/1 - 0s - loss: 2.8621 - gaussian_likelihood: -1.2368e+01
# Epoch 822/1000
# 1/1 - 0s - loss: 3.2332 - gaussian_likelihood: -1.1993e+01
# Epoch 823/1000
# 1/1 - 0s - loss: 3.2995 - gaussian_likelihood: -1.1927e+01
# Epoch 824/1000
# 1/1 - 0s - loss: 4.4495 - gaussian_likelihood: -1.0779e+01
# Epoch 825/1000
# 1/1 - 0s - loss: 9.0605 - gaussian_likelihood: -6.1746e+00
# Epoch 826/1000
# 1/1 - 0s - loss: 2.5151 - gaussian_likelihood: -1.2742e+01
# Epoch 827/1000
# 1/1 - 0s - loss: 4.3552 - gaussian_likelihood: -1.0900e+01
# Epoch 828/1000
# 1/1 - 0s - loss: 3.8804 - gaussian_likelihood: -1.1373e+01
# Epoch 829/1000
# 1/1 - 0s - loss: 2.9290 - gaussian_likelihood: -1.2328e+01
# Epoch 830/1000
# 1/1 - 0s - loss: 9.9629 - gaussian_likelihood: -5.2856e+00
# Epoch 831/1000
# 1/1 - 0s - loss: 4.0043 - gaussian_likelihood: -1.1243e+01
# Epoch 832/1000
# 1/1 - 0s - loss: 8.8337 - gaussian_likelihood: -6.4071e+00
# Epoch 833/1000
# 1/1 - 0s - loss: 2.7188 - gaussian_likelihood: -1.2533e+01
# Epoch 834/1000
# 1/1 - 0s - loss: 6.1816 - gaussian_likelihood: -9.0620e+00
# Epoch 835/1000
# 1/1 - 0s - loss: 2.7661 - gaussian_likelihood: -1.2470e+01
# Epoch 836/1000
# 1/1 - 0s - loss: 2.7972 - gaussian_likelihood: -1.2436e+01
# Epoch 837/1000
# 1/1 - 0s - loss: 5.7180 - gaussian_likelihood: -9.5095e+00
# Epoch 838/1000
# 1/1 - 0s - loss: 2.7374 - gaussian_likelihood: -1.2488e+01
# Epoch 839/1000
# 1/1 - 0s - loss: 2.2639 - gaussian_likelihood: -1.2950e+01
# Epoch 840/1000
# 1/1 - 0s - loss: 5.8945 - gaussian_likelihood: -9.3081e+00
# Epoch 841/1000
# 1/1 - 0s - loss: 2.2912 - gaussian_likelihood: -1.2911e+01
# Epoch 842/1000
# 1/1 - 0s - loss: 4.4803 - gaussian_likelihood: -1.0710e+01
# Epoch 843/1000
# 1/1 - 0s - loss: 2.4928 - gaussian_likelihood: -1.2700e+01
# Epoch 844/1000
# 1/1 - 0s - loss: 4.8551 - gaussian_likelihood: -1.0334e+01
# Epoch 845/1000
# 1/1 - 0s - loss: 4.9113 - gaussian_likelihood: -1.0291e+01
# Epoch 846/1000
# 1/1 - 0s - loss: 2.7209 - gaussian_likelihood: -1.2479e+01
# Epoch 847/1000
# 1/1 - 0s - loss: 3.6832 - gaussian_likelihood: -1.1520e+01
# Epoch 848/1000
# 1/1 - 0s - loss: 5.0443 - gaussian_likelihood: -1.0175e+01
# Epoch 849/1000
# 1/1 - 0s - loss: 6.2665 - gaussian_likelihood: -8.9581e+00
# Epoch 850/1000
# 1/1 - 0s - loss: 2.9316 - gaussian_likelihood: -1.2296e+01
# Epoch 851/1000
# 1/1 - 0s - loss: 2.6862 - gaussian_likelihood: -1.2537e+01
# Epoch 852/1000
# 1/1 - 0s - loss: 2.1742 - gaussian_likelihood: -1.3046e+01
# Epoch 853/1000
# 1/1 - 0s - loss: 1.4005 - gaussian_likelihood: -1.3818e+01
# Epoch 854/1000
# 1/1 - 0s - loss: 4.0999 - gaussian_likelihood: -1.1108e+01
# Epoch 855/1000
# 1/1 - 0s - loss: 2.5155 - gaussian_likelihood: -1.2710e+01
# Epoch 856/1000
# 1/1 - 0s - loss: 4.0767 - gaussian_likelihood: -1.1150e+01
# Epoch 857/1000
# 1/1 - 0s - loss: 1.6864 - gaussian_likelihood: -1.3544e+01
# Epoch 858/1000
# 1/1 - 0s - loss: 1.3773 - gaussian_likelihood: -1.3853e+01
# Epoch 859/1000
# 1/1 - 0s - loss: 3.1993 - gaussian_likelihood: -1.2025e+01
# Epoch 860/1000
# 1/1 - 0s - loss: 2.4045 - gaussian_likelihood: -1.2812e+01
# Epoch 861/1000
# 1/1 - 0s - loss: 3.3425 - gaussian_likelihood: -1.1868e+01
# Epoch 862/1000
# 1/1 - 0s - loss: 0.7805 - gaussian_likelihood: -1.4426e+01
# Epoch 863/1000
# 1/1 - 0s - loss: 1.6047 - gaussian_likelihood: -1.3590e+01
# Epoch 864/1000
# 1/1 - 0s - loss: 6.9335 - gaussian_likelihood: -8.2482e+00
# Epoch 865/1000
# 1/1 - 0s - loss: 1.0619 - gaussian_likelihood: -1.4161e+01
# Epoch 866/1000
# 1/1 - 0s - loss: 3.6567 - gaussian_likelihood: -1.1558e+01
# Epoch 867/1000
# 1/1 - 0s - loss: 2.5218 - gaussian_likelihood: -1.2706e+01
# Epoch 868/1000
# 1/1 - 0s - loss: 1.5473 - gaussian_likelihood: -1.3684e+01
# Epoch 869/1000
# 1/1 - 0s - loss: 4.4514 - gaussian_likelihood: -1.0781e+01
# Epoch 870/1000
# 1/1 - 0s - loss: 2.8278 - gaussian_likelihood: -1.2439e+01
# Epoch 871/1000
# 1/1 - 0s - loss: 1.8905 - gaussian_likelihood: -1.3391e+01
# Epoch 872/1000
# 1/1 - 0s - loss: 4.1035 - gaussian_likelihood: -1.1176e+01
# Epoch 873/1000
# 1/1 - 0s - loss: 1.8363 - gaussian_likelihood: -1.3456e+01
# Epoch 874/1000
# 1/1 - 0s - loss: 1.6277 - gaussian_likelihood: -1.3673e+01
# Epoch 875/1000
# 1/1 - 0s - loss: 0.9767 - gaussian_likelihood: -1.4324e+01
# Epoch 876/1000
# 1/1 - 0s - loss: 1.0855 - gaussian_likelihood: -1.4212e+01
# Epoch 877/1000
# 1/1 - 0s - loss: 3.1462 - gaussian_likelihood: -1.2149e+01
# Epoch 878/1000
# 1/1 - 0s - loss: 7.3105 - gaussian_likelihood: -8.0114e+00
# Epoch 879/1000
# 1/1 - 0s - loss: 2.3066 - gaussian_likelihood: -1.3023e+01
# Epoch 880/1000
# 1/1 - 0s - loss: 1.9800 - gaussian_likelihood: -1.3353e+01
# Epoch 881/1000
# 1/1 - 0s - loss: 3.1796 - gaussian_likelihood: -1.2146e+01
# Epoch 882/1000
# 1/1 - 0s - loss: 1.9468 - gaussian_likelihood: -1.3384e+01
# Epoch 883/1000
# 1/1 - 0s - loss: 0.6576 - gaussian_likelihood: -1.4667e+01
# Epoch 884/1000
# 1/1 - 0s - loss: 1.1466 - gaussian_likelihood: -1.4171e+01
# Epoch 885/1000
# 1/1 - 0s - loss: 0.6418 - gaussian_likelihood: -1.4675e+01
# Epoch 886/1000
# 1/1 - 0s - loss: 0.9069 - gaussian_likelihood: -1.4404e+01
# Epoch 887/1000
# 1/1 - 0s - loss: 0.1600 - gaussian_likelihood: -1.5146e+01
# Epoch 888/1000
# 1/1 - 0s - loss: 0.1889 - gaussian_likelihood: -1.5106e+01
# Epoch 889/1000
# 1/1 - 0s - loss: 1.0984 - gaussian_likelihood: -1.4186e+01
# Epoch 890/1000
# 1/1 - 0s - loss: 1.0200 - gaussian_likelihood: -1.4262e+01
# Epoch 891/1000
# 1/1 - 0s - loss: 3.9007 - gaussian_likelihood: -1.1371e+01
# Epoch 892/1000
# 1/1 - 0s - loss: 2.4029 - gaussian_likelihood: -1.2864e+01
# Epoch 893/1000
# 1/1 - 0s - loss: 0.7154 - gaussian_likelihood: -1.4552e+01
# Epoch 894/1000
# 1/1 - 0s - loss: 0.1039 - gaussian_likelihood: -1.5155e+01
# Epoch 895/1000
# 1/1 - 0s - loss: 1.1993 - gaussian_likelihood: -1.4049e+01
# Epoch 896/1000
# 1/1 - 0s - loss: 1.4245 - gaussian_likelihood: -1.3826e+01
# Epoch 897/1000
# 1/1 - 0s - loss: 3.3484 - gaussian_likelihood: -1.1907e+01
# Epoch 898/1000
# 1/1 - 0s - loss: 1.6257 - gaussian_likelihood: -1.3650e+01
# Epoch 899/1000
# 1/1 - 0s - loss: 0.8663 - gaussian_likelihood: -1.4413e+01
# Epoch 900/1000
# 1/1 - 0s - loss: 2.6092 - gaussian_likelihood: -1.2665e+01
# Epoch 901/1000
# 1/1 - 0s - loss: 2.1016 - gaussian_likelihood: -1.3190e+01
# Epoch 902/1000
# 1/1 - 0s - loss: 0.6321 - gaussian_likelihood: -1.4671e+01
# Epoch 903/1000
# 1/1 - 0s - loss: 4.0496 - gaussian_likelihood: -1.1248e+01
# Epoch 904/1000
# 1/1 - 0s - loss: 2.7042 - gaussian_likelihood: -1.2592e+01
# Epoch 905/1000
# 1/1 - 0s - loss: 2.8454 - gaussian_likelihood: -1.2458e+01
# Epoch 906/1000
# 1/1 - 0s - loss: 0.3626 - gaussian_likelihood: -1.4969e+01
# Epoch 907/1000
# 1/1 - 0s - loss: -2.3522e-01 - gaussian_likelihood: -1.5563e+01
# Epoch 908/1000
# 1/1 - 0s - loss: 1.0059 - gaussian_likelihood: -1.4317e+01
# Epoch 909/1000
# 1/1 - 0s - loss: 1.1424 - gaussian_likelihood: -1.4172e+01
# Epoch 910/1000
# 1/1 - 0s - loss: -1.5381e-01 - gaussian_likelihood: -1.5459e+01
# Epoch 911/1000
# 1/1 - 0s - loss: -1.8424e-01 - gaussian_likelihood: -1.5480e+01
# Epoch 912/1000
# 1/1 - 0s - loss: -4.0469e-01 - gaussian_likelihood: -1.5690e+01
# Epoch 913/1000
# 1/1 - 0s - loss: 4.3690 - gaussian_likelihood: -1.0907e+01
# Epoch 914/1000
# 1/1 - 0s - loss: 0.4025 - gaussian_likelihood: -1.4901e+01
# Epoch 915/1000
# 1/1 - 0s - loss: 4.7576 - gaussian_likelihood: -1.0539e+01
# Epoch 916/1000
# 1/1 - 0s - loss: 2.0029 - gaussian_likelihood: -1.3339e+01
# Epoch 917/1000
# 1/1 - 0s - loss: 0.6204 - gaussian_likelihood: -1.4728e+01
# Epoch 918/1000
# 1/1 - 0s - loss: 2.1306 - gaussian_likelihood: -1.3224e+01
# Epoch 919/1000
# 1/1 - 0s - loss: -7.4514e-01 - gaussian_likelihood: -1.6121e+01
# Epoch 920/1000
# 1/1 - 0s - loss: 4.0667 - gaussian_likelihood: -1.1303e+01
# Epoch 921/1000
# 1/1 - 0s - loss: 0.8550 - gaussian_likelihood: -1.4518e+01
# Epoch 922/1000
# 1/1 - 0s - loss: -3.7555e-01 - gaussian_likelihood: -1.5759e+01
# Epoch 923/1000
# 1/1 - 0s - loss: 0.1150 - gaussian_likelihood: -1.5263e+01
# Epoch 924/1000
# 1/1 - 0s - loss: 0.3948 - gaussian_likelihood: -1.4983e+01
# Epoch 925/1000
# 1/1 - 0s - loss: 0.0186 - gaussian_likelihood: -1.5356e+01
# Epoch 926/1000
# 1/1 - 0s - loss: 0.9870 - gaussian_likelihood: -1.4385e+01
# Epoch 927/1000
# 1/1 - 0s - loss: 0.6196 - gaussian_likelihood: -1.4746e+01
# Epoch 928/1000
# 1/1 - 0s - loss: -5.1383e-01 - gaussian_likelihood: -1.5877e+01
# Epoch 929/1000
# 1/1 - 0s - loss: -5.8010e-01 - gaussian_likelihood: -1.5936e+01
# Epoch 930/1000
# 1/1 - 0s - loss: 1.5746 - gaussian_likelihood: -1.3773e+01
# Epoch 931/1000
# 1/1 - 0s - loss: -5.6762e-01 - gaussian_likelihood: -1.5906e+01
# Epoch 932/1000
# 1/1 - 0s - loss: 1.0788 - gaussian_likelihood: -1.4253e+01
# Epoch 933/1000
# 1/1 - 0s - loss: 0.7569 - gaussian_likelihood: -1.4566e+01
# Epoch 934/1000
# 1/1 - 0s - loss: 0.5489 - gaussian_likelihood: -1.4776e+01
# Epoch 935/1000
# 1/1 - 0s - loss: 1.2775 - gaussian_likelihood: -1.4042e+01
# Epoch 936/1000
# 1/1 - 0s - loss: 0.2521 - gaussian_likelihood: -1.5072e+01
# Epoch 937/1000
# 1/1 - 0s - loss: 2.6155 - gaussian_likelihood: -1.2701e+01
# Epoch 938/1000
# 1/1 - 0s - loss: 1.3746 - gaussian_likelihood: -1.3946e+01
# Epoch 939/1000
# 1/1 - 0s - loss: -1.1254e+00 - gaussian_likelihood: -1.6447e+01
# Epoch 940/1000
# 1/1 - 0s - loss: 0.3229 - gaussian_likelihood: -1.4990e+01
# Epoch 941/1000
# 1/1 - 0s - loss: 1.1084 - gaussian_likelihood: -1.4203e+01
# Epoch 942/1000
# 1/1 - 0s - loss: -1.4345e+00 - gaussian_likelihood: -1.6754e+01
# Epoch 943/1000
# 1/1 - 0s - loss: 1.5609 - gaussian_likelihood: -1.3750e+01
# Epoch 944/1000
# 1/1 - 0s - loss: 0.4966 - gaussian_likelihood: -1.4807e+01
# Epoch 945/1000
# 1/1 - 0s - loss: 0.5359 - gaussian_likelihood: -1.4774e+01
# Epoch 946/1000
# 1/1 - 0s - loss: 0.9294 - gaussian_likelihood: -1.4385e+01
# Epoch 947/1000
# 1/1 - 0s - loss: 1.1094 - gaussian_likelihood: -1.4217e+01
# Epoch 948/1000
# 1/1 - 0s - loss: 0.4375 - gaussian_likelihood: -1.4888e+01
# Epoch 949/1000
# 1/1 - 0s - loss: -1.2525e+00 - gaussian_likelihood: -1.6587e+01
# Epoch 950/1000
# 1/1 - 0s - loss: -3.6102e-01 - gaussian_likelihood: -1.5689e+01
# Epoch 951/1000
# 1/1 - 0s - loss: 0.0494 - gaussian_likelihood: -1.5285e+01
# Epoch 952/1000
# 1/1 - 0s - loss: 1.8308 - gaussian_likelihood: -1.3498e+01
# Epoch 953/1000
# 1/1 - 0s - loss: 1.6021 - gaussian_likelihood: -1.3750e+01
# Epoch 954/1000
# 1/1 - 0s - loss: -4.7337e-02 - gaussian_likelihood: -1.5427e+01
# Epoch 955/1000
# 1/1 - 0s - loss: -6.2319e-01 - gaussian_likelihood: -1.6012e+01
# Epoch 956/1000
# 1/1 - 0s - loss: 0.1338 - gaussian_likelihood: -1.5252e+01
# Epoch 957/1000
# 1/1 - 0s - loss: 0.9263 - gaussian_likelihood: -1.4454e+01
# Epoch 958/1000
# 1/1 - 0s - loss: 0.5776 - gaussian_likelihood: -1.4812e+01
# Epoch 959/1000
# 1/1 - 0s - loss: -8.4686e-02 - gaussian_likelihood: -1.5486e+01
# Epoch 960/1000
# 1/1 - 0s - loss: -1.7873e+00 - gaussian_likelihood: -1.7184e+01
# Epoch 961/1000
# 1/1 - 0s - loss: -1.2240e+00 - gaussian_likelihood: -1.6612e+01
# Epoch 962/1000
# 1/1 - 0s - loss: -1.5514e+00 - gaussian_likelihood: -1.6932e+01
# Epoch 963/1000
# 1/1 - 0s - loss: -1.8142e+00 - gaussian_likelihood: -1.7188e+01
# Epoch 964/1000
# 1/1 - 0s - loss: -1.2052e+00 - gaussian_likelihood: -1.6569e+01
# Epoch 965/1000
# 1/1 - 0s - loss: -1.6712e+00 - gaussian_likelihood: -1.7029e+01
# Epoch 966/1000
# 1/1 - 0s - loss: -9.0034e-01 - gaussian_likelihood: -1.6250e+01
# Epoch 967/1000
# 1/1 - 0s - loss: 0.6866 - gaussian_likelihood: -1.4662e+01
# Epoch 968/1000
# 1/1 - 0s - loss: -6.9621e-01 - gaussian_likelihood: -1.6053e+01
# Epoch 969/1000
# 1/1 - 0s - loss: -4.2603e-01 - gaussian_likelihood: -1.5785e+01
# Epoch 970/1000
# 1/1 - 0s - loss: -1.2265e+00 - gaussian_likelihood: -1.6592e+01
# Epoch 971/1000
# 1/1 - 0s - loss: -4.6902e-01 - gaussian_likelihood: -1.5831e+01
# Epoch 972/1000
# 1/1 - 0s - loss: -1.8997e+00 - gaussian_likelihood: -1.7260e+01
# Epoch 973/1000
# 1/1 - 0s - loss: 1.7659 - gaussian_likelihood: -1.3585e+01
# Epoch 974/1000
# 1/1 - 0s - loss: -1.7080e+00 - gaussian_likelihood: -1.7049e+01
# Epoch 975/1000
# 1/1 - 0s - loss: -1.4830e+00 - gaussian_likelihood: -1.6815e+01
# Epoch 976/1000
# 1/1 - 0s - loss: 4.0388 - gaussian_likelihood: -1.1281e+01
# Epoch 977/1000
# 1/1 - 0s - loss: -1.3435e+00 - gaussian_likelihood: -1.6698e+01
# Epoch 978/1000
# 1/1 - 0s - loss: 3.9646 - gaussian_likelihood: -1.1387e+01
# Epoch 979/1000
# 1/1 - 0s - loss: 2.6698 - gaussian_likelihood: -1.2679e+01
# Epoch 980/1000
# 1/1 - 0s - loss: -6.2409e-01 - gaussian_likelihood: -1.5971e+01
# Epoch 981/1000
# 1/1 - 0s - loss: -2.2385e+00 - gaussian_likelihood: -1.7587e+01
# Epoch 982/1000
# 1/1 - 0s - loss: -1.8604e+00 - gaussian_likelihood: -1.7197e+01
# Epoch 983/1000
# 1/1 - 0s - loss: -2.0043e+00 - gaussian_likelihood: -1.7332e+01
# Epoch 984/1000
# 1/1 - 0s - loss: -2.4263e-02 - gaussian_likelihood: -1.5339e+01
# Epoch 985/1000
# 1/1 - 0s - loss: -2.0400e+00 - gaussian_likelihood: -1.7367e+01
# Epoch 986/1000
# 1/1 - 0s - loss: 0.6981 - gaussian_likelihood: -1.4618e+01
# Epoch 987/1000
# 1/1 - 0s - loss: 5.0512 - gaussian_likelihood: -1.0264e+01
# Epoch 988/1000
# 1/1 - 0s - loss: -1.5674e+00 - gaussian_likelihood: -1.6885e+01
# Epoch 989/1000
# 1/1 - 0s - loss: -6.1422e-01 - gaussian_likelihood: -1.5923e+01
# Epoch 990/1000
# 1/1 - 0s - loss: -1.7579e+00 - gaussian_likelihood: -1.7062e+01
# Epoch 991/1000
# 1/1 - 0s - loss: -1.8726e+00 - gaussian_likelihood: -1.7169e+01
# Epoch 992/1000
# 1/1 - 0s - loss: -1.1063e+00 - gaussian_likelihood: -1.6391e+01
# Epoch 993/1000
# 1/1 - 0s - loss: -3.1847e-01 - gaussian_likelihood: -1.5606e+01
# Epoch 994/1000
# 1/1 - 0s - loss: -1.5714e+00 - gaussian_likelihood: -1.6860e+01
# Epoch 995/1000
# 1/1 - 0s - loss: -2.0134e+00 - gaussian_likelihood: -1.7299e+01
# Epoch 996/1000
# 1/1 - 0s - loss: -1.0647e+00 - gaussian_likelihood: -1.6338e+01
# Epoch 997/1000
# 1/1 - 0s - loss: -9.3637e-01 - gaussian_likelihood: -1.6210e+01
# Epoch 998/1000
# 1/1 - 0s - loss: 0.3133 - gaussian_likelihood: -1.4956e+01
# Epoch 999/1000
# 1/1 - 0s - loss: -1.8834e-01 - gaussian_likelihood: -1.5464e+01
# Epoch 1000/1000
# 1/1 - 0s - loss: -1.1653e+00 - gaussian_likelihood: -1.6454e+01
# Total time elapsed for training = 43.90372824668884 seconds
# Training finished at 2020-07-21 13:07:35.844761

# %%
plt.plot(history.history['loss'])

# %%
for weights in model.get_weights():
    print('Weight/bias:', weights)
# Out:
# Weight/bias: [[2.9361267]
#  [1.9069946]]
# Weight/bias: [[-3.205471 ]
#  [-3.0449386]]
# Weight/bias: [0.08204258]
# Weight/bias: [-3.513804]

# %%
y_predict = np.zeros((N_SAMPLES, N_DATA))
for i in trange(N_SAMPLES):
    y_predict[i] = model.predict(Xy.batch(N_DATA)).flatten()
# Out:
# 100%|██████████| 1000/1000 [01:14<00:00, 15.22it/s]

# %%
plt.figure(dpi=200)
plt.errorbar(y, y_predict.mean(0),
             yerr=y_predict.std(0) + 2*LIKELIHOOD_STDDEV, 
             linestyle='None', marker=None)

plt.errorbar(y, y_predict.mean(0),
             yerr=y_predict.std(0), 
             linestyle='None', marker='o', mec='k', ms=1)

plt.plot([y.min()-0.5, y.max()+0.5], [y.min()-0.5, y.max()+0.5], 'k')

plt.axis('square')


plt.show()

# %%
Xb = np.concatenate([X, np.ones((N_DATA, 1))], axis=1)
# Xb = X
Sigma_0 = PRIOR_STDDEV**2 * np.eye(Xb.shape[1])
Sigma_e = LIKELIHOOD_STDDEV**2 * np.eye(N_DATA)
Sigma_k = np.linalg.inv(np.linalg.inv(Sigma_0) + Xb.T @ Xb/LIKELIHOOD_STDDEV**2)
Mu_k = Sigma_k @ (Xb.T @ y/LIKELIHOOD_STDDEV**2)

# %%
Mu_k
# Out:
# array([[ 3.05448974],
#        [ 2.04041812],
#        [-0.05174225]])

# %%
print(model.get_weights()[0])
print(model.get_weights()[2])
# Out:
# [[2.9361267]
#  [1.9069946]]
# [0.08204258]

# %%
Sigma_k
# Out:
# array([[ 0.00546116,  0.00269475, -0.00415022],
#        [ 0.00269475,  0.00741477, -0.00484326],
#        [-0.00415022, -0.00484326,  0.00506311]])

# %%
U, s, V = np.linalg.svd(Sigma_k)
U @ np.diag(s**0.5) @ V
# np.linalg.cholesky(Sigma_k)
# Out:
# array([[ 0.06594917,  0.01131052, -0.03136778],
#        [ 0.01131052,  0.07835352, -0.03387583],
#        [-0.03136778, -0.03387583,  0.05414425]])

# %%
print(np.log(np.exp(model.get_weights()[1]) + 1))
print(np.log(np.exp(model.get_weights()[3]) + 1))
# Out:
# [[0.03973956]
#  [0.04650107]]
# [0.02934846]

# %%
print(np.exp(model.get_weights()[1]))
print(np.exp(model.get_weights()[3]))
# Out:
# [[0.0405398 ]
#  [0.04759923]]
# [0.0297834]
